# %% [markdown]
# # Analyze the Voltage and Current Dynamics of a CUBA LIF Neuron and choose appropriate values for each use case

# %% [markdown]
# ### Check WD (change if necessary) and file loading

# %%
# Show current directory
import os
curr_dir = os.getcwd()
print(curr_dir)

# Check if the current WD is the file location
if "/src/dynamics_analysis" not in os.getcwd():
    # Set working directory to this file location
    file_location = f"{os.getcwd()}/thesis-lava/src/dynamics_analysis"
    print("File Location: ", file_location)

    # Change the current working Directory
    os.chdir(file_location)

    # New Working Directory
    print("New Working Directory: ", os.getcwd())
# Out:
# /home/monkin/Desktop/feup/thesis/thesis-lava/src/dynamics_analysis

# %% [markdown]
# ## Channel Burst Detection
# Let's find the optimal parameters for the channel burst detection. we will **consider a network burst any sequence of spikes that occurs within 10 ms**.
#
# Therefore, in the worst case scenario, the 2 spikes are separated by 10 ms.
#
# To find the optimal parameters, we will test different combinations of the parameters: `spike_weight`, `du`, and `dv` and we will see the resulting voltage in the worst case scenario that we still consider as a burst (10 ms). To find the optimal parameters, we will also calculate the voltage if the spike occurs 1 time step delayed and choose the parameters where:
# 1. The voltage is above the threshold in the worst case scenario that is still considered a burst.
# 2. The voltage is below the threshold if the spike occurs 1 time step delayed.

# %%
from du_dv_analysis import voltage_pred, CUBADynamicsResult
import numpy as np

# Fixed Parameters
PADDING_TIME = 20               # 20ms padding time (to allow the voltage to reach the max value)
sim_time = 10 + PADDING_TIME    # 10ms simulation time (10 time steps)
num_spikes = 2                  # Number of spikes
spike_times = [0, 10]           # Let's consider the spikes are with maximum spacing
v_th = 1.0                      # Threshold voltage
recording_times = [10]

# Explorable Parameters
spike_weights = [0.05 * i for i in range(11)]
du_vals = [0.05 * i for i in range(1, 20)]
dv_vals = [0.05 * i for i in range(1, 20)]

# Variables to store the results
results_cond1 = []

# Run the simulation
for spike_weight in spike_weights:
    for du in du_vals:
        for dv in dv_vals:
            bef_v, v, after_v = voltage_pred(sim_time, du, dv, spike_times, recording_times, spike_weight)
            # print(f"bef_v: {bef_v}, v: {v}, after_v: {after_v}")

            currResult = CUBADynamicsResult(spike_weight, du, dv, bef_v, v, after_v)
            results_cond1.append(currResult)

# %%
# Show the results
print(results_cond1)

print("Number of Results Cond 1: ", len(results_cond1))
# Out:
# [{'spike_weight': 0.0, 'du': 0.05, 'dv': 0.05, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.1, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.15000000000000002, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.2, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.25, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.30000000000000004, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.35000000000000003, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.4, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.45, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.5, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.55, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.6000000000000001, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.65, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.7000000000000001, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.75, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.8, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.8500000000000001, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.9, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.05, 'dv': 0.9500000000000001, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.05, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.1, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.15000000000000002, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.2, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.25, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.30000000000000004, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.35000000000000003, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.4, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.45, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.5, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.55, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.6000000000000001, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.65, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.7000000000000001, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.75, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.8, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.8500000000000001, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.9, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.1, 'dv': 0.9500000000000001, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.15000000000000002, 'dv': 0.05, 'before v': 0.0, 'spike v': 0.0, 'after v': 0.0}, {'spike_weight': 0.0, 'du': 0.15000000000000002, 'dv': 0.1, 'before v ...
# Number of Results Cond 1:  3971

# %%
# Find the results where the Voltage is above 1.0 (i.e. a spike occurs
relevant_results1 = [result for result in results_cond1 if (
    result.bef_spike_v <= v_th and 
    result.spike_v >= v_th 
    # and result.after_spike_v <= v_th
    )]

# Print number of relevant results
print(f"Number of relevant results for Cond. 1: {len(relevant_results1)}")

# Sort the relevant results from lowest voltage to highest
relevant_results1 = sorted(relevant_results1, key=lambda item: item.after_spike_v, reverse=False)

# Show the relevant results
print(relevant_results1)
# Out:
# Number of relevant results for Cond. 1: 75
# [{'spike_weight': 0.5, 'du': 0.1, 'dv': 0.4, 'before v': 0.5710530375000001, 'spike v': 1.01697104255, 'after v': 0.6992994628514534}, {'spike_weight': 0.5, 'du': 0.4, 'dv': 0.1, 'before v': 0.5710530375000001, 'spike v': 1.0169710425500003, 'after v': 0.6992994628514535}, {'spike_weight': 0.45, 'du': 0.15000000000000002, 'dv': 0.25, 'before v': 0.6325240033406249, 'spike v': 1.0129864844587937, 'after v': 0.7005388505631589}, {'spike_weight': 0.45, 'du': 0.25, 'dv': 0.15000000000000002, 'before v': 0.632524003340625, 'spike v': 1.012986484458794, 'after v': 0.700538850563159}, {'spike_weight': 0.5, 'du': 0.2, 'dv': 0.2, 'before v': 0.6710886400000005, 'spike v': 1.0905580032000004, 'after v': 0.7116147611837194}, {'spike_weight': 0.5, 'du': 0.15000000000000002, 'dv': 0.25, 'before v': 0.7028044481562498, 'spike v': 1.1255405382875485, 'after v': 0.7783765006257319}, {'spike_weight': 0.5, 'du': 0.25, 'dv': 0.15000000000000002, 'before v': 0.70280444815625, 'spike v': 1.1255405382875487, 'after v': 0.778376500625732}, {'spike_weight': 0.5, 'du': 0.6000000000000001, 'dv': 0.05, 'before v': 0.5442109833076171, 'spike v': 1.0170528629422362, 'after v': 0.8266543373877522}, {'spike_weight': 0.5, 'du': 0.05, 'dv': 0.6000000000000001, 'before v': 0.5442109833076169, 'spike v': 1.017052862942236, 'after v': 0.8266543373877525}, {'spike_weight': 0.5, 'du': 0.35000000000000003, 'dv': 0.1, 'before v': 0.6704313935107421, 'spike v': 1.1101196258319823, 'after v': 0.8287219849991346}, {'spike_weight': 0.5, 'du': 0.1, 'dv': 0.35000000000000003, 'before v': 0.6704313935107422, 'spike v': 1.1101196258319823, 'after v': 0.8287219849991347}, {'spike_weight': 0.4, 'du': 0.2, 'dv': 0.15000000000000002, 'before v': 0.7160017755257816, 'spike v': 1.0515511821569143, 'after v': 0.8413290172367734}, {'spike_weight': 0.4, 'du': 0.15000000000000002, 'dv': 0.2, 'before v': 0.7160017755257816, 'spike v': 1.0515511821569143, 'after v': 0.8413290172367738}, {'spike_weight': 0.45, 'du': 0.1, 'dv': 0.30000000000000004, 'before v': 0.7209695592, 'spike v': 1.1115839894850001, 'after v': 0.9065199868367155}, {'spike_weight': 0.45, 'du': 0.30000000000000004, 'dv': 0.1, 'before v': 0.7209695591999999, 'spike v': 1.111583989485, 'after v': 0.9065199868367156}, {'spike_weight': 0.45, 'du': 0.05, 'dv': 0.5, 'before v': 0.5977603767383787, 'spike v': 1.0183118110264597, 'after v': 0.9088729604774162}, {'spike_weight': 0.45, 'du': 0.5, 'dv': 0.05, 'before v': 0.5977603767383787, 'spike v': 1.0183118110264597, 'after v': 0.9088729604774163}, {'spike_weight': 0.5, 'du': 0.05, 'dv': 0.55, 'before v': 0.5983964329492184, 'spike v': 1.0686468644463376, 'after v': 0.9092084385594124}, {'spike_weight': 0.5, 'du': 0.55, 'dv': 0.05, 'before v': 0.5983964329492184, 'spike v': 1.0686468644463374, 'after v': 0.9092084385594124}, {'spike_weight': 0.45, 'du': 0.15000000000000002, 'dv': 0.2, 'before v': 0.8055019974665041, 'spike v': 1.1829950799265285, 'after v': 0.94649514439137}, {'spike_weight': 0.45, 'du': 0.2, 'dv': 0.15000000000000002, 'before v': 0.805501997466504, 'spike v': 1.1829950799265285, 'after v': 0.9464951443913702}, {'spike_weight': 0.5, 'du': 0.1, 'dv': 0.30000000000000004, 'before v': 0.8010772880000001, 'spike v': 1.23509332165, 'after v': 1.0072444298185725}, {'spike_weight': 0.5, 'du': 0.30000000000000004, 'dv': 0.1, 'before v': 0.8010772879999998, 'spike v': 1.23509332165, 'after v': 1.0072444298185725}, {'spike_weight': 0.4, 'du': 0.1, 'dv': 0.25, 'before v': 0.7796398010414065, 'spike v': 1.124201226821055, 'after v': 1.0096427739605534}, {'spike_weight': 0.4, 'du': 0.25, 'dv': 0.1, 'before v': 0.7796398010414066, 'spike v': 1.124201226821055, 'after v': 1.0096427739605534}, {'spike_weight': 0.5, 'du': 0.05, 'dv': 0.5, 'before v': 0.6641781963759763, 'spike v': 1.1314575678071774, 'after v': 1.0098588449749069}, {'spike_weight': 0.5, 'du': 0.5, 'dv': 0.05, 'before v': 0.6641781963759764, 'spike v': 1.1314575678071774, 'after v': 1.009858844974907}, {'spik ...

# %% [markdown]
# ### Test the dynamics, but now with 1 more time step between the spikes

# %%
# Fixed Parameters
spike_times = [0, 11]           # Let's consider the spikes are with maximum spacing
recording_times = [10, 11]

# Variables to store the results
results_cond2 = []

# Run the simulation
for spike_weight in spike_weights:
    for du in du_vals:
        for dv in dv_vals:
            bef_v, v = voltage_pred(sim_time, du, dv, spike_times, recording_times, spike_weight)
            # print(f"bef_v: {bef_v}, v: {v}, after_v: {after_v}")

            currResult = CUBADynamicsResult(spike_weight, du, dv, bef_v, v, None)
            results_cond2.append(currResult)

# %%
# Find the results where the Voltage is below 1.0
relevant_results2 = [result for result in results_cond2 if (
    result.bef_spike_v <= v_th and 
    result.spike_v <= v_th
    )]

# Print number of relevant results
print(f"Number of relevant results Cond. 2: {len(relevant_results2)}")

# Sort the relevant results from lowest voltage to highest
relevant_results2 = sorted(relevant_results2, key=lambda item: item.spike_v, reverse=True)

# Show the relevant results
print(relevant_results2)
# Out:
# Number of relevant results Cond. 2: 3840
# [{'spike_weight': 0.2, 'du': 0.05, 'dv': 0.15000000000000002, 'before v': 0.8029136971736911, 'spike v': 0.9962366610529294, 'after v': None}, {'spike_weight': 0.2, 'du': 0.15000000000000002, 'dv': 0.05, 'before v': 0.8029136971736911, 'spike v': 0.9962366610529293, 'after v': None}, {'spike_weight': 0.5, 'du': 0.6000000000000001, 'dv': 0.05, 'before v': 0.5170528629422362, 'spike v': 0.9912211913151243, 'after v': None}, {'spike_weight': 0.5, 'du': 0.05, 'dv': 0.6000000000000001, 'before v': 0.517052862942236, 'spike v': 0.9912211913151241, 'after v': None}, {'spike_weight': 0.45, 'du': 0.05, 'dv': 0.5, 'before v': 0.5683118110264598, 'spike v': 0.9901159470376368, 'after v': None}, {'spike_weight': 0.45, 'du': 0.5, 'dv': 0.05, 'before v': 0.5683118110264598, 'spike v': 0.9901159470376368, 'after v': None}, {'spike_weight': 0.4, 'du': 0.15000000000000002, 'dv': 0.2, 'before v': 0.6515511821569144, 'spike v': 0.9881782432013773, 'after v': None}, {'spike_weight': 0.4, 'du': 0.2, 'dv': 0.15000000000000002, 'before v': 0.6515511821569144, 'spike v': 0.9881782432013773, 'after v': None}, {'spike_weight': 0.35000000000000003, 'du': 0.35000000000000003, 'dv': 0.05, 'before v': 0.6533908606195261, 'spike v': 0.9737840916994529, 'after v': None}, {'spike_weight': 0.35000000000000003, 'du': 0.05, 'dv': 0.35000000000000003, 'before v': 0.653390860619526, 'spike v': 0.9737840916994528, 'after v': None}, {'spike_weight': 0.5, 'du': 0.1, 'dv': 0.4, 'before v': 0.5169710425500001, 'spike v': 0.9670879235750002, 'after v': None}, {'spike_weight': 0.5, 'du': 0.4, 'dv': 0.1, 'before v': 0.5169710425500001, 'spike v': 0.9670879235750001, 'after v': None}, {'spike_weight': 0.2, 'du': 0.1, 'dv': 0.1, 'before v': 0.7670925682200006, 'spike v': 0.9531454306160005, 'after v': None}, {'spike_weight': 0.25, 'du': 0.1, 'dv': 0.15000000000000002, 'before v': 0.7323367620019288, 'spike v': 0.9509388967241394, 'after v': None}, {'spike_weight': 0.25, 'du': 0.15000000000000002, 'dv': 0.1, 'before v': 0.7323367620019287, 'spike v': 0.9509388967241393, 'after v': None}, {'spike_weight': 0.5, 'du': 0.05, 'dv': 0.65, 'before v': 0.4739920311339353, 'spike v': 0.9502972570351071, 'after v': None}, {'spike_weight': 0.5, 'du': 0.65, 'dv': 0.05, 'before v': 0.4739920311339352, 'spike v': 0.9502972570351071, 'after v': None}, {'spike_weight': 0.45, 'du': 0.1, 'dv': 0.35000000000000003, 'before v': 0.5491076632487842, 'spike v': 0.9481347493522099, 'after v': None}, {'spike_weight': 0.45, 'du': 0.35000000000000003, 'dv': 0.1, 'before v': 0.5491076632487841, 'spike v': 0.9481347493522096, 'after v': None}, {'spike_weight': 0.45, 'du': 0.25, 'dv': 0.15000000000000002, 'before v': 0.562986484458794, 'spike v': 0.9475443230044218, 'after v': None}, {'spike_weight': 0.45, 'du': 0.15000000000000002, 'dv': 0.25, 'before v': 0.5629864844587938, 'spike v': 0.9475443230044217, 'after v': None}, {'spike_weight': 0.30000000000000004, 'du': 0.1, 'dv': 0.2, 'before v': 0.6837337505100004, 'spike v': 0.9411301792350004, 'after v': None}, {'spike_weight': 0.30000000000000004, 'du': 0.2, 'dv': 0.1, 'before v': 0.6837337505100003, 'spike v': 0.9411301792350003, 'after v': None}, {'spike_weight': 0.4, 'du': 0.05, 'dv': 0.45, 'before v': 0.5674069688848045, 'spike v': 0.9395938697972264, 'after v': None}, {'spike_weight': 0.4, 'du': 0.45, 'dv': 0.05, 'before v': 0.5674069688848045, 'spike v': 0.9395938697972264, 'after v': None}, {'spike_weight': 0.4, 'du': 0.1, 'dv': 0.30000000000000004, 'before v': 0.5880746573200002, 'spike v': 0.9371764985600002, 'after v': None}, {'spike_weight': 0.4, 'du': 0.30000000000000004, 'dv': 0.1, 'before v': 0.58807465732, 'spike v': 0.93717649856, 'after v': None}, {'spike_weight': 0.45, 'du': 0.55, 'dv': 0.05, 'before v': 0.511782178001704, 'spike v': 0.9362620216251738, 'after v': None}, {'spike_weight': 0.45, 'du': 0.05, 'dv': 0.55, 'before v': 0.5117821780017039, 'spike v': 0.9362620216251737, 'after v': None}, {'spike_weight': 0.35000000000000003,  ...

# %% [markdown]
# ### See if the intersection between both solutions is not empty

# %%
relevant_results = []

for rel_result in relevant_results1:
    if rel_result in relevant_results2:
        # Get the index of the relevant result
        index = relevant_results2.index(rel_result)
        delayed_result = relevant_results2[index]

        relevant_results.append({
            "spike_weight": rel_result.spike_weight, "du": rel_result.du, "dv": rel_result.dv, 
            "spike_v_on_time": rel_result.spike_v, "spike_v_delayed": delayed_result.spike_v,
            "later_v_on_time": rel_result.after_spike_v, "bef_v_delayed": delayed_result.bef_spike_v,
        })

        # print(f"Parameters: {rel_result}")
        # print(f"On Time Results: {rel_result.to_dict()}")
        # print(f"Voltage delayed: {relevant_results2[index].to_dict()}\n")

# Sort the relevant results by lowest voltage later_v_on_time
relevant_results = sorted(relevant_results, key=lambda item: item["later_v_on_time"], reverse=False)

for rel_result in relevant_results:
    print(rel_result)
# Out:
# {'spike_weight': 0.5, 'du': 0.1, 'dv': 0.4, 'spike_v_on_time': 1.01697104255, 'spike_v_delayed': 0.9670879235750002, 'later_v_on_time': 0.6992994628514534, 'bef_v_delayed': 0.5169710425500001}
# {'spike_weight': 0.5, 'du': 0.4, 'dv': 0.1, 'spike_v_on_time': 1.0169710425500003, 'spike_v_delayed': 0.9670879235750001, 'later_v_on_time': 0.6992994628514535, 'bef_v_delayed': 0.5169710425500001}
# {'spike_weight': 0.45, 'du': 0.15000000000000002, 'dv': 0.25, 'spike_v_on_time': 1.0129864844587937, 'spike_v_delayed': 0.9475443230044217, 'later_v_on_time': 0.7005388505631589, 'bef_v_delayed': 0.5629864844587938}
# {'spike_weight': 0.45, 'du': 0.25, 'dv': 0.15000000000000002, 'spike_v_on_time': 1.012986484458794, 'spike_v_delayed': 0.9475443230044218, 'later_v_on_time': 0.700538850563159, 'bef_v_delayed': 0.562986484458794}
# {'spike_weight': 0.5, 'du': 0.6000000000000001, 'dv': 0.05, 'spike_v_on_time': 1.0170528629422362, 'spike_v_delayed': 0.9912211913151243, 'later_v_on_time': 0.8266543373877522, 'bef_v_delayed': 0.5170528629422362}
# {'spike_weight': 0.5, 'du': 0.05, 'dv': 0.6000000000000001, 'spike_v_on_time': 1.017052862942236, 'spike_v_delayed': 0.9912211913151241, 'later_v_on_time': 0.8266543373877525, 'bef_v_delayed': 0.517052862942236}
# {'spike_weight': 0.4, 'du': 0.2, 'dv': 0.15000000000000002, 'spike_v_on_time': 1.0515511821569143, 'spike_v_delayed': 0.9881782432013773, 'later_v_on_time': 0.8413290172367734, 'bef_v_delayed': 0.6515511821569144}
# {'spike_weight': 0.4, 'du': 0.15000000000000002, 'dv': 0.2, 'spike_v_on_time': 1.0515511821569143, 'spike_v_delayed': 0.9881782432013773, 'later_v_on_time': 0.8413290172367738, 'bef_v_delayed': 0.6515511821569144}
# {'spike_weight': 0.45, 'du': 0.05, 'dv': 0.5, 'spike_v_on_time': 1.0183118110264597, 'spike_v_delayed': 0.9901159470376368, 'later_v_on_time': 0.9088729604774162, 'bef_v_delayed': 0.5683118110264598}
# {'spike_weight': 0.45, 'du': 0.5, 'dv': 0.05, 'spike_v_on_time': 1.0183118110264597, 'spike_v_delayed': 0.9901159470376368, 'later_v_on_time': 0.9088729604774163, 'bef_v_delayed': 0.5683118110264598}
# {'spike_weight': 0.35000000000000003, 'du': 0.35000000000000003, 'dv': 0.05, 'spike_v_on_time': 1.003390860619526, 'spike_v_delayed': 0.9737840916994529, 'later_v_on_time': 1.0505753134830675, 'bef_v_delayed': 0.6533908606195261}
# {'spike_weight': 0.35000000000000003, 'du': 0.05, 'dv': 0.35000000000000003, 'spike_v_on_time': 1.003390860619526, 'spike_v_delayed': 0.9737840916994528, 'later_v_on_time': 1.0505753134830678, 'bef_v_delayed': 0.653390860619526}
# {'spike_weight': 0.2, 'du': 0.05, 'dv': 0.15000000000000002, 'spike_v_on_time': 1.0029136971736912, 'spike_v_delayed': 0.9962366610529294, 'later_v_on_time': 1.4181457469062464, 'bef_v_delayed': 0.8029136971736911}
# {'spike_weight': 0.2, 'du': 0.15000000000000002, 'dv': 0.05, 'spike_v_on_time': 1.0029136971736912, 'spike_v_delayed': 0.9962366610529293, 'later_v_on_time': 1.4181457469062466, 'bef_v_delayed': 0.8029136971736911}

# %% [markdown]
# Looking at the results, we can see that the best parameters combination to detect the channel bursts with the above conditions are:
#
# (**Dense Layer Weight**, **du**, **dv**):
# - `(0.5, 0.1, 0.4)` or `(0.5, 0.4, 0.1)` or `(0.45, 0.15, 0.25)` or `(0.45, 0.25, 0.15)`
#
# Let's choose the parameters:
# - `spike_weight = 0.45`
# - `du = 0.25`
# - `dv = 0.15`
# as the optimal parameters and test it in a LAVA LIF Layer.
