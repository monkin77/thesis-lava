# %% [markdown]
# # SNN that detects High Frequency Oscillations (HFOs) with constant parameters
# In this notebook the `du` normal distribution is implemented correctly (w/o losing normality upon transformation)
#
# This notebook is a simple example of how to use a Spiking Neural Network (SNN) to detect HFOs
#
# ### What is an HFO?
# High Frequency Oscillations (HFOs) are a type of brain activity that occurs in the range of 80-500 Hz. They are believed to be related to the generation of seizures in patients with epilepsy. The detection of HFOs is an important task in the diagnosis and treatment of epilepsy.
#
# In terms of electrophysiology, HFOs are characterized by their high frequency and short duration, often lasting only a few milliseconds. The wave of a typical HFO consists of at least 4 UP and DOWN waves.

# %%
from lava.proc.lif.process import LIF
from lava.proc.dense.process import Dense
import numpy as np

LIF?
# Out:
# Init signature: LIF(*args, **kwargs)
# Docstring:
# Leaky-Integrate-and-Fire (LIF) neural Process.
#
# LIF dynamics abstracts to:
# u[t] = u[t-1] * (1-du) + a_in         # neuron current
# v[t] = v[t-1] * (1-dv) + u[t] + bias  # neuron voltage
# s_out = v[t] > vth                    # spike if threshold is exceeded
# v[t] = 0                              # reset at spike
#
# Parameters
# ----------
# shape : tuple(int)
#     Number and topology of LIF neurons.
# u : float, list, numpy.ndarray, optional
#     Initial value of the neurons' current.
# v : float, list, numpy.ndarray, optional
#     Initial value of the neurons' voltage (membrane potential).
# du : float, optional
#     Inverse of decay time-constant for current decay. Currently, only a
#     single decay can be set for the entire population of neurons.
# dv : float, optional
#     Inverse of decay time-constant for voltage decay. Currently, only a
#     single decay can be set for the entire population of neurons.
# bias_mant : float, list, numpy.ndarray, optional
#     Mantissa part of neuron bias.
# bias_exp : float, list, numpy.ndarray, optional
#     Exponent part of neuron bias, if needed. Mostly for fixed point
#     implementations. Ignored for floating point implementations.
# vth : float, optional
#     Neuron threshold voltage, exceeding which, the neuron will spike.
#     Currently, only a single threshold can be set for the entire
#     population of neurons.
#
# Example
# -------
# >>> lif = LIF(shape=(200, 15), du=10, dv=5)
# This will create 200x15 LIF neurons that all have the same current decay
# of 10 and voltage decay of 5.
# Init docstring: Initializes a new Process.
# File:           ~/Desktop/feup/thesis/thesis-lava/src/lava/proc/lif/process.py
# Type:           ProcessPostInitCaller
# Subclasses:     LIFReset, LIFRefractory

# %% [markdown]
# ### Check WD (change if necessary) and file loading

# %%
# Show current directory
import os
curr_dir = os.getcwd()
print(curr_dir)

# Check if the current WD is the file location
if "/src/hfo/snn" not in os.getcwd():
    # Set working directory to this file location
    file_location = f"{os.getcwd()}/thesis-lava/src/hfo/snn"
    print("File Location: ", file_location)

    # Change the current working Directory
    os.chdir(file_location)

    # New Working Directory
    print("New Working Directory: ", os.getcwd())
# Out:
# /home/monkin/Desktop/feup/thesis/thesis-lava/src/hfo/snn

# %% [markdown]
# ## Create the Custom Input Layer
#
# ### Define function to read the input data from the csv file and generate the corresponding spike events

# %%
import pandas as pd

def read_spike_events(file_path: str):
    """Reads the spike events from the input file and returns them as a numpy array

    Args:
        file_path (str): name of the file containing the spike events
    """
    spike_events = []

    try:
        # Read the spike events from the file
        df = pd.read_csv(file_path, header=None)

        # Detect errors
        if df.empty:
            raise Exception("The input file is empty")

        # Convert the scientific notation values to integers if any exist
        df = df.applymap(lambda x: int(float(x)) if (isinstance(x, str) and 'e' in x) else x)

        # Convert the dataframe to a numpy array
        spike_events = df.to_numpy()
        return spike_events[0]
    except Exception as e:
        print("Unable to read the input file: ", file_path, " error:", e)

    return spike_events

# %% [markdown]
# ## Configurable Parameters

# %%
from utils.input import BaselineAlgorithm, MarkerType, ModelDistStrategy, band_to_confidence_window, X_STEP, INPUT_DURATION
from math import floor

# Declare if using ripples, fast ripples, or both
chosen_band = MarkerType.RIPPLE     # RIPPLE, FAST_RIPPLE, or BOTH

# Specify the chosen Baseline Algorithm
chosen_baseline_alg_suffix = BaselineAlgorithm.Q3

# Select the Distribution Model Strategy
selected_strategy = ModelDistStrategy.MEAN_AND_STD

# Define the Weight Scale of the Dense Layer #TODO: Test changing this
weights_scale_input = 0.2   # 0.5
weights_scale_std = 0.1

# Define the IQR ranges for the specific data being fed (synaptic time constants)
ripple_IQR = [0.48, 6.5]
fr_IQR = [0.49, 2.93] # Inter-Quartile Range for the time constants of the Fast-Ripple neurons
hfo_IQR = [0.9766, 6.8359]

# Define the mean and std. deviation of the synaptic time constants
scale_std_dev = 1
synaptic_tc_mean = 4.6584
synaptic_tc_std_dev = 4.6663 * scale_std_dev

# Define the mean and std. deviation of the Membrane Potential Time Constants
mean_dv = 15    # Mean voltage time constant = 15ms (following Indiveri's paper)
std_dev_dv = 10  # Standard deviation of the voltage time constant. If 0, then the time constant is fixed 

# Range of random values to subtract from the excitatory time constants to get the inhibitory time constants (in milliseconds)
inh_scale_range = [1.021467, 1.21467] # [0.01, 0.5] # [0.1, 1.0]     # TODO: Test different ranges? 

# Simulation Time Parameters
num_steps = INPUT_DURATION    # Number of steps to run the simulation   # TODO: CAREFUL WITH THIS DURATION (INPUT_DURATION IS THE DURATION OF THE SYNTHETIC DATA)
init_offset = 0 # 900 # 33400      #   
virtual_time_step_interval = 1  # TODO: Check if this should be the time-step value. it is not aligned with the sampling rate of the input data
# TODO: Could try to use the virtual_time_step_interval aligned with the sampling rate of the input data

# Constants for the Refractory LIF Process
confidence_window = band_to_confidence_window(chosen_band)
# We know that 2 relevant events do not occur within the confidence window of a ripple event, so we set the refractory period accordingly
refrac_period = floor(confidence_window / virtual_time_step_interval)   # Number of time-steps for the refractory period
print("Refractory Period: ", refrac_period)

# (OPTIONAL) Scale down the simulation time
time_downscale = 1  # 4 # None  # 
if time_downscale is not None:
    num_steps = num_steps // time_downscale
# Out:
# Refractory Period:  180

# %% [markdown]
# ### Load the UP and DOWN spikes from the CSV Files

# %%
# Define the name of the dataset version being used
DATASET_FILENAME =  "seeg_filtered_subset_90-119_segment500_200"    # "filtered_seeg_csl_ch30-59_ch18"     # "filtered_seeg_ch90-119_ch0"

# %% [markdown]
# #### Load the Baseline Thresholds from the output file from the baseline process

# %%
# Load the Baseline Thresholds
BASELINE_FILENAME = "seeg_filtered_subset_90-119_segment500_200"
BASELINE_FILE = f"../signal_to_spike/baseline_results/{BASELINE_FILENAME}_thresholds_{chosen_baseline_alg_suffix}.npy"
baseline_thresholds = np.load(BASELINE_FILE)

# preview_np_array(baseline_thresholds, "baseline_thresholds", edge_items=3)

baseline_ripple_thresh = round(baseline_thresholds[0], 4)
baseline_fr_thresh = round(baseline_thresholds[1], 4)
baseline_hfo_thresh = round(baseline_thresholds[2], 4)

# For now, the UP and DN thresholds are the same (symmetric)
ripple_thresh_up = baseline_ripple_thresh
ripple_thresh_down = -baseline_ripple_thresh
fr_thresh_up = baseline_fr_thresh
fr_thresh_down = -baseline_fr_thresh
hfo_thresh_up = baseline_hfo_thresh
hfo_thresh_down = -baseline_hfo_thresh

print("Ripple Thresholds: ", ripple_thresh_up, ripple_thresh_down)
print("FR Thresholds: ", fr_thresh_up, fr_thresh_down)
print("HFO Thresholds: ", hfo_thresh_up, hfo_thresh_down)
# Out:
# Ripple Thresholds:  5.6556 -5.6556
# FR Thresholds:  1.6041 -1.6041
# HFO Thresholds:  5.152 -5.152

# %%
def band_to_thresholds(band: MarkerType):
    """Returns the ripple and FR thresholds for the given band

    Args:
        band (MarkerType): the band for which the thresholds are required
    """
    if band == MarkerType.RIPPLE:
        return ripple_thresh_up, ripple_thresh_down
    elif band == MarkerType.FAST_RIPPLE:
        return fr_thresh_up, fr_thresh_down
    elif band == MarkerType.BOTH:
        return hfo_thresh_up, hfo_thresh_down
    else:
        raise Exception("Invalid band type")

# %%
from utils.input import read_spike_events, band_to_file_name
from utils.io import preview_np_array

# Define the path of the files containing the spike events
INPUT_PATH = f"../signal_to_spike/results/{DATASET_FILENAME}"
band_file_name = band_to_file_name(chosen_band)

# Define the chosen thresholds
thresh_up, thresh_down = band_to_thresholds(chosen_band)
print("Thresholds: ", thresh_up, thresh_down)

# Call the function to read the spike events
up_spikes_file_path = f"{INPUT_PATH}/{band_file_name}_up_spike_train_{thresh_up}.csv"
up_spike_train = read_spike_events(up_spikes_file_path)

down_spikes_file_path = f"{INPUT_PATH}/{band_file_name}_down_spike_train_{thresh_down}.csv"
down_spike_train = read_spike_events(down_spikes_file_path)

preview_np_array(up_spike_train, "up_spike_train")
preview_np_array(down_spike_train, "down_spike_train")
# Out:
# Thresholds:  5.6556 -5.6556
# up_spike_train Shape: (2581, 2).
# Preview: [[ 1.00439453e+03 -1.00000000e+00]
#  [ 1.00878906e+03 -1.00000000e+00]
#  [ 1.00976562e+03 -1.00000000e+00]
#  [ 1.01074219e+03 -1.00000000e+00]
#  [ 1.01513672e+03 -1.00000000e+00]
#  ...
#  [ 1.19031250e+05 -1.00000000e+00]
#  [ 1.19032227e+05 -1.00000000e+00]
#  [ 1.19033691e+05 -1.00000000e+00]
#  [ 1.19042969e+05 -1.00000000e+00]
#  [ 1.19044434e+05 -1.00000000e+00]]
# down_spike_train Shape: (2574, 2).
# Preview: [[ 1.00585938e+03 -1.00000000e+00]
#  [ 1.00683594e+03 -1.00000000e+00]
#  [ 1.01220703e+03 -1.00000000e+00]
#  [ 1.01269531e+03 -1.00000000e+00]
#  [ 1.01318359e+03 -1.00000000e+00]
#  ...
#  [ 1.19027832e+05 -1.00000000e+00]
#  [ 1.19036621e+05 -1.00000000e+00]
#  [ 1.19038086e+05 -1.00000000e+00]
#  [ 1.19040039e+05 -1.00000000e+00]
#  [ 1.19048828e+05 -1.00000000e+00]]

# %% [markdown]
# ### Define the SpikeEvent Generator Interface

# %%
from lava.magma.core.process.process import AbstractProcess
from lava.magma.core.process.variable import Var
from lava.magma.core.process.ports.ports import OutPort

class SpikeEventGen(AbstractProcess):
    """Input Process that generates spike events based on the input file

    Args:
        @out_shape (tuple): Shape of the output port
        @exc_spike_events (np.ndarray): Excitatory spike events
        @inh_spike_event (np.ndarray): Inhibitory spike events
        @name (str): Name of the process
    """
    def __init__(self, out_shape: tuple, exc_spike_events: np.ndarray, inh_spike_event: np.ndarray, name: str) -> None:
        super().__init__(name=name)
        self.s_out = OutPort(shape=out_shape)
        self.exc_spike_events = Var(shape=exc_spike_events.shape, init=exc_spike_events)
        self.inh_spike_events = Var(shape=inh_spike_event.shape, init=inh_spike_event)

# %% [markdown]
# ## Define the Architecture of the Network

# %%
# Define the number of neurons in the Input Spike Event Generator
n_spike_gen = 2  # 2 neurons in the input spike event generator

# Define the number of neurons in each LIF Layer
# TODO: Test with 512 neurons?
n_lif1 = 256    # 512   # 256 neurons in the first LIF layer 
# n2 = 1  # 1 neuron in the second layer

# %% [markdown]
# ### Choose the LIF Models to use

# %%
use_refractory = True

# %% [markdown]
# ### Define the LIF parameters

# %%
# Constants for the LIF Process
v_th = 1
v_init = 0

# %% [markdown]
# ### Create a `ConfigTimeConstantsLIF` object

# %% [markdown]
# #### Define the time constants for the `ConfigTimeConstantsLIF` neurons
# The synapse time constants, corresponding to `du_exc` and `du_inh` will be different for each neuron in the LIF layer. Likewise, the excitatory and inhibitory time constants will also differ for each neuron in order to capture the dynamics of the HFOs.

# %%
from utils.neuron_dynamics import time_constant_to_fraction
# Create the np arrays for the time constants of each neuron

# Select the chosen IQR based on the chosen band
chosen_IQR = ripple_IQR
if chosen_band == MarkerType.FAST_RIPPLE:
    chosen_IQR = fr_IQR
elif chosen_band == MarkerType.BOTH:
    chosen_IQR = hfo_IQR
elif chosen_band != MarkerType.RIPPLE:
    raise Exception("What to do in this case?")


if selected_strategy == ModelDistStrategy.IQR:
    # Convert the IQR to time constant fractions
    chosen_IQR_du = [time_constant_to_fraction(chosen_IQR[0]), time_constant_to_fraction(chosen_IQR[1])]
    chosen_mu = np.mean(chosen_IQR_du)  # Midpoint of the IQR
    # Calculate the standard deviation of the normal distribution
    # For a normal distribution, the first quartile is ~0.675 standard deviations below the mean
    chosen_std_dev = (chosen_IQR_du[1] - chosen_IQR_du[0]) / (2 * 0.675)  # standard deviation is the IQR divided by 2*0.675
elif selected_strategy == ModelDistStrategy.MEAN_AND_STD:
    # Use the actual values from the STS_ANALYSIS
    chosen_mu = time_constant_to_fraction(synaptic_tc_mean)
    chosen_std_dev = time_constant_to_fraction(synaptic_tc_std_dev)
elif selected_strategy == ModelDistStrategy.LOG_NORMAL:
    raise Exception("Not implemented yet")
    # Convert the mean and std. deviation to the log-normal distribution
    synaptic_tc_mean_du = time_constant_to_fraction(synaptic_tc_mean)
    synaptic_tc_std_dev_du = time_constant_to_fraction(synaptic_tc_std_dev)
    print("Synaptic TC Mean (DU): ", synaptic_tc_mean_du)
    print("Synaptic TC Std. Dev (DU): ", synaptic_tc_std_dev_du)

    chosen_mu = np.log( synaptic_tc_mean_du**2 / np.sqrt(synaptic_tc_std_dev_du**2 + synaptic_tc_mean_du**2) )
    chosen_std_dev = np.sqrt( np.log( 1 + (synaptic_tc_std_dev_du**2 / synaptic_tc_mean_du**2) ) )

print("Chosen mu: ", chosen_mu)
print("Chosen std_dev: ", chosen_std_dev)
# print("Chosen IQR: ", chosen_IQR)
# Out:
# Chosen mu:  0.19318911363978286
# Chosen std_dev:  0.19289584317537622

# %%
# Generate the time constants for the Fast-Ripple neurons
exc_syn_time_constants = np.random.normal(chosen_mu, chosen_std_dev, n_lif1)

# Generate Log Normal Distribution if selected
# if selected_strategy == ModelDistStrategy.LOG_NORMAL:
#     exc_syn_time_constants = np.random.lognormal(mean_du_exc, std_dev_du_exc, n_lif1)

# preview_np_array(exc_syn_time_constants, "exc_syn_time_constants", edge_items=10)
print("Min and max time constants before:", np.min(exc_syn_time_constants), np.max(exc_syn_time_constants))

# Cannot have negative time constants. Make them 0 or positive?
# exc_syn_time_constants = np.clip(exc_syn_time_constants, a_min=0, a_max=None)
exc_syn_time_constants = np.abs(exc_syn_time_constants)
# TODO: Could add the mean to the negative values? 
print("[Excitatory] Min and max time constants after abs:", np.min(exc_syn_time_constants), np.max(exc_syn_time_constants))
print(f"[Excitatory] Mean time constants after: {np.mean(exc_syn_time_constants)} ± {np.std(exc_syn_time_constants)}")
# Out:
# Min and max time constants before: -0.3651509277776165 0.7493525530354627
# [Excitatory] Min and max time constants after abs: 0.00013866936243722705 0.7493525530354627
# [Excitatory] Mean time constants after: 0.21370766913561137 ± 0.15241380257170054

# %% [markdown]
# ### The inhibitory time constants will be calculated from the excitatory time constants by scaling down by a factor

# %%
# Generate the inhibitory time constants by scaling down by a random value in a range from the excitatory time constants

# Generate the random values to subtract from the excitatory time constants
inh_syn_offset = np.random.uniform(inh_scale_range[1], inh_scale_range[0], n_lif1)
preview_np_array(inh_syn_offset, "inh_syn_offset", edge_items=10)

# Subtract the random values from the excitatory time constants to get the inhibitory time constants
inh_syn_time_constants = exc_syn_time_constants * inh_syn_offset

print("Min and max time constants before:", np.min(inh_syn_time_constants), np.max(inh_syn_time_constants))
# Clip the inhibitory time constants to be positive or equal to the minimum found excitatory time 
inh_syn_time_constants = np.clip(inh_syn_time_constants, a_min=np.min(exc_syn_time_constants), a_max=1.0)
print("[Inhibitory] Min and max time constants after:", np.min(inh_syn_time_constants), np.max(inh_syn_time_constants))
print(f"[Inhibitory] Mean time constants after: {np.mean(inh_syn_time_constants)} ± {np.std(inh_syn_time_constants)}")

print(f"Mean Difference between E/I time constants: {np.mean(inh_syn_time_constants - exc_syn_time_constants)}")
# Out:
# inh_syn_offset Shape: (256,).
# Preview: [1.03336559 1.09536124 1.1328266  1.02254088 1.09854754 1.14052948
#  1.04831999 1.07128942 1.17536092 1.02249799 ... 1.19982397 1.20955241
#  1.14336997 1.2065185  1.14126464 1.07704892 1.1842507  1.2055333
#  1.205392   1.02648378]
# Min and max time constants before: 0.00015752544925515537 0.8803076952471787
# [Inhibitory] Min and max time constants after: 0.00015752544925515537 0.8803076952471787
# [Inhibitory] Mean time constants after: 0.23971022245694673 ± 0.169995142677434
# Mean Difference between E/I time constants: 0.02600255332133531

# %% [markdown]
# #### Define the Membrane Potential Time Constants for the LIF Neurons
# To add more variability to the network, the membrane potential time constants will be randomly generated from a normal distribution around a mean value.

# %%
dv_time_constants = np.random.normal(mean_dv, std_dev_dv, n_lif1)

preview_np_array(dv_time_constants, "dv_time_constants", edge_items=5)

# Guarantee that the time constants are positive
dv_time_constants = np.abs(dv_time_constants)
print("[ms] Min and max Voltage time constants:", np.min(dv_time_constants), np.max(dv_time_constants))

# Transform the time constants to fractions
dv_time_constants_frac = time_constant_to_fraction(dv_time_constants)
print("[Frac] Min and max Voltage time constants:", np.min(dv_time_constants_frac), np.max(dv_time_constants_frac))
# Out:
# dv_time_constants Shape: (256,).
# Preview: [25.59754067 10.83940179 16.23351915 28.56391331 -3.4626743  ...
#  24.10369612  8.13727408 11.75073406 13.41971573 17.79222726]
# [ms] Min and max Voltage time constants: 0.11117739132383875 39.8739361316464
# [Frac] Min and max Voltage time constants: 0.024767172461833686 0.9998759262614535

# %%
from lava.proc.lif.process import ConfigTimeConstantsLIF, ConfigTimeConstantsRefractoryLIF
""" 
configLIF = ConfigTimeConstantsLIF(shape=(n_lif1,),  # There are 256 neurons
            vth=v_th,  # TODO: Verify these initial values
            v=v_init,
            dv=dv_time_constants_frac,    # Inverse of decay time-constant for voltage decay
            du_exc=exc_syn_time_constants_frac,  # Inverse of decay time-constant for excitatory current decay
            du_inh=inh_syn_time_constants_frac,  # Inverse of decay time-constant for inhibitory current decay
            bias_mant=0,
            bias_exp=0,
            name="lif1")

configLIF.du_exc """
# Out:
# ' \nconfigLIF = ConfigTimeConstantsLIF(shape=(n_lif1,),  # There are 256 neurons\n            vth=v_th,  # TODO: Verify these initial values\n            v=v_init,\n            dv=dv_time_constants_frac,    # Inverse of decay time-constant for voltage decay\n            du_exc=exc_syn_time_constants_frac,  # Inverse of decay time-constant for excitatory current decay\n            du_inh=inh_syn_time_constants_frac,  # Inverse of decay time-constant for inhibitory current decay\n            bias_mant=0,\n            bias_exp=0,\n            name="lif1")\n\nconfigLIF.du_exc '

# %%
# Config Time Constants Refractory LIF
configRefracLIF = ConfigTimeConstantsRefractoryLIF(shape=(n_lif1,),  # There are 256 neurons
            vth=v_th,  # TODO: Verify these initial values
            v=v_init,
            dv=dv_time_constants_frac,    # Inverse of decay time-constant for voltage decay
            du_exc=exc_syn_time_constants,  # Inverse of decay time-constant for excitatory current decay
            du_inh=inh_syn_time_constants,  # Inverse of decay time-constant for inhibitory current decay
            bias_mant=0,
            bias_exp=0,
            refractory_period=refrac_period,
            name="lif1")

# %%
selectedLIF = configRefracLIF # configRefracLIF

# %% [markdown]
# ### Create the Dense Layers

# %%
# Create Dense Process to connect the input layer and LIF1
# create weights of the dense layer
# dense_weights_input = np.eye(N=n1, M=n1)
# Fully Connected Layer from n_spike_gen neurons to n_lif1 neurons
dense_weights_input = np.ones(shape=(n_lif1, n_spike_gen))

# Make the weights (synapses) connecting the odd-parity neurons of the input layer to the network negative (inhibitory)
dense_weights_input[:, 1::2] *= -1

# Create a Distribution of the weights_scale to multiply the weights of the Dense Layer
weights_scale_dist = np.random.normal(weights_scale_input, weights_scale_std, n_lif1)

# Multiply the weights of the Dense layer by the Distribution
dense_weights_input[:, 0] *= weights_scale_dist
dense_weights_input[:, 1] *= weights_scale_dist

# multiply the weights of the Dense layer by a constant
# dense_weights_input *= weights_scale_input

dense_input = Dense(weights=np.array(dense_weights_input), name="DenseInput")

# %% [markdown]
# #### Look at the weights of the Dense Layers

# %%
# Weights of the Input Dense Layer
dense_input.weights.get()
# Out:
# array([[ 0.28083668, -0.28083668],
#        [ 0.29066589, -0.29066589],
#        [ 0.0352006 , -0.0352006 ],
#        [ 0.2137785 , -0.2137785 ],
#        [ 0.21426404, -0.21426404],
#        ...,
#        [ 0.14893234, -0.14893234],
#        [ 0.14295731, -0.14295731],
#        [ 0.21948983, -0.21948983],
#        [ 0.27309494, -0.27309494],
#        [ 0.15896673, -0.15896673]])

# %% [markdown]
# ### Map the input channels to the corresponding indexes in the input layer
# Since the input channels in the input file may be of any number, we need to **map the input channels to the corresponding indexes in the input layer**. This is done by the `channel_map` dictionaries.
#
# The network expects an UP and DOWN spike train for each channel. Thusly, let's define 2 dictionaries, one for the UP spikes and one for the DOWN spikes. We want the UP and DOWN spike trains to be followed by each other in the input layer for each channel.

# %%
# Map the channels of the input file to the respective index in the output list of SpikeEventGen

# Define the mapping of the channels of the UP spike train to the respective index in the output list of SpikeEventGen
up_channel_map = {-1: 0}
# Define the mapping of the channels of the DOWN spike train to the respective index in the output list of SpikeEventGen
down_channel_map = {-1: 1}

# %% [markdown]
# ### Update the UP and DOWN spike trains to include only the spikes that occur within the simulation time

# %%
# Iterate the UP spike train to find the spikes that occur within the time interval
up_train_start = -1
up_train_end = up_spike_train.shape[0]
for i, (spike_time, _) in enumerate(up_spike_train):
    if up_train_start == -1 and spike_time >= init_offset:
        up_train_start = i
    
    if spike_time > init_offset + num_steps:
        up_train_end = i
        break

# Slice the spike train to the time interval
up_spike_train_interval = []
if up_train_start != -1:
    # If there are spikes in the interval
    up_spike_train_interval = up_spike_train[up_train_start:up_train_end]
    
preview_np_array(up_spike_train_interval, "Spike Events")
# Out:
# Spike Events Shape: (2581, 2).
# Preview: [[ 1.00439453e+03 -1.00000000e+00]
#  [ 1.00878906e+03 -1.00000000e+00]
#  [ 1.00976562e+03 -1.00000000e+00]
#  [ 1.01074219e+03 -1.00000000e+00]
#  [ 1.01513672e+03 -1.00000000e+00]
#  ...
#  [ 1.19031250e+05 -1.00000000e+00]
#  [ 1.19032227e+05 -1.00000000e+00]
#  [ 1.19033691e+05 -1.00000000e+00]
#  [ 1.19042969e+05 -1.00000000e+00]
#  [ 1.19044434e+05 -1.00000000e+00]]

# %%
# Iterate the UP spike train to find the spikes that occur within the time interval
down_train_start = -1
down_train_end = down_spike_train.shape[0]
for i, (spike_time, _) in enumerate(down_spike_train):
    if down_train_start == -1 and spike_time >= init_offset:
        down_train_start = i
    
    if spike_time > init_offset + num_steps:
        down_train_end = i
        break

# Slice the spike train to the time interval
down_spike_train_interval = []
if down_train_start != -1:
    # If there are spikes in the interval
    down_spike_train_interval = down_spike_train[down_train_start:down_train_end]
    
preview_np_array(down_spike_train_interval, "Spike Events")
# Out:
# Spike Events Shape: (2574, 2).
# Preview: [[ 1.00585938e+03 -1.00000000e+00]
#  [ 1.00683594e+03 -1.00000000e+00]
#  [ 1.01220703e+03 -1.00000000e+00]
#  [ 1.01269531e+03 -1.00000000e+00]
#  [ 1.01318359e+03 -1.00000000e+00]
#  ...
#  [ 1.19027832e+05 -1.00000000e+00]
#  [ 1.19036621e+05 -1.00000000e+00]
#  [ 1.19038086e+05 -1.00000000e+00]
#  [ 1.19040039e+05 -1.00000000e+00]
#  [ 1.19048828e+05 -1.00000000e+00]]

# %% [markdown]
# ## Implement the `SpikeEventGenerator` Model

# %%
from lava.magma.core.model.py.model import PyLoihiProcessModel  # Processes running on CPU inherit from this class
from lava.magma.core.resources import CPU
from lava.magma.core.decorator import implements, requires
from lava.magma.core.sync.protocols.loihi_protocol import LoihiProtocol
from lava.magma.core.model.py.type import LavaPyType
from lava.magma.core.model.py.ports import PyOutPort

@implements(proc=SpikeEventGen, protocol=LoihiProtocol)
@requires(CPU)
class PySpikeEventGenModel(PyLoihiProcessModel):
    """Spike Event Generator Process implementation running on CPU (Python)
    Args:
    """
    s_out: PyOutPort = LavaPyType(PyOutPort.VEC_DENSE, float)   # IT IS POSSIBLE TO SEND FLOATS AFTER ALL
    exc_spike_events: np.ndarray = LavaPyType(np.ndarray, np.ndarray)
    inh_spike_events: np.ndarray = LavaPyType(np.ndarray, np.ndarray)

    def __init__(self, proc_params) -> None:
        super().__init__(proc_params=proc_params)
        # print("spike events", self.spike_events.__str__())    # TODO: Check why during initialization the variable prints the class, while during run it prints the value
        
        self.curr_exc_idx = 0     # Index of the next excitatory spiking event to send
        self.curr_inh_idx = 0     # Index of the next inhibitory spiking event to send
        self.virtual_time_step_interval = virtual_time_step_interval  # 1000    # Arbitrary time between time steps (in microseconds). This is not a real time interval (1000ms = 1s)
        self.init_offset = init_offset        # 698995               # Arbitrary offset to start the simulation (in microseconds)
        
        # Try to increment the curr_exc_idx and curr_inh_idx to the first spike event that is greater than the init_offset here?

    def run_spk(self) -> None:
        spike_data = np.zeros(self.s_out.shape) # Initialize the spike data to 0
        
        #print("time step:", self.time_step)

        # If the current simulation time is greater than a spike event, send a spike in the corresponding channel
        currTime = self.init_offset + self.time_step*self.virtual_time_step_interval

        spiking_channels = set()   # List of channels that will spike in the current time step

        # Add the excitatory spike events to the spike_date
        while (self.curr_exc_idx < len(self.exc_spike_events)) and currTime >= self.exc_spike_events[self.curr_exc_idx][0]:
            # Get the channel of the current spike event
            curr_channel = self.exc_spike_events[self.curr_exc_idx][1]

            # Check if the channel is valid (belongs to a channel in the up_channel_map therefore it has an output index)
            if curr_channel not in up_channel_map:
                self.curr_exc_idx += 1
                continue    # Skip the current spike event

            # Check if the next spike belongs to a channel that will already spike in this time step
            # If so, we don't add the event and stop looking for more events
            if curr_channel in spiking_channels:
                break

            # Add the channel to the list of spiking channels
            spiking_channels.add(curr_channel)

            # Get the output index of the current channel according to the up_channel_map
            out_idx = up_channel_map[curr_channel]
            if out_idx < self.s_out.shape[0]:   # Check if the channel is valid
                # Update the spike_data with the excitatory spike event (value = 1.0)
                spike_data[out_idx] = 1.0   # Send spike (value corresponds to the punctual current of the spike event)

            # Move to the next spike event
            self.curr_exc_idx += 1

        # Add the inhibitory spike events to the spike_date
        while (self.curr_inh_idx < len(self.inh_spike_events)) and currTime >= self.inh_spike_events[self.curr_inh_idx][0]:
            # Get the channel of the current spike event
            curr_channel = self.inh_spike_events[self.curr_inh_idx][1]

            # Check if the channel is valid (belongs to a channel in the down_channel_map therefore it has an output index)
            if curr_channel not in down_channel_map:
                self.curr_inh_idx += 1
                continue    # Skip the current spike event

            # Check if the next spike belongs to a channel that will already spike in this time step
            # If so, we don't add the event and stop looking for more events
            if curr_channel in spiking_channels:
                break

            # Add the channel to the list of spiking channels
            spiking_channels.add(curr_channel)

            # Get the output index of the current channel according to the down_channel_map
            out_idx = down_channel_map[curr_channel]
            if out_idx < self.s_out.shape[0]:   # Check if the channel is valid
                # It is not possible to send negative values or floats in the spike_data. The weight of the synapse should do the inhibition
                spike_data[out_idx] = 1.0   # Send spike (value corresponds to the punctual current of the spike event)

            # Move to the next spike event
            self.curr_inh_idx += 1


        if len(spiking_channels) > 0:   # Print the spike event if there are any spikes
            VERBOSE = False
            if VERBOSE:
                print(f"""Sending spike event at time: {currTime}({self.time_step}). Last (E/I) spike idx: {self.curr_exc_idx-1}/{self.curr_inh_idx-1}
                        Spike times: {self.exc_spike_events[self.curr_exc_idx-1][0] if self.curr_exc_idx > 0 else "?"}/\
                        {self.inh_spike_events[self.curr_inh_idx-1][0] if self.curr_inh_idx > 0 else "?"}
                        Spike_data: {spike_data}\n"""
                )
            #else:
            #     print(f"Sending spike event at time: {currTime}({self.time_step}).")

        # Send spikes if self.curr_exc_idx > 0 else "?"
        # print("sending spike_data: ", spike_data, " at step: ", self.time_step)
        self.s_out.send(spike_data)

        # Stop the Process if there are no more spike events to send. (It will stop all the connected processes)
        # TODO: Should it be another process that stops the simulation? Such as the last LIF process
        # if self.curr_spike_idx >= 5: # len(self.spike_events):
        #    self.pause()

        # Print a progress message every 1000 time steps
        if self.time_step % 1000 == 0:
            # Clear the console
            print(f"Time step: {self.time_step}")

# %% [markdown]
# ## Connect the Layers
# To define the connectivity between the `SpikeGenerator` and the first `LIF` population, we use another `Dense` Layer.

# %%
# Create the Input Process
spike_event_gen = SpikeEventGen(out_shape=(n_spike_gen,),
                                exc_spike_events=up_spike_train_interval,
                                inh_spike_event=down_spike_train_interval,
                                name="SpikeEventsGenerator")

# If I connect the SpikeEventGen to the Dense Layer, the a_out value of the custom input will be rounded to 0 or 1 in the Dense Layer (it will not be a float) 
# However, setting the Dense weights to a float works instead
# Connect the SpikeEventGen to the Dense Layer
spike_event_gen.s_out.connect(dense_input.s_in)

# Connect the Dense_Input to the LIF1 Layer
dense_input.a_out.connect(selectedLIF.a_in)

# %% [markdown]
# ### Take a look at the connections in the Input Layer

# %%
for proc in [spike_event_gen, dense_input, selectedLIF]:
    for port in proc.in_ports:
        print(f"Proc: {proc.name:<5} Port Name: {port.name:<5} Size: {port.size}")
    for port in proc.out_ports:
        print(f"Proc: {proc.name:<5} Port Name: {port.name:<5} Size: {port.size}")
# Out:
# Proc: SpikeEventsGenerator Port Name: s_out Size: 2
# Proc: DenseInput Port Name: s_in  Size: 2
# Proc: DenseInput Port Name: a_out Size: 256
# Proc: lif1  Port Name: a_in  Size: 256
# Proc: lif1  Port Name: s_out Size: 256

# %% [markdown]
# ### Record Internal Vars over time
# To record the evolution of the internal variables over time, we need a `Monitor`. For this example, we want to record the membrane potential of the `LIF` Layer, hence we need 1 `Monitors`.
#
# We can define the `Var` that a `Monitor` should record, as well as the recording duration, using the `probe` function

# %%
from lava.proc.monitor.process import Monitor

monitor_lif1_v = Monitor()
monitor_lif1_u = Monitor()

# Connect the monitors to the variables we want to monitor
monitor_lif1_v.probe(selectedLIF.v, num_steps)
monitor_lif1_u.probe(selectedLIF.u, num_steps)  # Monitoring the net_current (u_exc + u_inh) of the LIF1 Process

# %% [markdown]
# ## Execution
# Now that we have defined the network, we can execute it. We will use the `run` function to execute the network.

# %% [markdown]
# ### Run Configuration and Conditions

# %%
from lava.magma.core.run_conditions import RunContinuous, RunSteps
from lava.magma.core.run_configs import Loihi1SimCfg

# run_condition = RunContinuous()   # TODO: Change to this one
run_condition = RunSteps(num_steps=num_steps)
run_cfg = Loihi1SimCfg(select_tag="floating_pt")   # TODO: Check why we need this select_tag="floating_pt"

# %% [markdown]
# ### Execute

# %%
selectedLIF.run(condition=run_condition, run_cfg=run_cfg)
# Out:
# Time step: 1000
# Time step: 2000
# Time step: 3000
# Time step: 4000
# Time step: 5000
# Time step: 6000
# Time step: 7000
# Time step: 8000
# Time step: 9000
# Time step: 10000
# Time step: 11000
# Time step: 12000
# Time step: 13000
# Time step: 14000
# Time step: 15000
# Time step: 16000
# Time step: 17000
# Time step: 18000
# Time step: 19000
# Time step: 20000
# Time step: 21000
# Time step: 22000
# Time step: 23000
# Time step: 24000
# Time step: 25000
# Time step: 26000
# Time step: 27000
# Time step: 28000
# Time step: 29000
# Time step: 30000
# Time step: 31000
# Time step: 32000
# Time step: 33000
# Time step: 34000
# Time step: 35000
# Time step: 36000
# Time step: 37000
# Time step: 38000
# Time step: 39000
# Time step: 40000
# Time step: 41000
# Time step: 42000
# Time step: 43000
# Time step: 44000
# Time step: 45000
# Time step: 46000
# Time step: 47000
# Time step: 48000
# Time step: 49000
# Time step: 50000
# Time step: 51000
# Time step: 52000
# Time step: 53000
# Time step: 54000
# Time step: 55000
# Time step: 56000
# Time step: 57000
# Time step: 58000
# Time step: 59000
# Time step: 60000
# Time step: 61000
# Time step: 62000
# Time step: 63000
# Time step: 64000
# Time step: 65000
# Time step: 66000
# Time step: 67000
# Time step: 68000
# Time step: 69000
# Time step: 70000
# Time step: 71000
# Time step: 72000
# Time step: 73000
# Time step: 74000
# Time step: 75000
# Time step: 76000
# Time step: 77000
# Time step: 78000
# Time step: 79000
# Time step: 80000
# Time step: 81000
# Time step: 82000
# Time step: 83000
# Time step: 84000
# Time step: 85000
# Time step: 86000
# Time step: 87000
# Time step: 88000
# Time step: 89000
# Time step: 90000
# Time step: 91000
# Time step: 92000
# Time step: 93000
# Time step: 94000
# Time step: 95000
# Time step: 96000
# Time step: 97000
# Time step: 98000
# Time step: 99000
# Time step: 100000
# Time step: 101000
# Time step: 102000
# Time step: 103000
# Time step: 104000
# Time step: 105000
# Time step: 106000
# Time step: 107000
# Time step: 108000
# Time step: 109000
# Time step: 110000
# Time step: 111000
# Time step: 112000
# Time step: 113000
# Time step: 114000
# Time step: 115000
# Time step: 116000
# Time step: 117000
# Time step: 118000
# Time step: 119000
# Time step: 120000

# %% [markdown]
# ### Retrieve recorded data

# %%
data_lif1_v = monitor_lif1_v.get_data()
data_lif1_u = monitor_lif1_u.get_data()

print("Copying...")
data_lif1 = data_lif1_v.copy()
data_lif1["lif1"]["u"] = data_lif1_u["lif1"]["u"]   # Merge the dictionaries to contain both voltage and current
# Out:
# Copying...

# %%
selectedLIF

# %%
# Check the shape to verify if it is printing the voltage for every step
print(len(data_lif1['lif1']['v']))     # Indeed, there are 300 values (same as the number of steps we ran the simulation for)
# Out:
# 120000

# %% [markdown]
# ### Plot the recorded data

# %%
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt

# Boolean defining if we should use the monitor plot
MONITOR_PLOT = False

if MONITOR_PLOT:
    # Create a subplot for each monitored variable
    fig = plt.figure(figsize=(16, 10))
    ax0 = fig.add_subplot(221)
    ax0.set_title('Voltage (V) / time step')
    ax1 = fig.add_subplot(222)
    ax1.set_title('Current (U) / time step')


    # Plot the data
    monitor_lif1_v.plot(ax0, lif1.v)
    monitor_lif1_u.plot(ax1, lif1.u)

# %% [markdown]
# ## Find the timesteps where the network spiked

# %%
from utils.data_analysis import find_spike_times

lif1_voltage_vals = np.array(data_lif1['lif1']['v'])
lif1_current_vals = np.array(data_lif1['lif1']['u'])
# preview_np_array(voltage_arr_1, "Voltage Array")

# Call the find_spike_times util function that detects the spikes in a voltage array
# TODO: Improve the find_spike_times method to view the current of the preview timestep to make sure it is a spike, instead of an inhibition
spike_times_lif1 = find_spike_times(lif1_voltage_vals, lif1_current_vals)

print(f"Found {len(spike_times_lif1)} spikes in the LIF1 Process")
for (spike_time, neuron_idx) in spike_times_lif1:
    print(f"Spike time: {init_offset + spike_time * virtual_time_step_interval} (iter. {spike_time}) at neuron: {neuron_idx}")
# Out:
# Found 22664 spikes in the LIF1 Process
# Spike time: 1011 (iter. 1011) at neuron: 60
# Spike time: 1011 (iter. 1011) at neuron: 72
# Spike time: 1011 (iter. 1011) at neuron: 109
# Spike time: 1011 (iter. 1011) at neuron: 126
# Spike time: 1011 (iter. 1011) at neuron: 146
# Spike time: 1011 (iter. 1011) at neuron: 167
# Spike time: 1011 (iter. 1011) at neuron: 232
# Spike time: 1012 (iter. 1012) at neuron: 0
# Spike time: 1012 (iter. 1012) at neuron: 1
# Spike time: 1012 (iter. 1012) at neuron: 6
# Spike time: 1012 (iter. 1012) at neuron: 11
# Spike time: 1012 (iter. 1012) at neuron: 13
# Spike time: 1012 (iter. 1012) at neuron: 18
# Spike time: 1012 (iter. 1012) at neuron: 20
# Spike time: 1012 (iter. 1012) at neuron: 22
# Spike time: 1012 (iter. 1012) at neuron: 50
# Spike time: 1012 (iter. 1012) at neuron: 52
# Spike time: 1012 (iter. 1012) at neuron: 54
# Spike time: 1012 (iter. 1012) at neuron: 56
# Spike time: 1012 (iter. 1012) at neuron: 63
# Spike time: 1012 (iter. 1012) at neuron: 64
# Spike time: 1012 (iter. 1012) at neuron: 65
# Spike time: 1012 (iter. 1012) at neuron: 76
# Spike time: 1012 (iter. 1012) at neuron: 79
# Spike time: 1012 (iter. 1012) at neuron: 82
# Spike time: 1012 (iter. 1012) at neuron: 83
# Spike time: 1012 (iter. 1012) at neuron: 85
# Spike time: 1012 (iter. 1012) at neuron: 86
# Spike time: 1012 (iter. 1012) at neuron: 87
# Spike time: 1012 (iter. 1012) at neuron: 90
# Spike time: 1012 (iter. 1012) at neuron: 91
# Spike time: 1012 (iter. 1012) at neuron: 95
# Spike time: 1012 (iter. 1012) at neuron: 97
# Spike time: 1012 (iter. 1012) at neuron: 105
# Spike time: 1012 (iter. 1012) at neuron: 106
# Spike time: 1012 (iter. 1012) at neuron: 112
# Spike time: 1012 (iter. 1012) at neuron: 116
# Spike time: 1012 (iter. 1012) at neuron: 124
# Spike time: 1012 (iter. 1012) at neuron: 125
# Spike time: 1012 (iter. 1012) at neuron: 138
# Spike time: 1012 (iter. 1012) at neuron: 140
# Spike time: 1012 (iter. 1012) at neuron: 150
# Spike time: 1012 (iter. 1012) at neuron: 152
# Spike time: 1012 (iter. 1012) at neuron: 157
# Spike time: 1012 (iter. 1012) at neuron: 161
# Spike time: 1012 (iter. 1012) at neuron: 168
# Spike time: 1012 (iter. 1012) at neuron: 173
# Spike time: 1012 (iter. 1012) at neuron: 176
# Spike time: 1012 (iter. 1012) at neuron: 178
# Spike time: 1012 (iter. 1012) at neuron: 181
# Spike time: 1012 (iter. 1012) at neuron: 188
# Spike time: 1012 (iter. 1012) at neuron: 190
# Spike time: 1012 (iter. 1012) at neuron: 192
# Spike time: 1012 (iter. 1012) at neuron: 193
# Spike time: 1012 (iter. 1012) at neuron: 196
# Spike time: 1012 (iter. 1012) at neuron: 198
# Spike time: 1012 (iter. 1012) at neuron: 201
# Spike time: 1012 (iter. 1012) at neuron: 207
# Spike time: 1012 (iter. 1012) at neuron: 213
# Spike time: 1012 (iter. 1012) at neuron: 228
# Spike time: 1012 (iter. 1012) at neuron: 229
# Spike time: 1012 (iter. 1012) at neuron: 237
# Spike time: 1012 (iter. 1012) at neuron: 238
# Spike time: 1012 (iter. 1012) at neuron: 239
# Spike time: 1012 (iter. 1012) at neuron: 241
# Spike time: 1012 (iter. 1012) at neuron: 243
# Spike time: 1012 (iter. 1012) at neuron: 244
# Spike time: 1012 (iter. 1012) at neuron: 254
# Spike time: 1013 (iter. 1013) at neuron: 43
# Spike time: 1013 (iter. 1013) at neuron: 66
# Spike time: 1013 (iter. 1013) at neuron: 84
# Spike time: 1013 (iter. 1013) at neuron: 113
# Spike time: 1013 (iter. 1013) at neuron: 136
# Spike time: 1013 (iter. 1013) at neuron: 163
# Spike time: 1013 (iter. 1013) at neuron: 164
# Spike time: 1013 (iter. 1013) at neuron: 236
# Spike time: 1018 (iter. 1018) at neuron: 15
# Spike time: 1018 (iter. 1018) at neuron: 27
# Spike time: 1018 (iter. 1018) at neuron: 45
# Spike time: 1019 (iter. 1019) at neuron: 3
# Spike time: 1019 (iter. 1019) at neuron: 4
# Spike time: 1019 (iter. 1019) at neuron: 8
# Spike time: 1019 (iter. 1019) at neuron: 9
# Spike time: 1019 (iter. 1019) at neuron: 14
# Spike time: 1019 (iter. 1019) at neuron: 16
# Spike time: 1019 (iter. 1019) at neuron: 17
# Spike time: 1019 (iter. 1019) at neuron: 28
# Spike time: 1019 (iter. 1019) at neuron: 30
# Spike time: 1019 (iter. 1019) at neuron: 31
# Spike time: 1019 (iter. 1019) at neuron: 34
# Spike time: 1019 (iter. 1019) at neuron: 36
# Spike time: 1019 (iter. 1019) at neuron: 40
# Spike time: 1019 (iter. 1019) at neuron: 42
# Spike time: 1019 (iter. 1019) at neuron: 46
# Spike time: 1019 (iter. 1019) at neuron: 47
# Spike time: 1019 (iter. 1019) at neuron: 48
# Spike time: 1019 (iter. 1019) at neuron: 49
# Spike time: 1019 (iter. 1019) at neuron: 51
# Spike time: 1019 (iter. 1019) at neuron: 55
# Spike time: 1019 (iter. 1019) at neuron: 57
# Spike time: 1019 (iter. 1019) at neuron: 59
# Spike time: 1019 (iter. 1019) at neuron: 71
# Spike time: 1019 (iter. 1019) at neuron: 73
# Spike time: 1019 (iter. 1019) at neuron: 89
# Spike time: 1019 (iter. 1019) at neuron: 99
# Spike time: 1019 (iter. 1019) at neuron: 111
# Spike time: 1019 (iter. 1019) at neuron: 115
# Spike time: 1019 (iter. 1019) at neuron: 117
# Spike time: 1019 (iter. 1019) at neuron: 118
# Spike time: 1019 (iter. 1019) at neuron: 123
# Spike time: 1019 (iter. 1019) at neuron: 129
# Spike time: 1019 (iter. 1019) at neuron: 147
# Spike time: 1019 (iter. 1019) at neuron: 151
# Spike time: 1019 (iter. 1019) at neuron: 155
# Spike time: 1019 (iter. 1019) at neuron: 156
# Spike time: 1019 (iter. 1019) at neuron: 158
# Spike time: 1019 (iter. 1019) at neuron: 160
# Spike time: 1019 (iter. 1019) at neuron: 162
# Spike time: 1019 (iter. 1019) at neuron: 165
# Spike time: 1019 (iter. 1019) at neuron: 171
# Spike time: 1019 (iter. 1019) at neuron: 172
# Spike time: 1019 (iter. 1019) at neuron: 175
# Spike time: 1019 (iter. 1019) at neuron: 177
# Spike time: 1019 (iter. 1019) at neuron: 179
# Spike time: 1019 (iter. 1019) at neuron: 180
# Spike time: 1019 (iter. 1019) at neuron: 186
# Spike time: 1019 (iter. 1019) at neuron: 187
# Spike time: 1019 (iter. 1019) at neuron: 191
# Spike time: 1019 (iter. 1019) at neuron: 194
# Spike time: 1019 (iter. 1019) at neuron: 205
# Spike time: 1019 (iter. 1019) at neuron: 208
# Spike time: 1019 (iter. 1019) at neuron: 210
# Spike time: 1019 (iter. 1019) at neuron: 211
# Spike time: 1019 (iter. 1019) at neuron: 214
# Spike time: 1019 (iter. 1019) at neuron: 217
# Spike time: 1019 (iter. 1019) at neuron: 222
# Spike time: 1019 (iter. 1019) at neuron: 227
# Spike time: 1019 (iter. 1019) at neuron: 234
# Spike time: 1019 (iter. 1019) at neuron: 247
# Spike time: 1019 (iter. 1019) at neuron: 250
# Spike time: 1019 (iter. 1019) at neuron: 253
# Spike time: 1020 (iter. 1020) at neuron: 68
# Spike time: 1020 (iter. 1020) at neuron: 70
# Spike time: 1020 (iter. 1020) at neuron: 78
# Spike time: 1020 (iter. 1020) at neuron: 120
# Spike time: 1020 (iter. 1020) at neuron: 122
# Spike time: 1020 (iter. 1020) at neuron: 132
# Spike time: 1020 (iter. 1020) at neuron: 133
# Spike time: 1020 (iter. 1020) at neuron: 134
# Spike time: 1020 (iter. 1020) at neuron: 159
# Spike time: 1020 (iter. 1020) at neuron: 235
# Spike time: 1200 (iter. 1200) at neuron: 91
# Spike time: 1214 (iter. 1214) at neuron: 151
# Spike time: 1359 (iter. 1359) at neuron: 66
# Spike time: 1390 (iter. 1390) at neuron: 91
# Spike time: 1432 (iter. 1432) at neuron: 151
# Spike time: 1568 (iter. 1568) at neuron: 66
# Spike time: 1593 (iter. 1593) at neuron: 91
# Spike time: 1771 (iter. 1771) at neuron: 66
# Spike time: 1971 (iter. 1971) at neuron: 66
# Spike time: 2171 (iter. 2171) at neuron: 66
# Spike time: 2371 (iter. 2371) at neuron: 66
# Spike time: 2572 (iter. 2572) at neuron: 66
# Spike time: 2677 (iter. 2677) at neuron: 105
# Spike time: 2775 (iter. 2775) at neuron: 66
# Spike time: 2888 (iter. 2888) at neuron: 105
# Spike time: 2981 (iter. 2981) at neuron: 66
# Spike time: 3092 (iter. 3092) at neuron: 105
# Spike time: 3192 (iter. 3192) at neuron: 66
# Spike time: 3232 (iter. 3232) at neuron: 11
# Spike time: 3232 (iter. 3232) at neuron: 22
# Spike time: 3232 (iter. 3232) at neuron: 60
# Spike time: 3232 (iter. 3232) at neuron: 72
# Spike time: 3232 (iter. 3232) at neuron: 109
# Spike time: 3232 (iter. 3232) at neuron: 146
# Spike time: 3232 (iter. 3232) at neuron: 167
# Spike time: 3232 (iter. 3232) at neuron: 196
# Spike time: 3232 (iter. 3232) at neuron: 201
# Spike time: 3233 (iter. 3233) at neuron: 18
# Spike time: 3233 (iter. 3233) at neuron: 52
# Spike time: 3233 (iter. 3233) at neuron: 82
# Spike time: 3233 (iter. 3233) at neuron: 85
# Spike time: 3233 (iter. 3233) at neuron: 91
# Spike time: 3233 (iter. 3233) at neuron: 95
# Spike time: 3233 (iter. 3233) at neuron: 106
# Spike time: 3233 (iter. 3233) at neuron: 124
# Spike time: 3233 (iter. 3233) at neuron: 125
# Spike time: 3233 (iter. 3233) at neuron: 138
# Spike time: 3233 (iter. 3233) at neuron: 140
# Spike time: 3233 (iter. 3233) at neuron: 152
# Spike time: 3233 (iter. 3233) at neuron: 181
# Spike time: 3233 (iter. 3233) at neuron: 207
# Spike time: 3233 (iter. 3233) at neuron: 213
# Spike time: 3233 (iter. 3233) at neuron: 237
# Spike time: 3233 (iter. 3233) at neuron: 238
# Spike time: 3233 (iter. 3233) at neuron: 244
# Spike time: 3244 (iter. 3244) at neuron: 63
# Spike time: 3244 (iter. 3244) at neuron: 90
# Spike time: 3244 (iter. 3244) at neuron: 150
# Spike time: 3244 (iter. 3244) at neuron: 190
# Spike time: 3244 (iter. 3244) at neuron: 236
# Spike time: 3262 (iter. 3262) at neuron: 126
# Spike time: 3263 (iter. 3263) at neuron: 232
# Spike time: 3264 (iter. 3264) at neuron: 50
# Spike time: 3264 (iter. 3264) at neuron: 54
# Spike time: 3264 (iter. 3264) at neuron: 64
# Spike time: 3264 (iter. 3264) at neuron: 79
# Spike time: 3264 (iter. 3264) at neuron: 86
# Spike time: 3264 (iter. 3264) at neuron: 87
# Spike time: 3264 (iter. 3264) at neuron: 116
# Spike time: 3264 (iter. 3264) at neuron: 157
# Spike time: 3264 (iter. 3264) at neuron: 161
# Spike time: 3264 (iter. 3264) at neuron: 192
# Spike time: 3264 (iter. 3264) at neuron: 239
# Spike time: 3264 (iter. 3264) at neuron: 254
# Spike time: 3265 (iter. 3265) at neuron: 1
# Spike time: 3265 (iter. 3265) at neuron: 6
# Spike time: 3265 (iter. 3265) at neuron: 20
# Spike time: 3265 (iter. 3265) at neuron: 31
# Spike time: 3265 (iter. 3265) at neuron: 56
# Spike time: 3265 (iter. 3265) at neuron: 65
# Spike time: 3265 (iter. 3265) at neuron: 76
# Spike time: 3265 (iter. 3265) at neuron: 83
# Spike time: 3265 (iter. 3265) at neuron: 112
# Spike time: 3265 (iter. 3265) at neuron: 113
# Spike time: 3265 (iter. 3265) at neuron: 164
# Spike time: 3265 (iter. 3265) at neuron: 168
# Spike time: 3265 (iter. 3265) at neuron: 176
# Spike time: 3265 (iter. 3265) at neuron: 178
# Spike time: 3265 (iter. 3265) at neuron: 188
# Spike time: 3265 (iter. 3265) at neuron: 193
# Spike time: 3265 (iter. 3265) at neuron: 198
# Spike time: 3265 (iter. 3265) at neuron: 228
# Spike time: 3265 (iter. 3265) at neuron: 229
# Spike time: 3265 (iter. 3265) at neuron: 243
# Spike time: 3266 (iter. 3266) at neuron: 45
# Spike time: 3289 (iter. 3289) at neuron: 162
# Spike time: 3301 (iter. 3301) at neuron: 173
# Spike time: 3301 (iter. 3301) at neuron: 191
# Spike time: 3302 (iter. 3302) at neuron: 55
# Spike time: 3408 (iter. 3408) at neuron: 151
# Spike time: 3429 (iter. 3429) at neuron: 91
# Spike time: 3429 (iter. 3429) at neuron: 125
# Spike time: 3527 (iter. 3527) at neuron: 43
# Spike time: 3528 (iter. 3528) at neuron: 106
# Spike time: 3528 (iter. 3528) at neuron: 167
# Spike time: 3529 (iter. 3529) at neuron: 22
# Spike time: 3529 (iter. 3529) at neuron: 109
# Spike time: 3529 (iter. 3529) at neuron: 117
# Spike time: 3529 (iter. 3529) at neuron: 146
# Spike time: 3530 (iter. 3530) at neuron: 11
# Spike time: 3530 (iter. 3530) at neuron: 18
# Spike time: 3530 (iter. 3530) at neuron: 52
# Spike time: 3530 (iter. 3530) at neuron: 60
# Spike time: 3530 (iter. 3530) at neuron: 72
# Spike time: 3530 (iter. 3530) at neuron: 84
# Spike time: 3530 (iter. 3530) at neuron: 124
# Spike time: 3530 (iter. 3530) at neuron: 152
# Spike time: 3530 (iter. 3530) at neuron: 196
# Spike time: 3530 (iter. 3530) at neuron: 201
# Spike time: 3530 (iter. 3530) at neuron: 207
# Spike time: 3530 (iter. 3530) at neuron: 213
# Spike time: 3530 (iter. 3530) at neuron: 238
# Spike time: 3531 (iter. 3531) at neuron: 0
# Spike time: 3531 (iter. 3531) at neuron: 63
# Spike time: 3531 (iter. 3531) at neuron: 82
# Spike time: 3531 (iter. 3531) at neuron: 90
# Spike time: 3531 (iter. 3531) at neuron: 95
# Spike time: 3531 (iter. 3531) at neuron: 138
# Spike time: 3531 (iter. 3531) at neuron: 140
# Spike time: 3531 (iter. 3531) at neuron: 173
# Spike time: 3531 (iter. 3531) at neuron: 178
# Spike time: 3531 (iter. 3531) at neuron: 190
# Spike time: 3531 (iter. 3531) at neuron: 236
# Spike time: 3531 (iter. 3531) at neuron: 237
# Spike time: 3531 (iter. 3531) at neuron: 244
# Spike time: 3539 (iter. 3539) at neuron: 126
# Spike time: 3539 (iter. 3539) at neuron: 232
# Spike time: 3540 (iter. 3540) at neuron: 1
# Spike time: 3540 (iter. 3540) at neuron: 6
# Spike time: 3540 (iter. 3540) at neuron: 13
# Spike time: 3540 (iter. 3540) at neuron: 15
# Spike time: 3540 (iter. 3540) at neuron: 17
# Spike time: 3540 (iter. 3540) at neuron: 20
# Spike time: 3540 (iter. 3540) at neuron: 31
# Spike time: 3540 (iter. 3540) at neuron: 45
# Spike time: 3540 (iter. 3540) at neuron: 50
# Spike time: 3540 (iter. 3540) at neuron: 51
# Spike time: 3540 (iter. 3540) at neuron: 54
# Spike time: 3540 (iter. 3540) at neuron: 56
# Spike time: 3540 (iter. 3540) at neuron: 57
# Spike time: 3540 (iter. 3540) at neuron: 59
# Spike time: 3540 (iter. 3540) at neuron: 64
# Spike time: 3540 (iter. 3540) at neuron: 65
# Spike time: 3540 (iter. 3540) at neuron: 73
# Spike time: 3540 (iter. 3540) at neuron: 75
# Spike time: 3540 (iter. 3540) at neuron: 76
# Spike time: 3540 (iter. 3540) at neuron: 79
# Spike time: 3540 (iter. 3540) at neuron: 83
# Spike time: 3540 (iter. 3540) at neuron: 85
# Spike time: 3540 (iter. 3540) at neuron: 86
# Spike time: 3540 (iter. 3540) at neuron: 87
# Spike time: 3540 (iter. 3540) at neuron: 89
# Spike time: 3540 (iter. 3540) at neuron: 97
# Spike time: 3540 (iter. 3540) at neuron: 111
# Spike time: 3540 (iter. 3540) at neuron: 112
# Spike time: 3540 (iter. 3540) at neuron: 113
# Spike time: 3540 (iter. 3540) at neuron: 115
# Spike time: 3540 (iter. 3540) at neuron: 116
# Spike time: 3540 (iter. 3540) at neuron: 118
# Spike time: 3540 (iter. 3540) at neuron: 136
# Spike time: 3540 (iter. 3540) at neuron: 147
# Spike time: 3540 (iter. 3540) at neuron: 150
# Spike time: 3540 (iter. 3540) at neuron: 156
# Spike time: 3540 (iter. 3540) at neuron: 157
# Spike time: 3540 (iter. 3540) at neuron: 158
# Spike time: 3540 (iter. 3540) at neuron: 160
# Spike time: 3540 (iter. 3540) at neuron: 161
# Spike time: 3540 (iter. 3540) at neuron: 163
# Spike time: 3540 (iter. 3540) at neuron: 164
# Spike time: 3540 (iter. 3540) at neuron: 168
# Spike time: 3540 (iter. 3540) at neuron: 171
# Spike time: 3540 (iter. 3540) at neuron: 176
# Spike time: 3540 (iter. 3540) at neuron: 181
# Spike time: 3540 (iter. 3540) at neuron: 188
# Spike time: 3540 (iter. 3540) at neuron: 192
# Spike time: 3540 (iter. 3540) at neuron: 193
# Spike time: 3540 (iter. 3540) at neuron: 194
# Spike time: 3540 (iter. 3540) at neuron: 198
# Spike time: 3540 (iter. 3540) at neuron: 205
# Spike time: 3540 (iter. 3540) at neuron: 214
# Spike time: 3540 (iter. 3540) at neuron: 222
# Spike time: 3540 (iter. 3540) at neuron: 228
# Spike time: 3540 (iter. 3540) at neuron: 229
# Spike time: 3540 (iter. 3540) at neuron: 234
# Spike time: 3540 (iter. 3540) at neuron: 239
# Spike time: 3540 (iter. 3540) at neuron: 241
# Spike time: 3540 (iter. 3540) at neuron: 243
# Spike time: 3540 (iter. 3540) at neuron: 253
# Spike time: 3540 (iter. 3540) at neuron: 254
# Spike time: 3541 (iter. 3541) at neuron: 3
# Spike time: 3541 (iter. 3541) at neuron: 4
# Spike time: 3541 (iter. 3541) at neuron: 8
# Spike time: 3541 (iter. 3541) at neuron: 9
# Spike time: 3541 (iter. 3541) at neuron: 14
# Spike time: 3541 (iter. 3541) at neuron: 16
# Spike time: 3541 (iter. 3541) at neuron: 25
# Spike time: 3541 (iter. 3541) at neuron: 27
# Spike time: 3541 (iter. 3541) at neuron: 28
# Spike time: 3541 (iter. 3541) at neuron: 30
# Spike time: 3541 (iter. 3541) at neuron: 34
# Spike time: 3541 (iter. 3541) at neuron: 36
# Spike time: 3541 (iter. 3541) at neuron: 40
# Spike time: 3541 (iter. 3541) at neuron: 42
# Spike time: 3541 (iter. 3541) at neuron: 46
# Spike time: 3541 (iter. 3541) at neuron: 47
# Spike time: 3541 (iter. 3541) at neuron: 48
# Spike time: 3541 (iter. 3541) at neuron: 49
# Spike time: 3541 (iter. 3541) at neuron: 55
# Spike time: 3541 (iter. 3541) at neuron: 58
# Spike time: 3541 (iter. 3541) at neuron: 70
# Spike time: 3541 (iter. 3541) at neuron: 71
# Spike time: 3541 (iter. 3541) at neuron: 78
# Spike time: 3541 (iter. 3541) at neuron: 93
# Spike time: 3541 (iter. 3541) at neuron: 99
# Spike time: 3541 (iter. 3541) at neuron: 108
# Spike time: 3541 (iter. 3541) at neuron: 110
# Spike time: 3541 (iter. 3541) at neuron: 120
# Spike time: 3541 (iter. 3541) at neuron: 122
# Spike time: 3541 (iter. 3541) at neuron: 123
# Spike time: 3541 (iter. 3541) at neuron: 129
# Spike time: 3541 (iter. 3541) at neuron: 132
# Spike time: 3541 (iter. 3541) at neuron: 133
# Spike time: 3541 (iter. 3541) at neuron: 141
# Spike time: 3541 (iter. 3541) at neuron: 145
# Spike time: 3541 (iter. 3541) at neuron: 149
# Spike time: 3541 (iter. 3541) at neuron: 153
# Spike time: 3541 (iter. 3541) at neuron: 155
# Spike time: 3541 (iter. 3541) at neuron: 159
# Spike time: 3541 (iter. 3541) at neuron: 162
# Spike time: 3541 (iter. 3541) at neuron: 165
# Spike time: 3541 (iter. 3541) at neuron: 172
# Spike time: 3541 (iter. 3541) at neuron: 175
# Spike time: 3541 (iter. 3541) at neuron: 177
# Spike time: 3541 (iter. 3541) at neuron: 179
# Spike time: 3541 (iter. 3541) at neuron: 180
# Spike time: 3541 (iter. 3541) at neuron: 183
# Spike time: 3541 (iter. 3541) at neuron: 186
# Spike time: 3541 (iter. 3541) at neuron: 187
# Spike time: 3541 (iter. 3541) at neuron: 199
# Spike time: 3541 (iter. 3541) at neuron: 202
# Spike time: 3541 (iter. 3541) at neuron: 208
# Spike time: 3541 (iter. 3541) at neuron: 210
# Spike time: 3541 (iter. 3541) at neuron: 211
# Spike time: 3541 (iter. 3541) at neuron: 217
# Spike time: 3541 (iter. 3541) at neuron: 227
# Spike time: 3541 (iter. 3541) at neuron: 235
# Spike time: 3541 (iter. 3541) at neuron: 247
# Spike time: 3541 (iter. 3541) at neuron: 250
# Spike time: 3542 (iter. 3542) at neuron: 68
# Spike time: 3542 (iter. 3542) at neuron: 69
# Spike time: 3542 (iter. 3542) at neuron: 191
# Spike time: 3553 (iter. 3553) at neuron: 135
# Spike time: 3553 (iter. 3553) at neuron: 203
# Spike time: 3554 (iter. 3554) at neuron: 12
# Spike time: 3554 (iter. 3554) at neuron: 26
# Spike time: 3554 (iter. 3554) at neuron: 33
# Spike time: 3554 (iter. 3554) at neuron: 37
# Spike time: 3554 (iter. 3554) at neuron: 80
# Spike time: 3554 (iter. 3554) at neuron: 88
# Spike time: 3554 (iter. 3554) at neuron: 94
# Spike time: 3554 (iter. 3554) at neuron: 98
# Spike time: 3554 (iter. 3554) at neuron: 114
# Spike time: 3554 (iter. 3554) at neuron: 134
# Spike time: 3554 (iter. 3554) at neuron: 144
# Spike time: 3554 (iter. 3554) at neuron: 148
# Spike time: 3554 (iter. 3554) at neuron: 166
# Spike time: 3554 (iter. 3554) at neuron: 170
# Spike time: 3554 (iter. 3554) at neuron: 200
# Spike time: 3554 (iter. 3554) at neuron: 209
# Spike time: 3554 (iter. 3554) at neuron: 215
# Spike time: 3554 (iter. 3554) at neuron: 225
# Spike time: 3554 (iter. 3554) at neuron: 231
# Spike time: 3554 (iter. 3554) at neuron: 245
# Spike time: 3554 (iter. 3554) at neuron: 251
# Spike time: 3554 (iter. 3554) at neuron: 252
# Spike time: 3555 (iter. 3555) at neuron: 5
# Spike time: 3555 (iter. 3555) at neuron: 7
# Spike time: 3555 (iter. 3555) at neuron: 10
# Spike time: 3555 (iter. 3555) at neuron: 21
# Spike time: 3555 (iter. 3555) at neuron: 24
# Spike time: 3555 (iter. 3555) at neuron: 53
# Spike time: 3555 (iter. 3555) at neuron: 61
# Spike time: 3555 (iter. 3555) at neuron: 66
# Spike time: 3555 (iter. 3555) at neuron: 67
# Spike time: 3555 (iter. 3555) at neuron: 74
# Spike time: 3555 (iter. 3555) at neuron: 77
# Spike time: 3555 (iter. 3555) at neuron: 105
# Spike time: 3555 (iter. 3555) at neuron: 130
# Spike time: 3555 (iter. 3555) at neuron: 142
# Spike time: 3555 (iter. 3555) at neuron: 182
# Spike time: 3555 (iter. 3555) at neuron: 204
# Spike time: 3555 (iter. 3555) at neuron: 220
# Spike time: 3555 (iter. 3555) at neuron: 223
# Spike time: 3555 (iter. 3555) at neuron: 226
# Spike time: 3555 (iter. 3555) at neuron: 248
# Spike time: 3555 (iter. 3555) at neuron: 255
# Spike time: 3556 (iter. 3556) at neuron: 103
# Spike time: 3556 (iter. 3556) at neuron: 119
# Spike time: 3556 (iter. 3556) at neuron: 127
# Spike time: 3556 (iter. 3556) at neuron: 128
# Spike time: 3556 (iter. 3556) at neuron: 154
# Spike time: 3556 (iter. 3556) at neuron: 218
# Spike time: 3556 (iter. 3556) at neuron: 221
# Spike time: 3557 (iter. 3557) at neuron: 104
# Spike time: 3560 (iter. 3560) at neuron: 216
# Spike time: 3561 (iter. 3561) at neuron: 242
# Spike time: 3562 (iter. 3562) at neuron: 189
# Spike time: 3563 (iter. 3563) at neuron: 143
# Spike time: 3563 (iter. 3563) at neuron: 174
# Spike time: 3563 (iter. 3563) at neuron: 212
# Spike time: 3564 (iter. 3564) at neuron: 139
# Spike time: 3565 (iter. 3565) at neuron: 39
# Spike time: 3565 (iter. 3565) at neuron: 219
# Spike time: 3566 (iter. 3566) at neuron: 2
# Spike time: 3566 (iter. 3566) at neuron: 23
# Spike time: 3566 (iter. 3566) at neuron: 38
# Spike time: 3566 (iter. 3566) at neuron: 107
# Spike time: 3566 (iter. 3566) at neuron: 184
# Spike time: 3566 (iter. 3566) at neuron: 185
# Spike time: 3567 (iter. 3567) at neuron: 29
# Spike time: 3567 (iter. 3567) at neuron: 41
# Spike time: 3567 (iter. 3567) at neuron: 121
# Spike time: 3567 (iter. 3567) at neuron: 197
# Spike time: 3567 (iter. 3567) at neuron: 249
# Spike time: 3576 (iter. 3576) at neuron: 44
# Spike time: 3577 (iter. 3577) at neuron: 32
# Spike time: 3577 (iter. 3577) at neuron: 230
# Spike time: 3593 (iter. 3593) at neuron: 246
# Spike time: 3595 (iter. 3595) at neuron: 81
# Spike time: 3616 (iter. 3616) at neuron: 91
# Spike time: 3663 (iter. 3663) at neuron: 125
# Spike time: 3711 (iter. 3711) at neuron: 43
# Spike time: 3715 (iter. 3715) at neuron: 117
# Spike time: 3721 (iter. 3721) at neuron: 106
# Spike time: 3741 (iter. 3741) at neuron: 66
# Spike time: 3742 (iter. 3742) at neuron: 105
# Spike time: 3772 (iter. 3772) at neuron: 151
# Spike time: 3798 (iter. 3798) at neuron: 91
# Spike time: 3897 (iter. 3897) at neuron: 43
# Spike time: 3925 (iter. 3925) at neuron: 66
# Spike time: 3927 (iter. 3927) at neuron: 105
# Spike time: 3957 (iter. 3957) at neuron: 151
# Spike time: 3981 (iter. 3981) at neuron: 91
# Spike time: 4106 (iter. 4106) at neuron: 43
# Spike time: 4108 (iter. 4108) at neuron: 66
# Spike time: 4111 (iter. 4111) at neuron: 105
# Spike time: 4147 (iter. 4147) at neuron: 151
# Spike time: 4168 (iter. 4168) at neuron: 91
# Spike time: 4169 (iter. 4169) at neuron: 11
# Spike time: 4169 (iter. 4169) at neuron: 60
# Spike time: 4169 (iter. 4169) at neuron: 72
# Spike time: 4169 (iter. 4169) at neuron: 109
# Spike time: 4169 (iter. 4169) at neuron: 146
# Spike time: 4169 (iter. 4169) at neuron: 181
# Spike time: 4169 (iter. 4169) at neuron: 196
# Spike time: 4169 (iter. 4169) at neuron: 232
# Spike time: 4169 (iter. 4169) at neuron: 244
# Spike time: 4170 (iter. 4170) at neuron: 6
# Spike time: 4170 (iter. 4170) at neuron: 22
# Spike time: 4170 (iter. 4170) at neuron: 52
# Spike time: 4170 (iter. 4170) at neuron: 64
# Spike time: 4170 (iter. 4170) at neuron: 65
# Spike time: 4170 (iter. 4170) at neuron: 76
# Spike time: 4170 (iter. 4170) at neuron: 82
# Spike time: 4170 (iter. 4170) at neuron: 85
# Spike time: 4170 (iter. 4170) at neuron: 86
# Spike time: 4170 (iter. 4170) at neuron: 87
# Spike time: 4170 (iter. 4170) at neuron: 95
# Spike time: 4170 (iter. 4170) at neuron: 116
# Spike time: 4170 (iter. 4170) at neuron: 138
# Spike time: 4170 (iter. 4170) at neuron: 150
# Spike time: 4170 (iter. 4170) at neuron: 152
# Spike time: 4170 (iter. 4170) at neuron: 157
# Spike time: 4170 (iter. 4170) at neuron: 161
# Spike time: 4170 (iter. 4170) at neuron: 188
# Spike time: 4170 (iter. 4170) at neuron: 201
# Spike time: 4170 (iter. 4170) at neuron: 207
# Spike time: 4170 (iter. 4170) at neuron: 228
# Spike time: 4170 (iter. 4170) at neuron: 237
# Spike time: 4170 (iter. 4170) at neuron: 238
# Spike time: 4170 (iter. 4170) at neuron: 254
# Spike time: 4171 (iter. 4171) at neuron: 1
# Spike time: 4171 (iter. 4171) at neuron: 18
# Spike time: 4171 (iter. 4171) at neuron: 20
# Spike time: 4171 (iter. 4171) at neuron: 50
# Spike time: 4171 (iter. 4171) at neuron: 79
# Spike time: 4171 (iter. 4171) at neuron: 83
# Spike time: 4171 (iter. 4171) at neuron: 90
# Spike time: 4171 (iter. 4171) at neuron: 112
# Spike time: 4171 (iter. 4171) at neuron: 140
# Spike time: 4171 (iter. 4171) at neuron: 164
# Spike time: 4171 (iter. 4171) at neuron: 167
# Spike time: 4171 (iter. 4171) at neuron: 168
# Spike time: 4171 (iter. 4171) at neuron: 176
# Spike time: 4171 (iter. 4171) at neuron: 178
# Spike time: 4171 (iter. 4171) at neuron: 190
# Spike time: 4171 (iter. 4171) at neuron: 213
# Spike time: 4171 (iter. 4171) at neuron: 229
# Spike time: 4171 (iter. 4171) at neuron: 241
# Spike time: 4171 (iter. 4171) at neuron: 243
# Spike time: 4182 (iter. 4182) at neuron: 63
# Spike time: 4182 (iter. 4182) at neuron: 113
# Spike time: 4183 (iter. 4183) at neuron: 31
# Spike time: 4183 (iter. 4183) at neuron: 45
# Spike time: 4183 (iter. 4183) at neuron: 106
# Spike time: 4183 (iter. 4183) at neuron: 124
# Spike time: 4183 (iter. 4183) at neuron: 125
# Spike time: 4183 (iter. 4183) at neuron: 173
# Spike time: 4183 (iter. 4183) at neuron: 236
# Spike time: 4184 (iter. 4184) at neuron: 0
# Spike time: 4184 (iter. 4184) at neuron: 27
# Spike time: 4184 (iter. 4184) at neuron: 34
# Spike time: 4184 (iter. 4184) at neuron: 172
# Spike time: 4291 (iter. 4291) at neuron: 66
# Spike time: 4295 (iter. 4295) at neuron: 105
# Spike time: 4338 (iter. 4338) at neuron: 151
# Spike time: 4354 (iter. 4354) at neuron: 91
# Spike time: 4474 (iter. 4474) at neuron: 66
# Spike time: 4478 (iter. 4478) at neuron: 105
# Spike time: 4544 (iter. 4544) at neuron: 91
# Spike time: 4549 (iter. 4549) at neuron: 151
# Spike time: 4657 (iter. 4657) at neuron: 66
# Spike time: 4661 (iter. 4661) at neuron: 105
# Spike time: 4749 (iter. 4749) at neuron: 91
# Spike time: 4840 (iter. 4840) at neuron: 66
# Spike time: 4844 (iter. 4844) at neuron: 105
# Spike time: 5023 (iter. 5023) at neuron: 66
# Spike time: 5026 (iter. 5026) at neuron: 105
# Spike time: 5206 (iter. 5206) at neuron: 66
# Spike time: 5208 (iter. 5208) at neuron: 105
# Spike time: 5389 (iter. 5389) at neuron: 66
# Spike time: 5390 (iter. 5390) at neuron: 105
# Spike time: 5572 (iter. 5572) at neuron: 66
# Spike time: 5572 (iter. 5572) at neuron: 105
# Spike time: 5754 (iter. 5754) at neuron: 105
# Spike time: 5756 (iter. 5756) at neuron: 66
# Spike time: 5936 (iter. 5936) at neuron: 105
# Spike time: 5940 (iter. 5940) at neuron: 66
# Spike time: 6118 (iter. 6118) at neuron: 105
# Spike time: 6124 (iter. 6124) at neuron: 66
# Spike time: 6173 (iter. 6173) at neuron: 167
# Spike time: 6174 (iter. 6174) at neuron: 22
# Spike time: 6174 (iter. 6174) at neuron: 109
# Spike time: 6174 (iter. 6174) at neuron: 146
# Spike time: 6181 (iter. 6181) at neuron: 60
# Spike time: 6181 (iter. 6181) at neuron: 126
# Spike time: 6181 (iter. 6181) at neuron: 232
# Spike time: 6182 (iter. 6182) at neuron: 0
# Spike time: 6182 (iter. 6182) at neuron: 1
# Spike time: 6182 (iter. 6182) at neuron: 3
# Spike time: 6182 (iter. 6182) at neuron: 6
# Spike time: 6182 (iter. 6182) at neuron: 8
# Spike time: 6182 (iter. 6182) at neuron: 11
# Spike time: 6182 (iter. 6182) at neuron: 13
# Spike time: 6182 (iter. 6182) at neuron: 15
# Spike time: 6182 (iter. 6182) at neuron: 16
# Spike time: 6182 (iter. 6182) at neuron: 17
# Spike time: 6182 (iter. 6182) at neuron: 18
# Spike time: 6182 (iter. 6182) at neuron: 20
# Spike time: 6182 (iter. 6182) at neuron: 28
# Spike time: 6182 (iter. 6182) at neuron: 31
# Spike time: 6182 (iter. 6182) at neuron: 34
# Spike time: 6182 (iter. 6182) at neuron: 43
# Spike time: 6182 (iter. 6182) at neuron: 45
# Spike time: 6182 (iter. 6182) at neuron: 46
# Spike time: 6182 (iter. 6182) at neuron: 50
# Spike time: 6182 (iter. 6182) at neuron: 51
# Spike time: 6182 (iter. 6182) at neuron: 52
# Spike time: 6182 (iter. 6182) at neuron: 54
# Spike time: 6182 (iter. 6182) at neuron: 56
# Spike time: 6182 (iter. 6182) at neuron: 57
# Spike time: 6182 (iter. 6182) at neuron: 59
# Spike time: 6182 (iter. 6182) at neuron: 63
# Spike time: 6182 (iter. 6182) at neuron: 64
# Spike time: 6182 (iter. 6182) at neuron: 65
# Spike time: 6182 (iter. 6182) at neuron: 72
# Spike time: 6182 (iter. 6182) at neuron: 73
# Spike time: 6182 (iter. 6182) at neuron: 75
# Spike time: 6182 (iter. 6182) at neuron: 76
# Spike time: 6182 (iter. 6182) at neuron: 79
# Spike time: 6182 (iter. 6182) at neuron: 82
# Spike time: 6182 (iter. 6182) at neuron: 83
# Spike time: 6182 (iter. 6182) at neuron: 84
# Spike time: 6182 (iter. 6182) at neuron: 85
# Spike time: 6182 (iter. 6182) at neuron: 86
# Spike time: 6182 (iter. 6182) at neuron: 87
# Spike time: 6182 (iter. 6182) at neuron: 89
# Spike time: 6182 (iter. 6182) at neuron: 90
# Spike time: 6182 (iter. 6182) at neuron: 91
# Spike time: 6182 (iter. 6182) at neuron: 95
# Spike time: 6182 (iter. 6182) at neuron: 97
# Spike time: 6182 (iter. 6182) at neuron: 106
# Spike time: 6182 (iter. 6182) at neuron: 111
# Spike time: 6182 (iter. 6182) at neuron: 112
# Spike time: 6182 (iter. 6182) at neuron: 113
# Spike time: 6182 (iter. 6182) at neuron: 115
# Spike time: 6182 (iter. 6182) at neuron: 116
# Spike time: 6182 (iter. 6182) at neuron: 118
# Spike time: 6182 (iter. 6182) at neuron: 124
# Spike time: 6182 (iter. 6182) at neuron: 125
# Spike time: 6182 (iter. 6182) at neuron: 136
# Spike time: 6182 (iter. 6182) at neuron: 138
# Spike time: 6182 (iter. 6182) at neuron: 140
# Spike time: 6182 (iter. 6182) at neuron: 147
# Spike time: 6182 (iter. 6182) at neuron: 150
# Spike time: 6182 (iter. 6182) at neuron: 152
# Spike time: 6182 (iter. 6182) at neuron: 156
# Spike time: 6182 (iter. 6182) at neuron: 157
# Spike time: 6182 (iter. 6182) at neuron: 158
# Spike time: 6182 (iter. 6182) at neuron: 160
# Spike time: 6182 (iter. 6182) at neuron: 161
# Spike time: 6182 (iter. 6182) at neuron: 163
# Spike time: 6182 (iter. 6182) at neuron: 164
# Spike time: 6182 (iter. 6182) at neuron: 168
# Spike time: 6182 (iter. 6182) at neuron: 171
# Spike time: 6182 (iter. 6182) at neuron: 173
# Spike time: 6182 (iter. 6182) at neuron: 176
# Spike time: 6182 (iter. 6182) at neuron: 178
# Spike time: 6182 (iter. 6182) at neuron: 181
# Spike time: 6182 (iter. 6182) at neuron: 188
# Spike time: 6182 (iter. 6182) at neuron: 190
# Spike time: 6182 (iter. 6182) at neuron: 192
# Spike time: 6182 (iter. 6182) at neuron: 193
# Spike time: 6182 (iter. 6182) at neuron: 194
# Spike time: 6182 (iter. 6182) at neuron: 196
# Spike time: 6182 (iter. 6182) at neuron: 198
# Spike time: 6182 (iter. 6182) at neuron: 201
# Spike time: 6182 (iter. 6182) at neuron: 205
# Spike time: 6182 (iter. 6182) at neuron: 207
# Spike time: 6182 (iter. 6182) at neuron: 213
# Spike time: 6182 (iter. 6182) at neuron: 214
# Spike time: 6182 (iter. 6182) at neuron: 222
# Spike time: 6182 (iter. 6182) at neuron: 228
# Spike time: 6182 (iter. 6182) at neuron: 229
# Spike time: 6182 (iter. 6182) at neuron: 234
# Spike time: 6182 (iter. 6182) at neuron: 236
# Spike time: 6182 (iter. 6182) at neuron: 237
# Spike time: 6182 (iter. 6182) at neuron: 238
# Spike time: 6182 (iter. 6182) at neuron: 239
# Spike time: 6182 (iter. 6182) at neuron: 241
# Spike time: 6182 (iter. 6182) at neuron: 243
# Spike time: 6182 (iter. 6182) at neuron: 244
# Spike time: 6182 (iter. 6182) at neuron: 250
# Spike time: 6182 (iter. 6182) at neuron: 253
# Spike time: 6182 (iter. 6182) at neuron: 254
# Spike time: 6183 (iter. 6183) at neuron: 4
# Spike time: 6183 (iter. 6183) at neuron: 9
# Spike time: 6183 (iter. 6183) at neuron: 14
# Spike time: 6183 (iter. 6183) at neuron: 27
# Spike time: 6183 (iter. 6183) at neuron: 36
# Spike time: 6183 (iter. 6183) at neuron: 40
# Spike time: 6183 (iter. 6183) at neuron: 42
# Spike time: 6183 (iter. 6183) at neuron: 48
# Spike time: 6183 (iter. 6183) at neuron: 49
# Spike time: 6183 (iter. 6183) at neuron: 55
# Spike time: 6183 (iter. 6183) at neuron: 71
# Spike time: 6183 (iter. 6183) at neuron: 78
# Spike time: 6183 (iter. 6183) at neuron: 99
# Spike time: 6183 (iter. 6183) at neuron: 117
# Spike time: 6183 (iter. 6183) at neuron: 123
# Spike time: 6183 (iter. 6183) at neuron: 129
# Spike time: 6183 (iter. 6183) at neuron: 151
# Spike time: 6183 (iter. 6183) at neuron: 155
# Spike time: 6183 (iter. 6183) at neuron: 165
# Spike time: 6183 (iter. 6183) at neuron: 172
# Spike time: 6183 (iter. 6183) at neuron: 175
# Spike time: 6183 (iter. 6183) at neuron: 179
# Spike time: 6183 (iter. 6183) at neuron: 180
# Spike time: 6183 (iter. 6183) at neuron: 183
# Spike time: 6183 (iter. 6183) at neuron: 186
# Spike time: 6183 (iter. 6183) at neuron: 187
# Spike time: 6183 (iter. 6183) at neuron: 210
# Spike time: 6183 (iter. 6183) at neuron: 211
# Spike time: 6183 (iter. 6183) at neuron: 217
# Spike time: 6183 (iter. 6183) at neuron: 227
# Spike time: 6191 (iter. 6191) at neuron: 120
# Spike time: 6191 (iter. 6191) at neuron: 162
# Spike time: 6191 (iter. 6191) at neuron: 191
# Spike time: 6192 (iter. 6192) at neuron: 30
# Spike time: 6192 (iter. 6192) at neuron: 47
# Spike time: 6192 (iter. 6192) at neuron: 68
# Spike time: 6192 (iter. 6192) at neuron: 247
# Spike time: 6193 (iter. 6193) at neuron: 132
# Spike time: 6193 (iter. 6193) at neuron: 148
# Spike time: 6193 (iter. 6193) at neuron: 208
# Spike time: 6193 (iter. 6193) at neuron: 235
# Spike time: 6202 (iter. 6202) at neuron: 33
# Spike time: 6202 (iter. 6202) at neuron: 130
# Spike time: 6202 (iter. 6202) at neuron: 134
# Spike time: 6202 (iter. 6202) at neuron: 144
# Spike time: 6202 (iter. 6202) at neuron: 177
# Spike time: 6203 (iter. 6203) at neuron: 24
# Spike time: 6203 (iter. 6203) at neuron: 70
# Spike time: 6203 (iter. 6203) at neuron: 142
# Spike time: 6300 (iter. 6300) at neuron: 105
# Spike time: 6308 (iter. 6308) at neuron: 66
# Spike time: 6368 (iter. 6368) at neuron: 91
# Spike time: 6373 (iter. 6373) at neuron: 151
# Spike time: 6376 (iter. 6376) at neuron: 43
# Spike time: 6482 (iter. 6482) at neuron: 105
# Spike time: 6492 (iter. 6492) at neuron: 66
# Spike time: 6555 (iter. 6555) at neuron: 91
# Spike time: 6568 (iter. 6568) at neuron: 151
# Spike time: 6664 (iter. 6664) at neuron: 105
# Spike time: 6675 (iter. 6675) at neuron: 66
# Spike time: 6675 (iter. 6675) at neuron: 167
# Spike time: 6676 (iter. 6676) at neuron: 22
# Spike time: 6676 (iter. 6676) at neuron: 43
# Spike time: 6676 (iter. 6676) at neuron: 109
# Spike time: 6676 (iter. 6676) at neuron: 146
# Spike time: 6677 (iter. 6677) at neuron: 11
# Spike time: 6677 (iter. 6677) at neuron: 18
# Spike time: 6677 (iter. 6677) at neuron: 52
# Spike time: 6677 (iter. 6677) at neuron: 60
# Spike time: 6677 (iter. 6677) at neuron: 72
# Spike time: 6677 (iter. 6677) at neuron: 106
# Spike time: 6677 (iter. 6677) at neuron: 124
# Spike time: 6677 (iter. 6677) at neuron: 125
# Spike time: 6677 (iter. 6677) at neuron: 152
# Spike time: 6677 (iter. 6677) at neuron: 196
# Spike time: 6677 (iter. 6677) at neuron: 201
# Spike time: 6677 (iter. 6677) at neuron: 207
# Spike time: 6677 (iter. 6677) at neuron: 213
# Spike time: 6677 (iter. 6677) at neuron: 238
# Spike time: 6684 (iter. 6684) at neuron: 126
# Spike time: 6684 (iter. 6684) at neuron: 232
# Spike time: 6685 (iter. 6685) at neuron: 0
# Spike time: 6685 (iter. 6685) at neuron: 1
# Spike time: 6685 (iter. 6685) at neuron: 3
# Spike time: 6685 (iter. 6685) at neuron: 6
# Spike time: 6685 (iter. 6685) at neuron: 13
# Spike time: 6685 (iter. 6685) at neuron: 15
# Spike time: 6685 (iter. 6685) at neuron: 17
# Spike time: 6685 (iter. 6685) at neuron: 20
# Spike time: 6685 (iter. 6685) at neuron: 27
# Spike time: 6685 (iter. 6685) at neuron: 28
# Spike time: 6685 (iter. 6685) at neuron: 31
# Spike time: 6685 (iter. 6685) at neuron: 34
# Spike time: 6685 (iter. 6685) at neuron: 45
# Spike time: 6685 (iter. 6685) at neuron: 50
# Spike time: 6685 (iter. 6685) at neuron: 51
# Spike time: 6685 (iter. 6685) at neuron: 54
# Spike time: 6685 (iter. 6685) at neuron: 56
# Spike time: 6685 (iter. 6685) at neuron: 57
# Spike time: 6685 (iter. 6685) at neuron: 59
# Spike time: 6685 (iter. 6685) at neuron: 63
# Spike time: 6685 (iter. 6685) at neuron: 64
# Spike time: 6685 (iter. 6685) at neuron: 65
# Spike time: 6685 (iter. 6685) at neuron: 73
# Spike time: 6685 (iter. 6685) at neuron: 75
# Spike time: 6685 (iter. 6685) at neuron: 76
# Spike time: 6685 (iter. 6685) at neuron: 79
# Spike time: 6685 (iter. 6685) at neuron: 82
# Spike time: 6685 (iter. 6685) at neuron: 83
# Spike time: 6685 (iter. 6685) at neuron: 84
# Spike time: 6685 (iter. 6685) at neuron: 85
# Spike time: 6685 (iter. 6685) at neuron: 86
# Spike time: 6685 (iter. 6685) at neuron: 87
# Spike time: 6685 (iter. 6685) at neuron: 89
# Spike time: 6685 (iter. 6685) at neuron: 90
# Spike time: 6685 (iter. 6685) at neuron: 95
# Spike time: 6685 (iter. 6685) at neuron: 97
# Spike time: 6685 (iter. 6685) at neuron: 111
# Spike time: 6685 (iter. 6685) at neuron: 112
# Spike time: 6685 (iter. 6685) at neuron: 113
# Spike time: 6685 (iter. 6685) at neuron: 115
# Spike time: 6685 (iter. 6685) at neuron: 116
# Spike time: 6685 (iter. 6685) at neuron: 117
# Spike time: 6685 (iter. 6685) at neuron: 118
# Spike time: 6685 (iter. 6685) at neuron: 136
# Spike time: 6685 (iter. 6685) at neuron: 138
# Spike time: 6685 (iter. 6685) at neuron: 140
# Spike time: 6685 (iter. 6685) at neuron: 147
# Spike time: 6685 (iter. 6685) at neuron: 150
# Spike time: 6685 (iter. 6685) at neuron: 156
# Spike time: 6685 (iter. 6685) at neuron: 157
# Spike time: 6685 (iter. 6685) at neuron: 158
# Spike time: 6685 (iter. 6685) at neuron: 160
# Spike time: 6685 (iter. 6685) at neuron: 161
# Spike time: 6685 (iter. 6685) at neuron: 163
# Spike time: 6685 (iter. 6685) at neuron: 164
# Spike time: 6685 (iter. 6685) at neuron: 168
# Spike time: 6685 (iter. 6685) at neuron: 171
# Spike time: 6685 (iter. 6685) at neuron: 173
# Spike time: 6685 (iter. 6685) at neuron: 176
# Spike time: 6685 (iter. 6685) at neuron: 178
# Spike time: 6685 (iter. 6685) at neuron: 181
# Spike time: 6685 (iter. 6685) at neuron: 188
# Spike time: 6685 (iter. 6685) at neuron: 190
# Spike time: 6685 (iter. 6685) at neuron: 192
# Spike time: 6685 (iter. 6685) at neuron: 193
# Spike time: 6685 (iter. 6685) at neuron: 194
# Spike time: 6685 (iter. 6685) at neuron: 198
# Spike time: 6685 (iter. 6685) at neuron: 205
# Spike time: 6685 (iter. 6685) at neuron: 214
# Spike time: 6685 (iter. 6685) at neuron: 222
# Spike time: 6685 (iter. 6685) at neuron: 228
# Spike time: 6685 (iter. 6685) at neuron: 229
# Spike time: 6685 (iter. 6685) at neuron: 234
# Spike time: 6685 (iter. 6685) at neuron: 236
# Spike time: 6685 (iter. 6685) at neuron: 237
# Spike time: 6685 (iter. 6685) at neuron: 239
# Spike time: 6685 (iter. 6685) at neuron: 241
# Spike time: 6685 (iter. 6685) at neuron: 243
# Spike time: 6685 (iter. 6685) at neuron: 244
# Spike time: 6685 (iter. 6685) at neuron: 254
# Spike time: 6686 (iter. 6686) at neuron: 4
# Spike time: 6686 (iter. 6686) at neuron: 8
# Spike time: 6686 (iter. 6686) at neuron: 9
# Spike time: 6686 (iter. 6686) at neuron: 14
# Spike time: 6686 (iter. 6686) at neuron: 16
# Spike time: 6686 (iter. 6686) at neuron: 36
# Spike time: 6686 (iter. 6686) at neuron: 40
# Spike time: 6686 (iter. 6686) at neuron: 46
# Spike time: 6686 (iter. 6686) at neuron: 48
# Spike time: 6686 (iter. 6686) at neuron: 49
# Spike time: 6686 (iter. 6686) at neuron: 55
# Spike time: 6686 (iter. 6686) at neuron: 71
# Spike time: 6686 (iter. 6686) at neuron: 78
# Spike time: 6686 (iter. 6686) at neuron: 129
# Spike time: 6686 (iter. 6686) at neuron: 155
# Spike time: 6686 (iter. 6686) at neuron: 165
# Spike time: 6686 (iter. 6686) at neuron: 172
# Spike time: 6686 (iter. 6686) at neuron: 175
# Spike time: 6686 (iter. 6686) at neuron: 179
# Spike time: 6686 (iter. 6686) at neuron: 186
# Spike time: 6686 (iter. 6686) at neuron: 187
# Spike time: 6686 (iter. 6686) at neuron: 210
# Spike time: 6686 (iter. 6686) at neuron: 211
# Spike time: 6686 (iter. 6686) at neuron: 217
# Spike time: 6686 (iter. 6686) at neuron: 227
# Spike time: 6686 (iter. 6686) at neuron: 250
# Spike time: 6687 (iter. 6687) at neuron: 162
# Spike time: 6694 (iter. 6694) at neuron: 30
# Spike time: 6694 (iter. 6694) at neuron: 42
# Spike time: 6694 (iter. 6694) at neuron: 47
# Spike time: 6694 (iter. 6694) at neuron: 120
# Spike time: 6694 (iter. 6694) at neuron: 177
# Spike time: 6694 (iter. 6694) at neuron: 191
# Spike time: 6694 (iter. 6694) at neuron: 247
# Spike time: 6694 (iter. 6694) at neuron: 253
# Spike time: 6695 (iter. 6695) at neuron: 5
# Spike time: 6695 (iter. 6695) at neuron: 24
# Spike time: 6695 (iter. 6695) at neuron: 25
# Spike time: 6695 (iter. 6695) at neuron: 26
# Spike time: 6695 (iter. 6695) at neuron: 33
# Spike time: 6695 (iter. 6695) at neuron: 58
# Spike time: 6695 (iter. 6695) at neuron: 68
# Spike time: 6695 (iter. 6695) at neuron: 69
# Spike time: 6695 (iter. 6695) at neuron: 70
# Spike time: 6695 (iter. 6695) at neuron: 74
# Spike time: 6695 (iter. 6695) at neuron: 80
# Spike time: 6695 (iter. 6695) at neuron: 88
# Spike time: 6695 (iter. 6695) at neuron: 93
# Spike time: 6695 (iter. 6695) at neuron: 99
# Spike time: 6695 (iter. 6695) at neuron: 108
# Spike time: 6695 (iter. 6695) at neuron: 110
# Spike time: 6695 (iter. 6695) at neuron: 122
# Spike time: 6695 (iter. 6695) at neuron: 123
# Spike time: 6695 (iter. 6695) at neuron: 130
# Spike time: 6695 (iter. 6695) at neuron: 132
# Spike time: 6695 (iter. 6695) at neuron: 133
# Spike time: 6695 (iter. 6695) at neuron: 134
# Spike time: 6695 (iter. 6695) at neuron: 135
# Spike time: 6695 (iter. 6695) at neuron: 141
# Spike time: 6695 (iter. 6695) at neuron: 142
# Spike time: 6695 (iter. 6695) at neuron: 144
# Spike time: 6695 (iter. 6695) at neuron: 145
# Spike time: 6695 (iter. 6695) at neuron: 148
# Spike time: 6695 (iter. 6695) at neuron: 149
# Spike time: 6695 (iter. 6695) at neuron: 153
# Spike time: 6695 (iter. 6695) at neuron: 159
# Spike time: 6695 (iter. 6695) at neuron: 166
# Spike time: 6695 (iter. 6695) at neuron: 170
# Spike time: 6695 (iter. 6695) at neuron: 180
# Spike time: 6695 (iter. 6695) at neuron: 183
# Spike time: 6695 (iter. 6695) at neuron: 199
# Spike time: 6695 (iter. 6695) at neuron: 202
# Spike time: 6695 (iter. 6695) at neuron: 203
# Spike time: 6695 (iter. 6695) at neuron: 208
# Spike time: 6695 (iter. 6695) at neuron: 209
# Spike time: 6695 (iter. 6695) at neuron: 235
# Spike time: 6695 (iter. 6695) at neuron: 251
# Spike time: 6695 (iter. 6695) at neuron: 252
# Spike time: 6696 (iter. 6696) at neuron: 98
# Spike time: 6696 (iter. 6696) at neuron: 182
# Spike time: 6696 (iter. 6696) at neuron: 215
# Spike time: 6715 (iter. 6715) at neuron: 216
# Spike time: 6717 (iter. 6717) at neuron: 218
# Spike time: 6718 (iter. 6718) at neuron: 10
# Spike time: 6718 (iter. 6718) at neuron: 67
# Spike time: 6718 (iter. 6718) at neuron: 226
# Spike time: 6719 (iter. 6719) at neuron: 21
# Spike time: 6719 (iter. 6719) at neuron: 189
# Spike time: 6719 (iter. 6719) at neuron: 223
# Spike time: 6719 (iter. 6719) at neuron: 242
# Spike time: 6739 (iter. 6739) at neuron: 91
# Spike time: 6751 (iter. 6751) at neuron: 151
# Spike time: 6857 (iter. 6857) at neuron: 66
# Spike time: 6859 (iter. 6859) at neuron: 43
# Spike time: 6861 (iter. 6861) at neuron: 106
# Spike time: 6861 (iter. 6861) at neuron: 167
# Spike time: 6862 (iter. 6862) at neuron: 125
# Spike time: 6869 (iter. 6869) at neuron: 117
# Spike time: 6889 (iter. 6889) at neuron: 84
# Spike time: 6915 (iter. 6915) at neuron: 120
# Spike time: 6921 (iter. 6921) at neuron: 91
# Spike time: 6934 (iter. 6934) at neuron: 151
# Spike time: 7039 (iter. 7039) at neuron: 66
# Spike time: 7045 (iter. 7045) at neuron: 43
# Spike time: 7104 (iter. 7104) at neuron: 91
# Spike time: 7120 (iter. 7120) at neuron: 151
# Spike time: 7221 (iter. 7221) at neuron: 66
# Spike time: 7260 (iter. 7260) at neuron: 109
# Spike time: 7267 (iter. 7267) at neuron: 126
# Spike time: 7268 (iter. 7268) at neuron: 6
# Spike time: 7268 (iter. 7268) at neuron: 11
# Spike time: 7268 (iter. 7268) at neuron: 54
# Spike time: 7268 (iter. 7268) at neuron: 60
# Spike time: 7268 (iter. 7268) at neuron: 72
# Spike time: 7268 (iter. 7268) at neuron: 87
# Spike time: 7268 (iter. 7268) at neuron: 138
# Spike time: 7268 (iter. 7268) at neuron: 146
# Spike time: 7268 (iter. 7268) at neuron: 157
# Spike time: 7268 (iter. 7268) at neuron: 181
# Spike time: 7268 (iter. 7268) at neuron: 192
# Spike time: 7268 (iter. 7268) at neuron: 196
# Spike time: 7268 (iter. 7268) at neuron: 232
# Spike time: 7268 (iter. 7268) at neuron: 239
# Spike time: 7268 (iter. 7268) at neuron: 244
# Spike time: 7269 (iter. 7269) at neuron: 1
# Spike time: 7269 (iter. 7269) at neuron: 50
# Spike time: 7269 (iter. 7269) at neuron: 56
# Spike time: 7269 (iter. 7269) at neuron: 64
# Spike time: 7269 (iter. 7269) at neuron: 65
# Spike time: 7269 (iter. 7269) at neuron: 76
# Spike time: 7269 (iter. 7269) at neuron: 82
# Spike time: 7269 (iter. 7269) at neuron: 83
# Spike time: 7269 (iter. 7269) at neuron: 85
# Spike time: 7269 (iter. 7269) at neuron: 86
# Spike time: 7269 (iter. 7269) at neuron: 95
# Spike time: 7269 (iter. 7269) at neuron: 97
# Spike time: 7269 (iter. 7269) at neuron: 112
# Spike time: 7269 (iter. 7269) at neuron: 116
# Spike time: 7269 (iter. 7269) at neuron: 140
# Spike time: 7269 (iter. 7269) at neuron: 150
# Spike time: 7269 (iter. 7269) at neuron: 152
# Spike time: 7269 (iter. 7269) at neuron: 161
# Spike time: 7269 (iter. 7269) at neuron: 168
# Spike time: 7269 (iter. 7269) at neuron: 176
# Spike time: 7269 (iter. 7269) at neuron: 178
# Spike time: 7269 (iter. 7269) at neuron: 188
# Spike time: 7269 (iter. 7269) at neuron: 198
# Spike time: 7269 (iter. 7269) at neuron: 201
# Spike time: 7269 (iter. 7269) at neuron: 228
# Spike time: 7269 (iter. 7269) at neuron: 229
# Spike time: 7269 (iter. 7269) at neuron: 237
# Spike time: 7269 (iter. 7269) at neuron: 238
# Spike time: 7269 (iter. 7269) at neuron: 241
# Spike time: 7269 (iter. 7269) at neuron: 243
# Spike time: 7269 (iter. 7269) at neuron: 254
# Spike time: 7270 (iter. 7270) at neuron: 8
# Spike time: 7270 (iter. 7270) at neuron: 13
# Spike time: 7270 (iter. 7270) at neuron: 17
# Spike time: 7270 (iter. 7270) at neuron: 18
# Spike time: 7270 (iter. 7270) at neuron: 20
# Spike time: 7270 (iter. 7270) at neuron: 22
# Spike time: 7270 (iter. 7270) at neuron: 31
# Spike time: 7270 (iter. 7270) at neuron: 52
# Spike time: 7270 (iter. 7270) at neuron: 73
# Spike time: 7270 (iter. 7270) at neuron: 79
# Spike time: 7270 (iter. 7270) at neuron: 89
# Spike time: 7270 (iter. 7270) at neuron: 90
# Spike time: 7270 (iter. 7270) at neuron: 136
# Spike time: 7270 (iter. 7270) at neuron: 158
# Spike time: 7270 (iter. 7270) at neuron: 164
# Spike time: 7270 (iter. 7270) at neuron: 171
# Spike time: 7270 (iter. 7270) at neuron: 190
# Spike time: 7270 (iter. 7270) at neuron: 193
# Spike time: 7270 (iter. 7270) at neuron: 207
# Spike time: 7270 (iter. 7270) at neuron: 213
# Spike time: 7270 (iter. 7270) at neuron: 234
# Spike time: 7281 (iter. 7281) at neuron: 63
# Spike time: 7281 (iter. 7281) at neuron: 111
# Spike time: 7281 (iter. 7281) at neuron: 113
# Spike time: 7281 (iter. 7281) at neuron: 172
# Spike time: 7282 (iter. 7282) at neuron: 45
# Spike time: 7305 (iter. 7305) at neuron: 236
# Spike time: 7306 (iter. 7306) at neuron: 162
# Spike time: 7307 (iter. 7307) at neuron: 125
# Spike time: 7307 (iter. 7307) at neuron: 173
# Spike time: 7307 (iter. 7307) at neuron: 191
# Spike time: 7339 (iter. 7339) at neuron: 91
# Spike time: 7355 (iter. 7355) at neuron: 151
# Spike time: 7404 (iter. 7404) at neuron: 66
# Spike time: 7526 (iter. 7526) at neuron: 91
# Spike time: 7548 (iter. 7548) at neuron: 151
# Spike time: 7587 (iter. 7587) at neuron: 66
# Spike time: 7601 (iter. 7601) at neuron: 43
# Spike time: 7601 (iter. 7601) at neuron: 167
# Spike time: 7602 (iter. 7602) at neuron: 22
# Spike time: 7602 (iter. 7602) at neuron: 106
# Spike time: 7602 (iter. 7602) at neuron: 109
# Spike time: 7602 (iter. 7602) at neuron: 125
# Spike time: 7602 (iter. 7602) at neuron: 146
# Spike time: 7603 (iter. 7603) at neuron: 11
# Spike time: 7603 (iter. 7603) at neuron: 18
# Spike time: 7603 (iter. 7603) at neuron: 52
# Spike time: 7603 (iter. 7603) at neuron: 60
# Spike time: 7603 (iter. 7603) at neuron: 72
# Spike time: 7603 (iter. 7603) at neuron: 124
# Spike time: 7603 (iter. 7603) at neuron: 152
# Spike time: 7603 (iter. 7603) at neuron: 196
# Spike time: 7603 (iter. 7603) at neuron: 201
# Spike time: 7603 (iter. 7603) at neuron: 207
# Spike time: 7603 (iter. 7603) at neuron: 213
# Spike time: 7603 (iter. 7603) at neuron: 238
# Spike time: 7614 (iter. 7614) at neuron: 84
# Spike time: 7614 (iter. 7614) at neuron: 90
# Spike time: 7614 (iter. 7614) at neuron: 95
# Spike time: 7615 (iter. 7615) at neuron: 0
# Spike time: 7615 (iter. 7615) at neuron: 20
# Spike time: 7615 (iter. 7615) at neuron: 63
# Spike time: 7615 (iter. 7615) at neuron: 85
# Spike time: 7615 (iter. 7615) at neuron: 113
# ...
# Spike time: 116018 (iter. 116018) at neuron: 106
# Spike time: 116018 (iter. 116018) at neuron: 124
# Spike time: 116018 (iter. 116018) at neuron: 125
# Spike time: 116018 (iter. 116018) at neuron: 152
# Spike time: 116018 (iter. 116018) at neuron: 196
# Spike time: 116018 (iter. 116018) at neuron: 201
# Spike time: 116018 (iter. 116018) at neuron: 207
# Spike time: 116018 (iter. 116018) at neuron: 213
# Spike time: 116018 (iter. 116018) at neuron: 238
# Spike time: 116019 (iter. 116019) at neuron: 0
# Spike time: 116019 (iter. 116019) at neuron: 63
# Spike time: 116019 (iter. 116019) at neuron: 82
# Spike time: 116019 (iter. 116019) at neuron: 84
# Spike time: 116019 (iter. 116019) at neuron: 90
# Spike time: 116019 (iter. 116019) at neuron: 95
# Spike time: 116019 (iter. 116019) at neuron: 138
# Spike time: 116019 (iter. 116019) at neuron: 140
# Spike time: 116019 (iter. 116019) at neuron: 173
# Spike time: 116019 (iter. 116019) at neuron: 178
# Spike time: 116019 (iter. 116019) at neuron: 190
# Spike time: 116019 (iter. 116019) at neuron: 236
# Spike time: 116019 (iter. 116019) at neuron: 237
# Spike time: 116019 (iter. 116019) at neuron: 244
# Spike time: 116020 (iter. 116020) at neuron: 20
# Spike time: 116020 (iter. 116020) at neuron: 43
# Spike time: 116020 (iter. 116020) at neuron: 65
# Spike time: 116020 (iter. 116020) at neuron: 85
# Spike time: 116020 (iter. 116020) at neuron: 112
# Spike time: 116020 (iter. 116020) at neuron: 113
# Spike time: 116020 (iter. 116020) at neuron: 150
# Spike time: 116020 (iter. 116020) at neuron: 151
# Spike time: 116020 (iter. 116020) at neuron: 163
# Spike time: 116020 (iter. 116020) at neuron: 181
# Spike time: 116020 (iter. 116020) at neuron: 188
# Spike time: 116028 (iter. 116028) at neuron: 15
# Spike time: 116028 (iter. 116028) at neuron: 45
# Spike time: 116029 (iter. 116029) at neuron: 27
# Spike time: 116029 (iter. 116029) at neuron: 211
# Spike time: 116030 (iter. 116030) at neuron: 3
# Spike time: 116030 (iter. 116030) at neuron: 55
# Spike time: 116030 (iter. 116030) at neuron: 117
# Spike time: 116031 (iter. 116031) at neuron: 120
# Spike time: 116031 (iter. 116031) at neuron: 175
# Spike time: 116034 (iter. 116034) at neuron: 129
# Spike time: 116040 (iter. 116040) at neuron: 126
# Spike time: 116041 (iter. 116041) at neuron: 1
# Spike time: 116041 (iter. 116041) at neuron: 6
# Spike time: 116041 (iter. 116041) at neuron: 13
# Spike time: 116041 (iter. 116041) at neuron: 31
# Spike time: 116041 (iter. 116041) at neuron: 50
# Spike time: 116041 (iter. 116041) at neuron: 51
# Spike time: 116041 (iter. 116041) at neuron: 54
# Spike time: 116041 (iter. 116041) at neuron: 56
# Spike time: 116041 (iter. 116041) at neuron: 59
# Spike time: 116041 (iter. 116041) at neuron: 64
# Spike time: 116041 (iter. 116041) at neuron: 76
# Spike time: 116041 (iter. 116041) at neuron: 79
# Spike time: 116041 (iter. 116041) at neuron: 83
# Spike time: 116041 (iter. 116041) at neuron: 86
# Spike time: 116041 (iter. 116041) at neuron: 87
# Spike time: 116041 (iter. 116041) at neuron: 97
# Spike time: 116041 (iter. 116041) at neuron: 116
# Spike time: 116041 (iter. 116041) at neuron: 157
# Spike time: 116041 (iter. 116041) at neuron: 161
# Spike time: 116041 (iter. 116041) at neuron: 164
# Spike time: 116041 (iter. 116041) at neuron: 165
# Spike time: 116041 (iter. 116041) at neuron: 168
# Spike time: 116041 (iter. 116041) at neuron: 176
# Spike time: 116041 (iter. 116041) at neuron: 192
# Spike time: 116041 (iter. 116041) at neuron: 193
# Spike time: 116041 (iter. 116041) at neuron: 205
# Spike time: 116041 (iter. 116041) at neuron: 222
# Spike time: 116041 (iter. 116041) at neuron: 228
# Spike time: 116041 (iter. 116041) at neuron: 229
# Spike time: 116041 (iter. 116041) at neuron: 232
# Spike time: 116041 (iter. 116041) at neuron: 239
# Spike time: 116041 (iter. 116041) at neuron: 254
# Spike time: 116042 (iter. 116042) at neuron: 4
# Spike time: 116042 (iter. 116042) at neuron: 8
# Spike time: 116042 (iter. 116042) at neuron: 9
# Spike time: 116042 (iter. 116042) at neuron: 14
# Spike time: 116042 (iter. 116042) at neuron: 16
# Spike time: 116042 (iter. 116042) at neuron: 17
# Spike time: 116042 (iter. 116042) at neuron: 25
# Spike time: 116042 (iter. 116042) at neuron: 28
# Spike time: 116042 (iter. 116042) at neuron: 30
# Spike time: 116042 (iter. 116042) at neuron: 34
# Spike time: 116042 (iter. 116042) at neuron: 36
# Spike time: 116042 (iter. 116042) at neuron: 40
# Spike time: 116042 (iter. 116042) at neuron: 42
# Spike time: 116042 (iter. 116042) at neuron: 46
# Spike time: 116042 (iter. 116042) at neuron: 47
# Spike time: 116042 (iter. 116042) at neuron: 48
# Spike time: 116042 (iter. 116042) at neuron: 49
# Spike time: 116042 (iter. 116042) at neuron: 57
# Spike time: 116042 (iter. 116042) at neuron: 58
# Spike time: 116042 (iter. 116042) at neuron: 68
# Spike time: 116042 (iter. 116042) at neuron: 69
# Spike time: 116042 (iter. 116042) at neuron: 70
# Spike time: 116042 (iter. 116042) at neuron: 71
# Spike time: 116042 (iter. 116042) at neuron: 73
# Spike time: 116042 (iter. 116042) at neuron: 75
# Spike time: 116042 (iter. 116042) at neuron: 78
# Spike time: 116042 (iter. 116042) at neuron: 80
# Spike time: 116042 (iter. 116042) at neuron: 89
# Spike time: 116042 (iter. 116042) at neuron: 93
# Spike time: 116042 (iter. 116042) at neuron: 99
# Spike time: 116042 (iter. 116042) at neuron: 108
# Spike time: 116042 (iter. 116042) at neuron: 110
# Spike time: 116042 (iter. 116042) at neuron: 111
# Spike time: 116042 (iter. 116042) at neuron: 115
# Spike time: 116042 (iter. 116042) at neuron: 118
# Spike time: 116042 (iter. 116042) at neuron: 122
# Spike time: 116042 (iter. 116042) at neuron: 123
# Spike time: 116042 (iter. 116042) at neuron: 130
# Spike time: 116042 (iter. 116042) at neuron: 132
# Spike time: 116042 (iter. 116042) at neuron: 133
# Spike time: 116042 (iter. 116042) at neuron: 135
# Spike time: 116042 (iter. 116042) at neuron: 136
# Spike time: 116042 (iter. 116042) at neuron: 141
# Spike time: 116042 (iter. 116042) at neuron: 145
# Spike time: 116042 (iter. 116042) at neuron: 147
# Spike time: 116042 (iter. 116042) at neuron: 148
# Spike time: 116042 (iter. 116042) at neuron: 149
# Spike time: 116042 (iter. 116042) at neuron: 153
# Spike time: 116042 (iter. 116042) at neuron: 155
# Spike time: 116042 (iter. 116042) at neuron: 156
# Spike time: 116042 (iter. 116042) at neuron: 158
# Spike time: 116042 (iter. 116042) at neuron: 159
# Spike time: 116042 (iter. 116042) at neuron: 160
# Spike time: 116042 (iter. 116042) at neuron: 162
# Spike time: 116042 (iter. 116042) at neuron: 166
# Spike time: 116042 (iter. 116042) at neuron: 171
# Spike time: 116042 (iter. 116042) at neuron: 172
# Spike time: 116042 (iter. 116042) at neuron: 177
# Spike time: 116042 (iter. 116042) at neuron: 179
# Spike time: 116042 (iter. 116042) at neuron: 180
# Spike time: 116042 (iter. 116042) at neuron: 183
# Spike time: 116042 (iter. 116042) at neuron: 186
# Spike time: 116042 (iter. 116042) at neuron: 187
# Spike time: 116042 (iter. 116042) at neuron: 191
# Spike time: 116042 (iter. 116042) at neuron: 194
# Spike time: 116042 (iter. 116042) at neuron: 198
# Spike time: 116042 (iter. 116042) at neuron: 202
# Spike time: 116042 (iter. 116042) at neuron: 203
# Spike time: 116042 (iter. 116042) at neuron: 208
# Spike time: 116042 (iter. 116042) at neuron: 210
# Spike time: 116042 (iter. 116042) at neuron: 214
# Spike time: 116042 (iter. 116042) at neuron: 217
# Spike time: 116042 (iter. 116042) at neuron: 227
# Spike time: 116042 (iter. 116042) at neuron: 234
# Spike time: 116042 (iter. 116042) at neuron: 235
# Spike time: 116042 (iter. 116042) at neuron: 241
# Spike time: 116042 (iter. 116042) at neuron: 243
# Spike time: 116042 (iter. 116042) at neuron: 247
# Spike time: 116042 (iter. 116042) at neuron: 250
# Spike time: 116042 (iter. 116042) at neuron: 253
# Spike time: 116043 (iter. 116043) at neuron: 24
# Spike time: 116043 (iter. 116043) at neuron: 33
# Spike time: 116043 (iter. 116043) at neuron: 134
# Spike time: 116043 (iter. 116043) at neuron: 142
# Spike time: 116043 (iter. 116043) at neuron: 144
# Spike time: 116043 (iter. 116043) at neuron: 199
# Spike time: 116043 (iter. 116043) at neuron: 209
# Spike time: 116043 (iter. 116043) at neuron: 251
# Spike time: 116043 (iter. 116043) at neuron: 252
# Spike time: 116044 (iter. 116044) at neuron: 74
# Spike time: 116050 (iter. 116050) at neuron: 5
# Spike time: 116050 (iter. 116050) at neuron: 170
# Spike time: 116051 (iter. 116051) at neuron: 10
# Spike time: 116051 (iter. 116051) at neuron: 98
# Spike time: 116051 (iter. 116051) at neuron: 182
# Spike time: 116051 (iter. 116051) at neuron: 216
# Spike time: 116051 (iter. 116051) at neuron: 223
# Spike time: 116051 (iter. 116051) at neuron: 226
# Spike time: 116051 (iter. 116051) at neuron: 242
# Spike time: 116052 (iter. 116052) at neuron: 21
# Spike time: 116052 (iter. 116052) at neuron: 53
# Spike time: 116052 (iter. 116052) at neuron: 67
# Spike time: 116052 (iter. 116052) at neuron: 104
# Spike time: 116052 (iter. 116052) at neuron: 119
# Spike time: 116052 (iter. 116052) at neuron: 215
# Spike time: 116052 (iter. 116052) at neuron: 218
# Spike time: 116052 (iter. 116052) at neuron: 245
# Spike time: 116052 (iter. 116052) at neuron: 248
# Spike time: 116053 (iter. 116053) at neuron: 189
# Spike time: 116198 (iter. 116198) at neuron: 91
# Spike time: 116204 (iter. 116204) at neuron: 43
# Spike time: 116204 (iter. 116204) at neuron: 151
# Spike time: 116205 (iter. 116205) at neuron: 106
# Spike time: 116208 (iter. 116208) at neuron: 125
# Spike time: 116211 (iter. 116211) at neuron: 167
# Spike time: 116218 (iter. 116218) at neuron: 117
# Spike time: 116254 (iter. 116254) at neuron: 66
# Spike time: 116382 (iter. 116382) at neuron: 91
# Spike time: 116391 (iter. 116391) at neuron: 151
# Spike time: 116395 (iter. 116395) at neuron: 43
# Spike time: 116436 (iter. 116436) at neuron: 66
# Spike time: 116569 (iter. 116569) at neuron: 91
# Spike time: 116592 (iter. 116592) at neuron: 151
# Spike time: 116618 (iter. 116618) at neuron: 66
# Spike time: 116732 (iter. 116732) at neuron: 167
# Spike time: 116733 (iter. 116733) at neuron: 22
# Spike time: 116733 (iter. 116733) at neuron: 109
# Spike time: 116733 (iter. 116733) at neuron: 146
# Spike time: 116734 (iter. 116734) at neuron: 11
# Spike time: 116734 (iter. 116734) at neuron: 18
# Spike time: 116734 (iter. 116734) at neuron: 43
# Spike time: 116734 (iter. 116734) at neuron: 52
# Spike time: 116734 (iter. 116734) at neuron: 60
# Spike time: 116734 (iter. 116734) at neuron: 72
# Spike time: 116734 (iter. 116734) at neuron: 106
# Spike time: 116734 (iter. 116734) at neuron: 124
# Spike time: 116734 (iter. 116734) at neuron: 125
# Spike time: 116734 (iter. 116734) at neuron: 152
# Spike time: 116734 (iter. 116734) at neuron: 196
# Spike time: 116734 (iter. 116734) at neuron: 201
# Spike time: 116734 (iter. 116734) at neuron: 207
# Spike time: 116734 (iter. 116734) at neuron: 213
# Spike time: 116734 (iter. 116734) at neuron: 238
# Spike time: 116744 (iter. 116744) at neuron: 0
# Spike time: 116744 (iter. 116744) at neuron: 63
# Spike time: 116744 (iter. 116744) at neuron: 84
# Spike time: 116744 (iter. 116744) at neuron: 190
# Spike time: 116744 (iter. 116744) at neuron: 236
# Spike time: 116745 (iter. 116745) at neuron: 90
# Spike time: 116745 (iter. 116745) at neuron: 95
# Spike time: 116745 (iter. 116745) at neuron: 113
# Spike time: 116745 (iter. 116745) at neuron: 173
# Spike time: 116746 (iter. 116746) at neuron: 20
# Spike time: 116746 (iter. 116746) at neuron: 45
# Spike time: 116746 (iter. 116746) at neuron: 140
# Spike time: 116746 (iter. 116746) at neuron: 150
# Spike time: 116746 (iter. 116746) at neuron: 163
# Spike time: 116746 (iter. 116746) at neuron: 237
# Spike time: 116756 (iter. 116756) at neuron: 91
# Spike time: 116757 (iter. 116757) at neuron: 85
# Spike time: 116757 (iter. 116757) at neuron: 181
# Spike time: 116758 (iter. 116758) at neuron: 178
# Spike time: 116758 (iter. 116758) at neuron: 188
# Spike time: 116758 (iter. 116758) at neuron: 244
# Spike time: 116800 (iter. 116800) at neuron: 66
# Spike time: 116816 (iter. 116816) at neuron: 151
# Spike time: 116944 (iter. 116944) at neuron: 91
# Spike time: 116982 (iter. 116982) at neuron: 66
# Spike time: 117019 (iter. 117019) at neuron: 151
# Spike time: 117137 (iter. 117137) at neuron: 91
# Spike time: 117164 (iter. 117164) at neuron: 66
# Spike time: 117346 (iter. 117346) at neuron: 66
# Spike time: 117355 (iter. 117355) at neuron: 91
# Spike time: 117529 (iter. 117529) at neuron: 66
# Spike time: 117712 (iter. 117712) at neuron: 66
# Spike time: 117895 (iter. 117895) at neuron: 66
# Spike time: 118078 (iter. 118078) at neuron: 66
# Spike time: 118261 (iter. 118261) at neuron: 66
# Spike time: 118445 (iter. 118445) at neuron: 66
# Spike time: 118629 (iter. 118629) at neuron: 66
# Spike time: 118814 (iter. 118814) at neuron: 66
# Spike time: 118999 (iter. 118999) at neuron: 66
# Spike time: 119002 (iter. 119002) at neuron: 167
# Spike time: 119012 (iter. 119012) at neuron: 60
# Spike time: 119012 (iter. 119012) at neuron: 109
# Spike time: 119022 (iter. 119022) at neuron: 126
# Spike time: 119023 (iter. 119023) at neuron: 232
# Spike time: 119024 (iter. 119024) at neuron: 54
# Spike time: 119024 (iter. 119024) at neuron: 87
# Spike time: 119024 (iter. 119024) at neuron: 95
# Spike time: 119024 (iter. 119024) at neuron: 116
# Spike time: 119024 (iter. 119024) at neuron: 146
# Spike time: 119024 (iter. 119024) at neuron: 157
# Spike time: 119024 (iter. 119024) at neuron: 181
# Spike time: 119024 (iter. 119024) at neuron: 196
# Spike time: 119024 (iter. 119024) at neuron: 239
# Spike time: 119024 (iter. 119024) at neuron: 244
# Spike time: 119035 (iter. 119035) at neuron: 56
# Spike time: 119035 (iter. 119035) at neuron: 64
# Spike time: 119035 (iter. 119035) at neuron: 85
# Spike time: 119035 (iter. 119035) at neuron: 192
# Spike time: 119035 (iter. 119035) at neuron: 254
# Spike time: 119036 (iter. 119036) at neuron: 1
# Spike time: 119036 (iter. 119036) at neuron: 6
# Spike time: 119036 (iter. 119036) at neuron: 11
# Spike time: 119036 (iter. 119036) at neuron: 20
# Spike time: 119036 (iter. 119036) at neuron: 31
# Spike time: 119036 (iter. 119036) at neuron: 50
# Spike time: 119036 (iter. 119036) at neuron: 52
# Spike time: 119036 (iter. 119036) at neuron: 65
# Spike time: 119036 (iter. 119036) at neuron: 72
# Spike time: 119036 (iter. 119036) at neuron: 73
# Spike time: 119036 (iter. 119036) at neuron: 76
# Spike time: 119036 (iter. 119036) at neuron: 79
# Spike time: 119036 (iter. 119036) at neuron: 82
# Spike time: 119036 (iter. 119036) at neuron: 83
# Spike time: 119036 (iter. 119036) at neuron: 86
# Spike time: 119036 (iter. 119036) at neuron: 89
# Spike time: 119036 (iter. 119036) at neuron: 90
# Spike time: 119036 (iter. 119036) at neuron: 112
# Spike time: 119036 (iter. 119036) at neuron: 138
# Spike time: 119036 (iter. 119036) at neuron: 150
# Spike time: 119036 (iter. 119036) at neuron: 152
# Spike time: 119036 (iter. 119036) at neuron: 158
# Spike time: 119036 (iter. 119036) at neuron: 161
# Spike time: 119036 (iter. 119036) at neuron: 164
# Spike time: 119036 (iter. 119036) at neuron: 168
# Spike time: 119036 (iter. 119036) at neuron: 171
# Spike time: 119036 (iter. 119036) at neuron: 176
# Spike time: 119036 (iter. 119036) at neuron: 188
# Spike time: 119036 (iter. 119036) at neuron: 193
# Spike time: 119036 (iter. 119036) at neuron: 198
# Spike time: 119036 (iter. 119036) at neuron: 201
# Spike time: 119036 (iter. 119036) at neuron: 228
# Spike time: 119036 (iter. 119036) at neuron: 229
# Spike time: 119036 (iter. 119036) at neuron: 237
# Spike time: 119036 (iter. 119036) at neuron: 238
# Spike time: 119036 (iter. 119036) at neuron: 243
# Spike time: 119037 (iter. 119037) at neuron: 207
# Spike time: 119038 (iter. 119038) at neuron: 22
# Spike time: 119048 (iter. 119048) at neuron: 63
# Spike time: 119048 (iter. 119048) at neuron: 113
# Spike time: 119071 (iter. 119071) at neuron: 236
# Spike time: 119085 (iter. 119085) at neuron: 125
# Spike time: 119218 (iter. 119218) at neuron: 91
# Spike time: 119230 (iter. 119230) at neuron: 151
# Spike time: 119349 (iter. 119349) at neuron: 66
# Spike time: 119412 (iter. 119412) at neuron: 91
# Spike time: 119550 (iter. 119550) at neuron: 66
# Spike time: 119621 (iter. 119621) at neuron: 91
# Spike time: 119746 (iter. 119746) at neuron: 66
# Spike time: 119940 (iter. 119940) at neuron: 66

# %% [markdown]
# ## View the Voltage and Current dynamics with an interactive plot

# %% [markdown]
# Grab the data from the recorded variables

# %%
preview_np_array(lif1_voltage_vals, "Voltage Values", edge_items=3)
# Out:
# Voltage Values Shape: (120000, 256).
# Preview: [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  ...
#  [-1.49209613e-16  2.94219553e-48  1.80532877e-26 ...  4.74932520e-37
#    8.31724187e-41 -9.58786427e-25]
#  [-1.43492944e-16  2.68290475e-48  1.69747488e-26 ...  4.36187268e-37
#    7.71999308e-41 -9.06384880e-25]
#  [-1.37995298e-16  2.44646483e-48  1.59606439e-26 ...  4.00602874e-37
#    7.16563184e-41 -8.56847289e-25]]

# %% [markdown]
# ## Assemble the values to be plotted

# %%
from utils.line_plot import create_fig  # Import the function to create the figure
from bokeh.models import Range1d

# Define the x and y values
x = [val + init_offset for val in range(num_steps)]

v_y1 = [val[215] for val in lif1_voltage_vals]
v_y2 = [val[124] for val in lif1_voltage_vals]
v_y3 = [val[129] for val in lif1_voltage_vals]
v_y4 = [val[138] for val in lif1_voltage_vals]
v_y5 = [val[164] for val in lif1_voltage_vals]
v_y6 = [val[5] for val in lif1_voltage_vals]
v_y7 = [val[6] for val in lif1_voltage_vals]
v_y8 = [val[7] for val in lif1_voltage_vals]
v_y9 = [val[8] for val in lif1_voltage_vals]
v_y10 = [val[9] for val in lif1_voltage_vals]

# Create the plot
voltage_lif1_y_arrays = [
    (v_y1, "Neuron. 0"), (v_y2, "Neuron. 1"), (v_y3, "Neuron. 2"),
    (v_y4, "Neuron. 3"), (v_y5, "Neuron. 4"), # (v_y6, "Neuron. 5"),
    # (v_y7, "Neuron. 6"), (v_y8, "Neuron. 7"), (v_y9, "Neuron. 8"),
    # (v_y10, "Neuron. 9")
]    # List of tuples containing the y values and the legend label
# Define the box annotation parameters
box_annotation_voltage = {
    "bottom": 0,
    "top": v_th,
    "left": 0,
    "right": num_steps,
    "fill_alpha": 0.03,
    "fill_color": "green"
}

# Create the LIF1 Voltage
voltage_lif1_plot = create_fig(
    title="LIF1 Voltage dynamics", 
    x_axis_label='time (ms)', 
    y_axis_label='Voltage (V)',
    x=x, 
    y_arrays=voltage_lif1_y_arrays, 
    sizing_mode="stretch_both", 
    tools="pan, box_zoom, wheel_zoom, hover, undo, redo, zoom_in, zoom_out, reset, save",
    tooltips="Data point @x: @y",
    legend_location="top_right",
    legend_bg_fill_color="navy",
    legend_bg_fill_alpha=0.1,
    box_annotation_params=box_annotation_voltage,
    y_range=Range1d(-1.05, 1.05)
)


# Create the LIF1 Current
u_y1 = [val[215] for val in lif1_current_vals]
u_y2 = [val[124] for val in lif1_current_vals]
u_y3 = [val[129] for val in lif1_current_vals]
u_y4 = [val[138] for val in lif1_current_vals]
u_y5 = [val[164] for val in lif1_current_vals]
current_lif1_y_arrays = [(u_y1, "Neuron. 0"), (u_y2, "Neuron. 1"), (u_y3, "Neuron. 2"),
                          (u_y4, "Neuron. 3"), (u_y5, "Neuron. 4")]    # List of tuples containing the y values and the legend label
current_lif1_plot = create_fig(
    title="LIF1 Current dynamics", 
    x_axis_label='time (ms)', 
    y_axis_label='Current (U)',
    x=x, 
    y_arrays=current_lif1_y_arrays, 
    sizing_mode="stretch_both", 
    tools="pan, box_zoom, wheel_zoom, hover, undo, redo, zoom_in, zoom_out, reset, save",
    tooltips="Data point @x: @y",
    legend_location="top_right",
    legend_bg_fill_color="navy",
    legend_bg_fill_alpha=0.1,
    x_range=voltage_lif1_plot.x_range,    # Link the x-axis range to the voltage plot
)

# bplt.show(voltage_lif1_plot)

# %% [markdown]
# ## Show the Plots assembled in a grid

# %%
import bokeh.plotting as bplt
from bokeh.layouts import gridplot

showPlot = True
if showPlot:
    # Create array of plots to be shown
    plots = [voltage_lif1_plot, current_lif1_plot]

    if len(plots) == 1:
        grid = plots[0]
    else:   # Create a grid layout
        grid = gridplot(plots, ncols=2, sizing_mode="stretch_both")

    # Show the plot
    bplt.show(grid)

# %% [markdown]
# ## Export the plot to a file

# %%
export = False
OUTPUT_FOLDER = f"./results/{DATASET_FILENAME}"
TIME_SUFFIX = f"time{init_offset}-{num_steps}-{virtual_time_step_interval}"
THRESH_SUFFIX = f"thresh{thresh_up}-{thresh_down}"
STRAT_SUFFIX = f"strat{selected_strategy}"
WEIGHT_SUFFIX = f"w{weights_scale_input}"
DV_SUFFIX = f"dv{mean_dv}"
INH_RANGE = f"inh{inh_scale_range[0]}-{inh_scale_range[1]}"

if export:
    # Create the output folder if it does not exist
    if not os.path.exists(OUTPUT_FOLDER):
        os.makedirs(OUTPUT_FOLDER)

    file_path = f"{OUTPUT_FOLDER}/{band_file_name}_output_{DV_SUFFIX}_{WEIGHT_SUFFIX}_{THRESH_SUFFIX}_{INH_RANGE}_{STRAT_SUFFIX}_{TIME_SUFFIX}.html"

    # Customize the output file settings
    bplt.output_file(filename=file_path, title="HFO Detection - Voltage and Current dynamics")

    # Save the plot
    bplt.save(grid)

# %% [markdown]
# ## Export the Voltage and Current dynamics to a `.npy` file
# In order to classify the feature neurons (Noisy, Silent, Ripple, or Fast Ripple Detector), we need to export the voltage and current dynamics to a `.npy` file to be analyzed by a Classification Algorithm

# %%
EXPORT_DYNAMICS = True
if EXPORT_DYNAMICS:
    if not os.path.exists(OUTPUT_FOLDER):
        os.makedirs(OUTPUT_FOLDER)

    # Define the file paths to save the Voltage and Current dynamics
    v_dynamics_file_path = f"{OUTPUT_FOLDER}/{band_file_name}_v_dynamics_{DV_SUFFIX}_{WEIGHT_SUFFIX}_{THRESH_SUFFIX}_{INH_RANGE}_{STRAT_SUFFIX}_{TIME_SUFFIX}.npy"
    u_dynamic_file_path = f"{OUTPUT_FOLDER}/{band_file_name}_u_dynamics_{DV_SUFFIX}_{WEIGHT_SUFFIX}_{THRESH_SUFFIX}_{INH_RANGE}_{STRAT_SUFFIX}_{TIME_SUFFIX}.npy"
    
    # Export the Voltage dynamics to a numpy file
    np.save(v_dynamics_file_path, lif1_voltage_vals)
    
    # Export the Current dynamics to a numpy file
    np.save(u_dynamic_file_path, lif1_current_vals)

# %% [markdown]
# ## Export the Ground Truth data to a `.npy` file along with necessary Simulation Parameters

# %% [markdown]
# ### Load the Ground Truth data from the `.npy` file

# %%
# Load the ground_truth data
ground_truth_file_name = f"{INPUT_PATH}/{band_file_name}_ground_truth.npy"

ground_truth = np.load(ground_truth_file_name)

preview_np_array(ground_truth, "ground_truth", edge_items=3)
print(f"Number of relevant events: {np.count_nonzero(ground_truth)}")
# Out:
# ground_truth Shape: (197,).
# Preview: [('Ripple+Fast-Ripple',   1000.  , 0.)
#  ('Spike+Ripple+Fast-Ripple',   3206.54, 0.)
#  ('Spike+Ripple',   3521.  , 0.) ... ('Ripple', 116037.  , 0.)
#  ('Ripple', 116721.  , 0.) ('Spike+Ripple+Fast-Ripple', 119000.  , 0.)]
# Number of relevant events: 197

# %%
from utils.snn import SNNSimConfig

EXPORT_CONFIG = True
if EXPORT_CONFIG:
    # Define the simulation configuration
    snn_config = SNNSimConfig(ground_truth, init_offset, virtual_time_step_interval, num_steps)

    snn_config_file_name = f"{OUTPUT_FOLDER}/{band_file_name}_snn_config_{TIME_SUFFIX}.npy"
    # Save the SNN Config Class to a npy file
    np.save(snn_config_file_name, snn_config)

# %% [markdown]
# ## Stop the Runtime

# %%
selectedLIF.stop()
