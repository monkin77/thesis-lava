# %% [markdown]
# # Notebook for data visualization of the processed HFO data from human SEEGs

# %%
# Show current directory
import os
curr_dir = os.getcwd()
print(curr_dir)

PATH_TO_FILE = '' # src/seeg_data/synthetic/' # ''  # This is needed if the WD is not the same as the file location
# Out:
# /home/monkin/Desktop/feup/thesis/lava/src/seeg_data/synthetic

# %% [markdown]
# ## Add the parent directory to the path to detect the utils module

# %%
import os
import sys

# Add the parent directory to the path so it detects the utils module
module_path = os.path.abspath(os.path.join('src'))      # Changed this since WD is not the same as the file location
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# ## Load the data from the .npy file

# %%
import numpy as np
import math

seeg_file_name = "seeg_synthetic_humans.npy"
recorded_data = np.load(f"{PATH_TO_FILE}{seeg_file_name}")

print("Data shape: ", recorded_data.shape)
print("First time steps: ", recorded_data[:10])
# Out:
# Data shape:  (245760, 960)
# First time steps:  [[ 3.2352024e-01 -1.3235390e+00 -5.9668809e-01 ... -1.9608999e+00
#   -1.9769822e-01 -1.2078454e+00]
#  [-6.9759099e-04 -3.5122361e+00 -4.8766956e-01 ... -5.8757830e+00
#   -7.4400985e-01 -5.1096064e-01]
#  [ 1.9026639e+00 -5.6726017e+00  9.8274893e-01 ... -6.6182971e+00
#   -8.3053267e-01 -8.1596655e-01]
#  ...
#  [ 3.2172418e+00 -8.4650068e+00  1.5216088e+00 ... -4.1081657e+00
#    2.0085973e-01 -4.7539668e+00]
#  [ 1.7725919e+00 -9.4744024e+00  1.6776791e+00 ... -4.1469693e+00
#    1.6412770e+00 -3.4672713e+00]
#  [ 7.8109097e-01 -1.0500931e+01  2.3717029e+00 ... -5.1762242e+00
#    1.0715837e+00 -4.4489903e+00]]

# %% [markdown]
# ## Markers' Shape
# The markers are stored in a numpy array of shape (num_channels, events):
# - Each row represents the events of a channel
# - Each event is composed of the following 3 fields (Label, Position, Shape)

# %%
markers_seeg_file_name = "seeg_synthetic_humans_markers.npy"
markers = np.load(f"{PATH_TO_FILE}{markers_seeg_file_name}")

print("Markers shape: ", markers.shape)
print("First time steps: ", markers[:10])
# Out:
# Markers shape:  (960, 42)
# First time steps:  [[('Spike+Ripple+Fast-Ripple',   1000.  , 0.)
#   ('Spike+Ripple+Fast-Ripple',   4537.6 , 0.)
#   ('Ripple+Fast-Ripple',   7610.84, 0.) ('Spike',  10261.2 , 0.)
#   ('Fast-Ripple',  13411.6 , 0.) ('Spike+Ripple',  15644.  , 0.)
#   ('Ripple',  18607.9 , 0.) ('Fast-Ripple',  21300.8 , 0.)
#   ('Fast-Ripple',  24086.9 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  26598.1 , 0.)
#   ('Spike+Fast-Ripple',  30529.8 , 0.) ('Ripple',  33387.7 , 0.)
#   ('Spike+Fast-Ripple',  36145.5 , 0.) ('Spike',  38744.1 , 0.)
#   ('Spike+Fast-Ripple',  41876.  , 0.)
#   ('Ripple+Fast-Ripple',  44531.7 , 0.) ('Spike+Ripple',  47699.7 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  50303.2 , 0.) ('Ripple',  53045.9 , 0.)
#   ('Ripple+Fast-Ripple',  56416.  , 0.)
#   ('Spike+Ripple+Fast-Ripple',  58838.4 , 0.)
#   ('Ripple+Fast-Ripple',  62578.6 , 0.) ('Fast-Ripple',  65430.2 , 0.)
#   ('Spike',  68184.1 , 0.) ('Spike+Ripple',  70753.9 , 0.)
#   ('Ripple+Fast-Ripple',  73788.6 , 0.) ('Spike',  76749.  , 0.)
#   ('Fast-Ripple',  79802.7 , 0.) ('Spike+Ripple',  82200.7 , 0.)
#   ('Spike',  85205.1 , 0.) ('Spike+Fast-Ripple',  88308.6 , 0.)
#   ('Spike',  91154.3 , 0.) ('Ripple',  93484.4 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  96478.  , 0.)
#   ('Spike+Fast-Ripple',  99524.4 , 0.) ('Ripple', 101862.  , 0.)
#   ('Spike+Ripple', 104127.  , 0.) ('Spike+Fast-Ripple', 106672.  , 0.)
#   ('Ripple+Fast-Ripple', 109322.  , 0.) ('Ripple', 113024.  , 0.)
#   ('Fast-Ripple', 116549.  , 0.) ('Spike+Ripple', 119000.  , 0.)]
#  [('Spike+Fast-Ripple',   1000.  , 0.)
#   ('Spike+Ripple+Fast-Ripple',   3849.12, 0.)
#   ('Ripple+Fast-Ripple',   7010.25, 0.) ('Spike',   9893.55, 0.)
#   ('Spike+Ripple',  12840.8 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  15537.6 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  17798.3 , 0.)
#   ('Fast-Ripple',  21310.1 , 0.) ('Spike+Fast-Ripple',  24303.2 , 0.)
#   ('Spike+Ripple',  26703.1 , 0.) ('Spike+Ripple',  29163.1 , 0.)
#   ('Ripple',  32477.1 , 0.) ('Ripple',  35353.5 , 0.)
#   ('Spike+Ripple',  38091.3 , 0.) ('Ripple',  40928.7 , 0.)
#   ('Spike+Fast-Ripple',  43745.6 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  46724.6 , 0.)
#   ('Spike+Fast-Ripple',  49544.4 , 0.)
#   ('Ripple+Fast-Ripple',  52280.8 , 0.) ('Ripple',  55122.1 , 0.)
#   ('Spike',  58428.7 , 0.) ('Fast-Ripple',  61564.9 , 0.)
#   ('Ripple+Fast-Ripple',  64350.1 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  67462.4 , 0.)
#   ('Ripple+Fast-Ripple',  70412.6 , 0.)
#   ('Ripple+Fast-Ripple',  73817.9 , 0.) ('Spike',  77059.6 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  80096.7 , 0.) ('Ripple',  82790.5 , 0.)
#   ('Spike+Ripple',  86759.3 , 0.) ('Spike+Fast-Ripple',  89232.4 , 0.)
#   ('Ripple',  91572.8 , 0.) ('Spike',  94439.5 , 0.)
#   ('Spike+Ripple',  98288.1 , 0.) ('Ripple+Fast-Ripple', 101109.  , 0.)
#   ('Fast-Ripple', 103939.  , 0.) ('Fast-Ripple', 106747.  , 0.)
#   ('Spike', 109180.  , 0.) ('Spike', 112373.  , 0.)
#   ('Fast-Ripple', 114176.  , 0.) ('Spike+Fast-Ripple', 116672.  , 0.)
#   ('Fast-Ripple', 119000.  , 0.)]
#  [('Fast-Ripple',   1000.  , 0.)
#   ('Spike+Ripple+Fast-Ripple',   4357.42, 0.)
#   ('Fast-Ripple',   7062.01, 0.) ('Spike+Ripple',  10354.  , 0.)
#   ('Spike+Ripple',  12860.4 , 0.) ('Ripple',  16188.  , 0.)
#   ('Spike+Ripple+Fast-Ripple',  19890.1 , 0.) ('Spike',  23101.6 , 0.)
#   ('Spike+Fast-Ripple',  25157.2 , 0.)
#   ('Spike+Fast-Ripple',  27310.1 , 0.) ('Ripple',  30074.7 , 0.)
#   ('Spike+Ripple',  33075.7 , 0.) ('Ripple+Fast-Ripple',  37325.2 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  39814.5 , 0.) ('Ripple',  41879.4 , 0.)
#   ('Spike',  45083.5 , 0.) ('Ripple',  49012.7 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  52209.5 , 0.)
#   ('Fast-Ripple',  55219.2 , 0.) ('Ripple+Fast-Ripple',  57720.7 , 0.)
#   ('Spike+Ripple',  60536.1 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  63434.6 , 0.) ('Spike',  66771.5 , 0.)
#   ('Spike+Fast-Ripple',  69609.4 , 0.)
#   ('Spike+Fast-Ripple',  72251.  , 0.) ('Ripple',  75393.6 , 0.)
#   ('Spike',  77523.9 , 0.) ('Ripple',  80550.3 , 0.)
#   ('Ripple+Fast-Ripple',  84069.3 , 0.) ('Fast-Ripple',  86533.7 , 0.)
#   ('Spike+Fast-Ripple',  89963.4 , 0.) ('Fast-Ripple',  93359.4 , 0.)
#   ('Fast-Ripple',  95230.5 , 0.) ('Spike+Ripple',  97459.5 , 0.)
#   ('Spike', 100138.  , 0.) ('Ripple+Fast-Ripple', 102263.  , 0.)
#   ('Spike+Ripple+Fast-Ripple', 105350.  , 0.)
#   ('Spike+Ripple', 108121.  , 0.) ('Ripple+Fast-Ripple', 110854.  , 0.)
#   ('Spike+Fast-Ripple', 113759.  , 0.)
#   ('Ripple+Fast-Ripple', 116295.  , 0.) ('Spike', 119000.  , 0.)]
#  [('Fast-Ripple',   1000.  , 0.) ('Ripple',   5092.77, 0.)
#   ('Spike+Fast-Ripple',   7318.85, 0.)
#   ('Spike+Fast-Ripple',   9595.7 , 0.)
#   ('Ripple+Fast-Ripple',  12451.2 , 0.)
#   ('Spike+Fast-Ripple',  14609.4 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  17176.3 , 0.)
#   ('Ripple+Fast-Ripple',  20439.5 , 0.) ('Ripple',  23130.4 , 0.)
#   ('Spike+Ripple',  25369.6 , 0.) ('Ripple',  28132.8 , 0.)
#   ('Ripple+Fast-Ripple',  31882.3 , 0.) ('Spike+Ripple',  35011.7 , 0.)
#   ('Spike+Ripple',  38243.2 , 0.) ('Spike',  41433.1 , 0.)
#   ('Fast-Ripple',  44473.1 , 0.) ('Ripple',  46984.4 , 0.)
#   ('Fast-Ripple',  49504.4 , 0.) ('Ripple+Fast-Ripple',  53097.7 , 0.)
#   ('Ripple+Fast-Ripple',  56185.5 , 0.)
#   ('Spike+Fast-Ripple',  58714.4 , 0.) ('Ripple',  61378.9 , 0.)
#   ('Spike+Ripple',  64099.6 , 0.) ('Ripple+Fast-Ripple',  66736.3 , 0.)
#   ('Spike',  70240.2 , 0.) ('Ripple',  73241.2 , 0.)
#   ('Spike',  76167.  , 0.) ('Fast-Ripple',  78410.6 , 0.)
#   ('Spike+Fast-Ripple',  80942.9 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  83665.5 , 0.) ('Spike',  86739.3 , 0.)
#   ('Fast-Ripple',  89409.2 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  93123.5 , 0.)
#   ('Spike+Ripple',  95171.4 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  98305.2 , 0.)
#   ('Spike+Ripple', 101041.  , 0.) ('Fast-Ripple', 103388.  , 0.)
#   ('Spike+Ripple+Fast-Ripple', 106038.  , 0.)
#   ('Spike+Fast-Ripple', 109606.  , 0.) ('Spike', 113252.  , 0.)
#   ('Spike+Ripple+Fast-Ripple', 116529.  , 0.) ('Spike', 119000.  , 0.)]
#  [('Spike+Ripple',   1000.  , 0.) ('Spike+Fast-Ripple',   3064.45, 0.)
#   ('Ripple',   6027.83, 0.) ('Spike+Fast-Ripple',   8658.2 , 0.)
#   ('Ripple+Fast-Ripple',  12106.4 , 0.) ('Fast-Ripple',  14305.2 , 0.)
#   ('Fast-Ripple',  17662.6 , 0.) ('Spike+Ripple',  21267.6 , 0.)
#   ('Spike',  23998.5 , 0.) ('Spike+Ripple+Fast-Ripple',  26069.8 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  29381.3 , 0.) ('Spike',  32615.7 , 0.)
#   ('Ripple',  35105.  , 0.) ('Fast-Ripple',  37521.  , 0.)
#   ('Ripple+Fast-Ripple',  40814.5 , 0.) ('Ripple',  43641.6 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  46275.4 , 0.)
#   ('Spike+Ripple',  48763.7 , 0.) ('Spike+Fast-Ripple',  51656.7 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  54807.6 , 0.)
#   ('Fast-Ripple',  57375.5 , 0.) ('Spike+Fast-Ripple',  59815.4 , 0.)
#   ('Spike+Fast-Ripple',  62677.2 , 0.)
#   ('Ripple+Fast-Ripple',  66109.4 , 0.) ('Spike',  69555.7 , 0.)
#   ('Ripple',  72959.5 , 0.) ('Spike+Ripple',  75730.  , 0.)
#   ('Ripple',  78694.8 , 0.) ('Fast-Ripple',  81899.9 , 0.)
#   ('Fast-Ripple',  84894.5 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  87584.5 , 0.) ('Spike',  89555.2 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  92365.7 , 0.)
#   ('Ripple+Fast-Ripple',  95023.4 , 0.)
#   ('Ripple+Fast-Ripple',  98278.8 , 0.) ('Spike', 101478.  , 0.)
#   ('Spike+Ripple', 104220.  , 0.) ('Spike+Ripple', 107146.  , 0.)
#   ('Spike+Fast-Ripple', 109986.  , 0.)
#   ('Ripple+Fast-Ripple', 112877.  , 0.) ('Ripple', 115691.  , 0.)
#   ('Spike', 119000.  , 0.)]
#  [('Fast-Ripple',   1000.  , 0.) ('Ripple+Fast-Ripple',   3812.99, 0.)
#   ('Ripple',   6643.56, 0.) ('Ripple',   9703.13, 0.)
#   ('Fast-Ripple',  12194.8 , 0.) ('Spike',  15098.1 , 0.)
#   ('Spike+Fast-Ripple',  17557.6 , 0.) ('Fast-Ripple',  20716.3 , 0.)
#   ('Spike+Fast-Ripple',  24186.5 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  27138.2 , 0.) ('Spike',  29897.9 , 0.)
#   ('Spike+Fast-Ripple',  32565.9 , 0.)
#   ('Ripple+Fast-Ripple',  34736.8 , 0.)
#   ('Ripple+Fast-Ripple',  38332.5 , 0.) ('Spike+Ripple',  41036.6 , 0.)
#   ('Spike+Ripple',  44186.5 , 0.) ('Ripple+Fast-Ripple',  46985.8 , 0.)
#   ('Spike+Ripple',  49071.8 , 0.) ('Spike',  52250.  , 0.)
#   ('Ripple',  55004.9 , 0.) ('Spike',  58087.4 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  61502.4 , 0.)
#   ('Spike+Ripple',  64346.2 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  66982.9 , 0.)
#   ('Ripple+Fast-Ripple',  69884.8 , 0.) ('Spike',  72438.5 , 0.)
#   ('Fast-Ripple',  75745.1 , 0.) ('Fast-Ripple',  78004.4 , 0.)
#   ('Spike+Ripple',  80292.  , 0.)
#   ('Spike+Ripple+Fast-Ripple',  83281.3 , 0.) ('Ripple',  86146.5 , 0.)
#   ('Ripple',  88517.1 , 0.) ('Spike+Ripple',  91434.1 , 0.)
#   ('Spike+Fast-Ripple',  94384.3 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  96798.3 , 0.)
#   ('Spike+Fast-Ripple', 100239.  , 0.)
#   ('Ripple+Fast-Ripple', 103870.  , 0.) ('Fast-Ripple', 106941.  , 0.)
#   ('Spike+Ripple+Fast-Ripple', 109890.  , 0.) ('Ripple', 112565.  , 0.)
#   ('Spike+Fast-Ripple', 116043.  , 0.) ('Spike', 119000.  , 0.)]
#  [('Spike+Ripple',   1000.  , 0.) ('Spike+Fast-Ripple',   3947.75, 0.)
#   ('Ripple',   6848.63, 0.) ('Ripple+Fast-Ripple',   9342.77, 0.)
#   ('Spike',  12378.4 , 0.) ('Ripple+Fast-Ripple',  15358.9 , 0.)
#   ('Spike+Ripple',  18624.  , 0.) ('Spike+Fast-Ripple',  21766.6 , 0.)
#   ('Spike',  24684.6 , 0.) ('Fast-Ripple',  27981.4 , 0.)
#   ('Fast-Ripple',  30698.2 , 0.) ('Spike',  32988.3 , 0.)
#   ('Spike+Ripple',  35934.1 , 0.) ('Spike+Fast-Ripple',  38634.3 , 0.)
#   ('Ripple+Fast-Ripple',  42008.3 , 0.) ('Spike+Ripple',  45172.9 , 0.)
#   ('Ripple+Fast-Ripple',  47933.1 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  50622.1 , 0.) ('Ripple',  53227.5 , 0.)
#   ('Ripple',  55601.1 , 0.) ('Spike+Ripple+Fast-Ripple',  58145.5 , 0.)
#   ('Fast-Ripple',  61350.6 , 0.) ('Fast-Ripple',  64059.6 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  66864.3 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  69667.5 , 0.)
#   ('Spike+Ripple',  72280.8 , 0.) ('Spike+Ripple',  74982.4 , 0.)
#   ('Spike+Fast-Ripple',  77640.6 , 0.)
#   ('Spike+Fast-Ripple',  80725.6 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  84104.5 , 0.)
#   ('Fast-Ripple',  86585.4 , 0.) ('Spike',  89452.1 , 0.)
#   ('Ripple+Fast-Ripple',  92625.  , 0.) ('Fast-Ripple',  94686.  , 0.)
#   ('Spike',  97717.8 , 0.) ('Spike+Fast-Ripple', 100930.  , 0.)
#   ('Spike', 103618.  , 0.) ('Ripple', 106630.  , 0.)
#   ('Ripple', 108965.  , 0.) ('Ripple', 112506.  , 0.)
#   ('Spike+Ripple+Fast-Ripple', 116000.  , 0.)
#   ('Ripple+Fast-Ripple', 119000.  , 0.)]
#  [('Spike+Fast-Ripple',   1000.  , 0.)
#   ('Spike+Ripple+Fast-Ripple',   4099.12, 0.)
#   ('Spike+Fast-Ripple',   7249.51, 0.) ('Spike',   9766.11, 0.)
#   ('Spike+Ripple+Fast-Ripple',  13030.3 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  16438.  , 0.)
#   ('Spike+Ripple+Fast-Ripple',  19992.2 , 0.)
#   ('Spike+Ripple',  22127.  , 0.) ('Spike+Fast-Ripple',  24682.1 , 0.)
#   ('Fast-Ripple',  26986.3 , 0.) ('Spike+Ripple',  30152.3 , 0.)
#   ('Fast-Ripple',  32986.8 , 0.) ('Spike+Ripple',  35772.9 , 0.)
#   ('Spike',  38679.2 , 0.) ('Ripple',  41064.5 , 0.)
#   ('Fast-Ripple',  43746.6 , 0.) ('Spike+Ripple',  46012.2 , 0.)
#   ('Ripple',  48642.6 , 0.) ('Spike+Ripple',  51367.2 , 0.)
#   ('Fast-Ripple',  54580.1 , 0.) ('Spike',  58276.9 , 0.)
#   ('Spike',  61289.6 , 0.) ('Spike+Fast-Ripple',  63979.  , 0.)
#   ('Spike',  67093.3 , 0.) ('Ripple+Fast-Ripple',  70689.5 , 0.)
#   ('Spike',  73170.4 , 0.) ('Ripple',  76267.1 , 0.)
#   ('Ripple+Fast-Ripple',  79483.4 , 0.) ('Ripple',  82485.8 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  84944.8 , 0.)
#   ('Spike+Fast-Ripple',  87336.4 , 0.) ('Fast-Ripple',  90399.9 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  92600.1 , 0.)
#   ('Ripple+Fast-Ripple',  96038.6 , 0.)
#   ('Ripple+Fast-Ripple',  98303.7 , 0.)
#   ('Ripple+Fast-Ripple', 101745.  , 0.) ('Ripple', 104444.  , 0.)
#   ('Spike+Ripple', 107053.  , 0.) ('Fast-Ripple', 109825.  , 0.)
#   ('Ripple+Fast-Ripple', 112534.  , 0.) ('Ripple', 115200.  , 0.)
#   ('Spike+Fast-Ripple', 119000.  , 0.)]
#  [('Ripple+Fast-Ripple',   1000.  , 0.) ('Spike+Ripple',   3555.66, 0.)
#   ('Fast-Ripple',   5852.54, 0.) ('Fast-Ripple',   9145.51, 0.)
#   ('Spike+Ripple+Fast-Ripple',  11714.4 , 0.)
#   ('Fast-Ripple',  14260.3 , 0.) ('Spike+Fast-Ripple',  16332.5 , 0.)
#   ('Ripple',  19316.9 , 0.) ('Fast-Ripple',  22032.2 , 0.)
#   ('Spike',  25527.3 , 0.) ('Ripple+Fast-Ripple',  29096.7 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  32144.  , 0.) ('Ripple',  35350.6 , 0.)
#   ('Spike',  37768.6 , 0.) ('Spike',  40810.5 , 0.)
#   ('Spike',  43454.6 , 0.) ('Spike',  46148.9 , 0.)
#   ('Ripple+Fast-Ripple',  49296.9 , 0.) ('Fast-Ripple',  52478.  , 0.)
#   ('Spike+Ripple+Fast-Ripple',  55692.4 , 0.)
#   ('Ripple+Fast-Ripple',  58959.  , 0.)
#   ('Spike+Ripple+Fast-Ripple',  61124.  , 0.)
#   ('Spike+Ripple',  63252.4 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  66234.4 , 0.)
#   ('Ripple+Fast-Ripple',  70075.7 , 0.)
#   ('Spike+Fast-Ripple',  73000.  , 0.)
#   ('Spike+Fast-Ripple',  75776.4 , 0.)
#   ('Spike+Fast-Ripple',  79237.8 , 0.)
#   ('Ripple+Fast-Ripple',  82091.8 , 0.) ('Spike+Ripple',  84607.4 , 0.)
#   ('Spike',  87552.2 , 0.) ('Spike+Fast-Ripple',  89773.9 , 0.)
#   ('Spike+Ripple',  92686.5 , 0.) ('Spike+Ripple',  95402.3 , 0.)
#   ('Spike+Fast-Ripple',  99105.5 , 0.) ('Ripple', 102125.  , 0.)
#   ('Spike+Ripple', 105077.  , 0.) ('Ripple', 107729.  , 0.)
#   ('Ripple', 110340.  , 0.) ('Ripple', 113236.  , 0.)
#   ('Spike+Ripple+Fast-Ripple', 116402.  , 0.)
#   ('Fast-Ripple', 119000.  , 0.)]
#  [('Spike+Fast-Ripple',   1000.  , 0.) ('Fast-Ripple',   3844.24, 0.)
#   ('Ripple+Fast-Ripple',   6911.13, 0.) ('Ripple',   9519.04, 0.)
#   ('Spike',  12259.8 , 0.) ('Spike+Fast-Ripple',  15189.  , 0.)
#   ('Spike+Ripple+Fast-Ripple',  18526.4 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  21004.9 , 0.)
#   ('Ripple+Fast-Ripple',  24302.2 , 0.) ('Spike',  27242.2 , 0.)
#   ('Spike+Ripple',  29596.7 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  31946.3 , 0.)
#   ('Fast-Ripple',  34291.5 , 0.) ('Ripple+Fast-Ripple',  37582.  , 0.)
#   ('Spike+Fast-Ripple',  40289.6 , 0.) ('Ripple',  43156.3 , 0.)
#   ('Fast-Ripple',  46783.7 , 0.) ('Ripple',  50758.3 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  53685.5 , 0.)
#   ('Ripple+Fast-Ripple',  56055.2 , 0.) ('Spike+Ripple',  59023.4 , 0.)
#   ('Ripple',  61054.7 , 0.) ('Ripple',  64209.5 , 0.)
#   ('Spike+Fast-Ripple',  66384.3 , 0.) ('Ripple',  68632.8 , 0.)
#   ('Spike',  71851.6 , 0.) ('Spike',  74876.5 , 0.)
#   ('Spike+Ripple',  77247.1 , 0.) ('Fast-Ripple',  80233.4 , 0.)
#   ('Spike+Fast-Ripple',  82717.3 , 0.)
#   ('Spike+Fast-Ripple',  85167.5 , 0.) ('Spike+Ripple',  87874.5 , 0.)
#   ('Spike',  91449.7 , 0.) ('Fast-Ripple',  94450.2 , 0.)
#   ('Spike+Ripple+Fast-Ripple',  97982.4 , 0.)
#   ('Spike+Ripple', 101565.  , 0.)
#   ('Spike+Ripple+Fast-Ripple', 104568.  , 0.) ('Spike', 107079.  , 0.)
#   ('Ripple+Fast-Ripple', 110476.  , 0.) ('Fast-Ripple', 113016.  , 0.)
#   ('Ripple+Fast-Ripple', 115897.  , 0.) ('Spike+Ripple', 119000.  , 0.)]]

# %% [markdown]
# ## Define some important parameters of the input data

# %%
sampling_rate = 2048    # 2048 Hz
input_duration = 120 * (10**3)    # 120000 ms or 120 seconds
num_samples = recorded_data.shape[0]    # 2048 * 120 = 245760
num_channels = recorded_data.shape[1]   # 960

x_step = 1/sampling_rate * (10**3)  # 0.48828125 ms

# %% [markdown]
# ## Plot the data in an interactive Line Plot

# %% [markdown]
# ### Configurable parameters

# %%
# Channels to plot
min_channel = 0     #   Index of the first channel to plot
max_channel = 0     #   Index of the last channel to plot

# Create set containing the indices of the channels used
channels_used = {0, 60, 120, 180, 240, 360, 480, 600, 660, 720, 780, 840} # {0, 1, 30, 31, 60, 61, 90, 91} 
# channels_used = set(range(1, num_channels+1, 1))

# Sort the set by value and convert it to a list
channels_used = sorted(channels_used)

print(channels_used)
# Out:
# [0, 60, 120, 180, 240, 360, 480, 600, 660, 720, 780, 840]

# %%
# Interactive Plot for the HFO detection
# bokeh docs: https://docs.bokeh.org/en/2.4.1/docs/first_steps/first_steps_1.html

from utils.line_plot import create_fig  # Import the function to create the figure
from bokeh.models import Range1d

# Define the x and y values
# Should the first input start at 0 or x_step?
# TODO: is it okay to create a range with floats?
x = [val for val in np.arange(x_step, input_duration + x_step, x_step)] 

# Create the y arrays for the voltage plot representing the voltage of each electrode
v_yarrays = []
# Add each channel
for ch_idx in channels_used:
    v_yarrays.append([val[ch_idx] for val in recorded_data])

# %% [markdown]
# ## Define a specific time interval to plot

# %%
min_t = 0
max_t = input_duration # / 10     # 120 / 10 seconds = 12 seconds

# Trim the x and y arrays to the desired time range
start_index = int(min_t / x_step)
num_data_points = int((max_t - min_t) / x_step)

x = x[start_index:start_index + num_data_points + 1]
for i in range(len(v_yarrays)):
    v_yarrays[i] = v_yarrays[i][start_index:start_index + num_data_points + 1]  # Trim the y arrays

print("num_data_points", num_data_points)
# Out:
# num_data_points 245760

# %% [markdown]
# ## Create the Plot

# %%
# Create the plot
# List of tuples containing the y values and the legend label
hfo_y_arrays = [(voltage_val, f"Ch. {idx}") for idx, voltage_val in enumerate(v_yarrays)]

# Create the SEEG Voltage plot
hfo_plot = create_fig(
    title="SEEG Voltage dynamics of Synthetic data from Human recordings", 
    x_axis_label='time (ms)', 
    y_axis_label='Voltage (μV)',
    x=x, 
    y_arrays=hfo_y_arrays, 
    sizing_mode="stretch_both", 
    tools="pan, box_zoom, wheel_zoom, hover, undo, redo, zoom_in, zoom_out, reset, save",
    tooltips="Data point @x: @y",
    legend_location="top_right",
    legend_bg_fill_color="navy",
    legend_bg_fill_alpha=0.1,
    # y_range=Range1d(-0.05, 1.05)
)

# If there are more than 30 channels, hide the legend
if len(channels_used) > 30:
    # Hide the legend
    hfo_plot.legend.visible = False

# %% [markdown]
# ## Add Box Annotations to the plot to identify the marked HFOs (ground truth)

# %%
from bokeh.models import BoxAnnotation

confidence_range = 100          # When the duration is missing (0), we consider the 200ms window around the marked position
color_map = {                   # Map the label to a color
    'Spike': 'red',
    'Fast-Ripple': 'blue',
    'Ripple': 'green',  
    'Spike+Ripple': 'yellow',
    'Spike+Fast-Ripple': 'magenta',
    'Ripple+Fast-Ripple': 'cyan',
    'Spike+Ripple+Fast-Ripple': 'black'
}

visited_markers = {}    # Avoid inserting multiple boxes for the same marker (only one of each label)
use_visited = False     # Boolean controlling if we remove duplicate markers

plot_instant = True     # Boolean to plot the markers as instant events or as boxes
instant_width = 100 # 20       # Width of the instant event for visualization purposes

show_markers = True    # Boolean to show the markers
if show_markers:
    for ch_idx in channels_used:
        channel_markers = markers[ch_idx]
        # print("channel_markers", channel_markers)
        for idx2, marker in enumerate(channel_markers):
            # print("marker:", marker)
            
            if use_visited:
                # Check if the marker has already been visited and skip it if it has
                if marker['position'] in visited_markers:
                    visited_labels = visited_markers[marker['position']]    # Get the labels that already have an annotation for this position
                    if marker['label'] in visited_labels:
                        # print("Skipping marker", marker['position'], marker['label'])
                        continue    # Skip this marker
                    else:
                        visited_labels.append(marker['label'])  # Add the label to the visited labels
                else:
                    visited_markers[marker['position']] = [marker['label']] # Add the marker to the visited markers

            # Add a box annotation for each marker
            has_duration = marker['duration'] > 0
            
            confidence_constant = 0 if plot_instant or has_duration else confidence_range
            instant_padding = instant_width if plot_instant else 0

            left = marker['position'] - confidence_constant
            right = marker['position'] + confidence_constant + instant_width
            box_color = color_map[marker['label']]  # Choose a color according to the label
            
            if left < min_t or right > max_t:
                continue    # Skip this marker
            

            box = BoxAnnotation(left=left, right=right, fill_color=box_color, fill_alpha=0.2)
            # print("Added marker for channel: ", ch_idx, " at position: ", left)
            hfo_plot.add_layout(box)
# Out:
# Added marker for channel:  0  at position:  1000.0
# Added marker for channel:  0  at position:  4537.60009765625
# Added marker for channel:  0  at position:  7610.83984375
# Added marker for channel:  0  at position:  10261.2001953125
# Added marker for channel:  0  at position:  13411.599609375
# Added marker for channel:  0  at position:  15644.0
# Added marker for channel:  0  at position:  18607.900390625
# Added marker for channel:  0  at position:  21300.80078125
# Added marker for channel:  0  at position:  24086.900390625
# Added marker for channel:  0  at position:  26598.099609375
# Added marker for channel:  0  at position:  30529.80078125
# Added marker for channel:  0  at position:  33387.69921875
# Added marker for channel:  0  at position:  36145.5
# Added marker for channel:  0  at position:  38744.1015625
# Added marker for channel:  0  at position:  41876.0
# Added marker for channel:  0  at position:  44531.69921875
# Added marker for channel:  0  at position:  47699.69921875
# Added marker for channel:  0  at position:  50303.19921875
# Added marker for channel:  0  at position:  53045.8984375
# Added marker for channel:  0  at position:  56416.0
# Added marker for channel:  0  at position:  58838.3984375
# Added marker for channel:  0  at position:  62578.6015625
# Added marker for channel:  0  at position:  65430.19921875
# Added marker for channel:  0  at position:  68184.1015625
# Added marker for channel:  0  at position:  70753.8984375
# Added marker for channel:  0  at position:  73788.6015625
# Added marker for channel:  0  at position:  76749.0
# Added marker for channel:  0  at position:  79802.703125
# Added marker for channel:  0  at position:  82200.703125
# Added marker for channel:  0  at position:  85205.1015625
# Added marker for channel:  0  at position:  88308.6015625
# Added marker for channel:  0  at position:  91154.296875
# Added marker for channel:  0  at position:  93484.3984375
# Added marker for channel:  0  at position:  96478.0
# Added marker for channel:  0  at position:  99524.3984375
# Added marker for channel:  0  at position:  101862.0
# Added marker for channel:  0  at position:  104127.0
# Added marker for channel:  0  at position:  106672.0
# Added marker for channel:  0  at position:  109322.0
# Added marker for channel:  0  at position:  113024.0
# Added marker for channel:  0  at position:  116549.0
# Added marker for channel:  0  at position:  119000.0
# Added marker for channel:  60  at position:  1000.0
# Added marker for channel:  60  at position:  4864.259765625
# Added marker for channel:  60  at position:  7393.06982421875
# Added marker for channel:  60  at position:  10703.599609375
# Added marker for channel:  60  at position:  14079.099609375
# Added marker for channel:  60  at position:  16561.5
# Added marker for channel:  60  at position:  18815.400390625
# Added marker for channel:  60  at position:  21696.80078125
# Added marker for channel:  60  at position:  23181.599609375
# Added marker for channel:  60  at position:  26527.80078125
# Added marker for channel:  60  at position:  29216.80078125
# Added marker for channel:  60  at position:  32364.69921875
# Added marker for channel:  60  at position:  35471.19921875
# Added marker for channel:  60  at position:  38055.69921875
# Added marker for channel:  60  at position:  41405.80078125
# Added marker for channel:  60  at position:  44010.69921875
# Added marker for channel:  60  at position:  47026.8984375
# Added marker for channel:  60  at position:  49739.30078125
# Added marker for channel:  60  at position:  52280.80078125
# Added marker for channel:  60  at position:  55846.19921875
# Added marker for channel:  60  at position:  58763.19921875
# Added marker for channel:  60  at position:  61331.1015625
# Added marker for channel:  60  at position:  65355.0
# Added marker for channel:  60  at position:  68086.8984375
# Added marker for channel:  60  at position:  71237.796875
# Added marker for channel:  60  at position:  73814.8984375
# Added marker for channel:  60  at position:  76415.5
# Added marker for channel:  60  at position:  79358.3984375
# Added marker for channel:  60  at position:  82070.796875
# Added marker for channel:  60  at position:  85400.3984375
# Added marker for channel:  60  at position:  89184.1015625
# Added marker for channel:  60  at position:  91800.796875
# Added marker for channel:  60  at position:  94755.3984375
# Added marker for channel:  60  at position:  98271.5
# Added marker for channel:  60  at position:  100830.0
# Added marker for channel:  60  at position:  102831.0
# Added marker for channel:  60  at position:  105380.0
# Added marker for channel:  60  at position:  108167.0
# Added marker for channel:  60  at position:  111072.0
# Added marker for channel:  60  at position:  114138.0
# Added marker for channel:  60  at position:  116290.0
# Added marker for channel:  60  at position:  119000.0
# Added marker for channel:  120  at position:  1000.0
# Added marker for channel:  120  at position:  3539.550048828125
# Added marker for channel:  120  at position:  6644.52978515625
# Added marker for channel:  120  at position:  8995.6103515625
# Added marker for channel:  120  at position:  12344.2001953125
# Added marker for channel:  120  at position:  14663.599609375
# Added marker for channel:  120  at position:  17598.599609375
# Added marker for channel:  120  at position:  20029.30078125
# Added marker for channel:  120  at position:  22821.80078125
# Added marker for channel:  120  at position:  26020.0
# Added marker for channel:  120  at position:  29581.099609375
# Added marker for channel:  120  at position:  32056.19921875
# Added marker for channel:  120  at position:  35613.80078125
# Added marker for channel:  120  at position:  38290.5
# Added marker for channel:  120  at position:  40520.5
# Added marker for channel:  120  at position:  43573.69921875
# Added marker for channel:  120  at position:  46742.19921875
# Added marker for channel:  120  at position:  49319.30078125
# Added marker for channel:  120  at position:  51870.6015625
# Added marker for channel:  120  at position:  54646.5
# Added marker for channel:  120  at position:  57469.69921875
# Added marker for channel:  120  at position:  60268.1015625
# Added marker for channel:  120  at position:  62655.30078125
# Added marker for channel:  120  at position:  65678.203125
# Added marker for channel:  120  at position:  68767.1015625
# Added marker for channel:  120  at position:  72664.1015625
# Added marker for channel:  120  at position:  75757.296875
# Added marker for channel:  120  at position:  79213.8984375
# Added marker for channel:  120  at position:  82917.0
# Added marker for channel:  120  at position:  85532.203125
# Added marker for channel:  120  at position:  88936.0
# Added marker for channel:  120  at position:  91633.296875
# Added marker for channel:  120  at position:  94982.8984375
# Added marker for channel:  120  at position:  98027.296875
# Added marker for channel:  120  at position:  100506.0
# Added marker for channel:  120  at position:  102837.0
# Added marker for channel:  120  at position:  105549.0
# Added marker for channel:  120  at position:  108152.0
# Added marker for channel:  120  at position:  111010.0
# Added marker for channel:  120  at position:  113596.0
# Added marker for channel:  120  at position:  116395.0
# Added marker for channel:  120  at position:  119000.0
# Added marker for channel:  180  at position:  1000.0
# Added marker for channel:  180  at position:  3494.6298828125
# Added marker for channel:  180  at position:  6010.740234375
# Added marker for channel:  180  at position:  9643.0703125
# Added marker for channel:  180  at position:  12295.400390625
# Added marker for channel:  180  at position:  14632.2998046875
# Added marker for channel:  180  at position:  17252.0
# Added marker for channel:  180  at position:  19480.5
# Added marker for channel:  180  at position:  21489.69921875
# Added marker for channel:  180  at position:  24047.900390625
# Added marker for channel:  180  at position:  27377.400390625
# Added marker for channel:  180  at position:  30754.900390625
# Added marker for channel:  180  at position:  33798.30078125
# Added marker for channel:  180  at position:  37222.69921875
# Added marker for channel:  180  at position:  40035.19921875
# Added marker for channel:  180  at position:  42738.30078125
# Added marker for channel:  180  at position:  45546.3984375
# Added marker for channel:  180  at position:  48994.6015625
# Added marker for channel:  180  at position:  51571.30078125
# Added marker for channel:  180  at position:  54840.80078125
# Added marker for channel:  180  at position:  57722.19921875
# Added marker for channel:  180  at position:  60262.19921875
# Added marker for channel:  180  at position:  62444.80078125
# Added marker for channel:  180  at position:  64997.6015625
# Added marker for channel:  180  at position:  68386.203125
# Added marker for channel:  180  at position:  70817.3984375
# Added marker for channel:  180  at position:  73800.296875
# Added marker for channel:  180  at position:  76865.703125
# Added marker for channel:  180  at position:  79629.3984375
# Added marker for channel:  180  at position:  82483.8984375
# Added marker for channel:  180  at position:  85327.6015625
# Added marker for channel:  180  at position:  88667.5
# Added marker for channel:  180  at position:  92326.203125
# Added marker for channel:  180  at position:  94484.8984375
# Added marker for channel:  180  at position:  98147.0
# Added marker for channel:  180  at position:  100916.0
# Added marker for channel:  180  at position:  104235.0
# Added marker for channel:  180  at position:  106931.0
# Added marker for channel:  180  at position:  109024.0
# Added marker for channel:  180  at position:  113354.0
# Added marker for channel:  180  at position:  115743.0
# Added marker for channel:  180  at position:  119000.0
# Added marker for channel:  240  at position:  1000.0
# Added marker for channel:  240  at position:  3799.800048828125
# Added marker for channel:  240  at position:  7079.58984375
# Added marker for channel:  240  at position:  9556.6396484375
# Added marker for channel:  240  at position:  12720.7001953125
# Added marker for channel:  240  at position:  15400.400390625
# Added marker for channel:  240  at position:  18004.400390625
# Added marker for channel:  240  at position:  20588.900390625
# Added marker for channel:  240  at position:  22820.80078125
# Added marker for channel:  240  at position:  25502.400390625
# Added marker for channel:  240  at position:  27989.69921875
# Added marker for channel:  240  at position:  31167.0
# Added marker for channel:  240  at position:  34415.0
# Added marker for channel:  240  at position:  37164.6015625
# Added marker for channel:  240  at position:  39703.1015625
# Added marker for channel:  240  at position:  43070.30078125
# Added marker for channel:  240  at position:  46430.19921875
# Added marker for channel:  240  at position:  49519.0
# Added marker for channel:  240  at position:  52401.3984375
# Added marker for channel:  240  at position:  54756.30078125
# Added marker for channel:  240  at position:  57318.3984375
# Added marker for channel:  240  at position:  59621.6015625
# Added marker for channel:  240  at position:  62120.1015625
# Added marker for channel:  240  at position:  65410.19921875
# Added marker for channel:  240  at position:  68248.0
# Added marker for channel:  240  at position:  72312.0
# Added marker for channel:  240  at position:  75276.3984375
# Added marker for channel:  240  at position:  77590.796875
# Added marker for channel:  240  at position:  80551.296875
# Added marker for channel:  240  at position:  82937.0
# Added marker for channel:  240  at position:  85915.0
# Added marker for channel:  240  at position:  88593.296875
# Added marker for channel:  240  at position:  91550.296875
# Added marker for channel:  240  at position:  93627.3984375
# Added marker for channel:  240  at position:  96156.703125
# Added marker for channel:  240  at position:  98983.3984375
# Added marker for channel:  240  at position:  102280.0
# Added marker for channel:  240  at position:  105394.0
# Added marker for channel:  240  at position:  108811.0
# Added marker for channel:  240  at position:  112544.0
# Added marker for channel:  240  at position:  115950.0
# Added marker for channel:  240  at position:  119000.0
# Added marker for channel:  360  at position:  1000.0
# Added marker for channel:  360  at position:  4377.93017578125
# Added marker for channel:  360  at position:  7080.56982421875
# Added marker for channel:  360  at position:  9924.3203125
# Added marker for channel:  360  at position:  13136.7001953125
# Added marker for channel:  360  at position:  16156.7001953125
# Added marker for channel:  360  at position:  18669.400390625
# Added marker for channel:  360  at position:  21319.30078125
# Added marker for channel:  360  at position:  22995.099609375
# Added marker for channel:  360  at position:  25578.599609375
# Added marker for channel:  360  at position:  29043.0
# Added marker for channel:  360  at position:  31884.80078125
# Added marker for channel:  360  at position:  34456.5
# Added marker for channel:  360  at position:  36747.6015625
# Added marker for channel:  360  at position:  39397.8984375
# Added marker for channel:  360  at position:  42236.30078125
# Added marker for channel:  360  at position:  45950.69921875
# Added marker for channel:  360  at position:  48971.69921875
# Added marker for channel:  360  at position:  51367.69921875
# Added marker for channel:  360  at position:  54163.1015625
# Added marker for channel:  360  at position:  57608.8984375
# Added marker for channel:  360  at position:  59802.19921875
# Added marker for channel:  360  at position:  62108.3984375
# Added marker for channel:  360  at position:  65280.80078125
# Added marker for channel:  360  at position:  68362.796875
# Added marker for channel:  360  at position:  71877.8984375
# Added marker for channel:  360  at position:  74859.3984375
# Added marker for channel:  360  at position:  78216.296875
# Added marker for channel:  360  at position:  82022.8984375
# Added marker for channel:  360  at position:  84236.796875
# Added marker for channel:  360  at position:  87608.8984375
# Added marker for channel:  360  at position:  90586.3984375
# Added marker for channel:  360  at position:  93131.296875
# Added marker for channel:  360  at position:  95462.3984375
# Added marker for channel:  360  at position:  98526.3984375
# Added marker for channel:  360  at position:  102007.0
# Added marker for channel:  360  at position:  104880.0
# Added marker for channel:  360  at position:  107995.0
# Added marker for channel:  360  at position:  110622.0
# Added marker for channel:  360  at position:  113093.0
# Added marker for channel:  360  at position:  115859.0
# Added marker for channel:  360  at position:  119000.0
# Added marker for channel:  480  at position:  1000.0
# Added marker for channel:  480  at position:  4263.18017578125
# Added marker for channel:  480  at position:  6444.33984375
# Added marker for channel:  480  at position:  9331.5400390625
# Added marker for channel:  480  at position:  12135.2998046875
# Added marker for channel:  480  at position:  14585.400390625
# Added marker for channel:  480  at position:  16730.5
# Added marker for channel:  480  at position:  19774.900390625
# Added marker for channel:  480  at position:  22697.30078125
# Added marker for channel:  480  at position:  25913.099609375
# Added marker for channel:  480  at position:  27934.099609375
# Added marker for channel:  480  at position:  29890.099609375
# Added marker for channel:  480  at position:  33259.30078125
# Added marker for channel:  480  at position:  36495.1015625
# Added marker for channel:  480  at position:  39932.6015625
# Added marker for channel:  480  at position:  42853.0
# Added marker for channel:  480  at position:  46289.6015625
# Added marker for channel:  480  at position:  48850.1015625
# Added marker for channel:  480  at position:  52122.1015625
# Added marker for channel:  480  at position:  55087.3984375
# Added marker for channel:  480  at position:  57838.3984375
# Added marker for channel:  480  at position:  60579.6015625
# Added marker for channel:  480  at position:  63864.69921875
# Added marker for channel:  480  at position:  67110.3984375
# Added marker for channel:  480  at position:  70155.296875
# Added marker for channel:  480  at position:  73936.5
# Added marker for channel:  480  at position:  76257.296875
# Added marker for channel:  480  at position:  79202.6015625
# Added marker for channel:  480  at position:  81206.5
# Added marker for channel:  480  at position:  84651.3984375
# Added marker for channel:  480  at position:  86889.6015625
# Added marker for channel:  480  at position:  90042.0
# Added marker for channel:  480  at position:  93212.3984375
# Added marker for channel:  480  at position:  96520.5
# Added marker for channel:  480  at position:  99438.5
# Added marker for channel:  480  at position:  102065.0
# Added marker for channel:  480  at position:  105558.0
# Added marker for channel:  480  at position:  108279.0
# Added marker for channel:  480  at position:  111353.0
# Added marker for channel:  480  at position:  114334.0
# Added marker for channel:  480  at position:  116417.0
# Added marker for channel:  480  at position:  119000.0
# Added marker for channel:  600  at position:  1000.0
# Added marker for channel:  600  at position:  3891.60009765625
# Added marker for channel:  600  at position:  6296.39013671875
# Added marker for channel:  600  at position:  8613.2802734375
# Added marker for channel:  600  at position:  11734.900390625
# Added marker for channel:  600  at position:  14529.2998046875
# Added marker for channel:  600  at position:  17403.30078125
# Added marker for channel:  600  at position:  20160.599609375
# Added marker for channel:  600  at position:  22938.0
# Added marker for channel:  600  at position:  26003.400390625
# Added marker for channel:  600  at position:  29207.5
# Added marker for channel:  600  at position:  32262.69921875
# Added marker for channel:  600  at position:  34306.6015625
# Added marker for channel:  600  at position:  36888.19921875
# Added marker for channel:  600  at position:  39997.6015625
# Added marker for channel:  600  at position:  42762.19921875
# Added marker for channel:  600  at position:  45203.6015625
# Added marker for channel:  600  at position:  48754.8984375
# Added marker for channel:  600  at position:  51436.5
# Added marker for channel:  600  at position:  54878.8984375
# Added marker for channel:  600  at position:  58479.0
# Added marker for channel:  600  at position:  61078.1015625
# Added marker for channel:  600  at position:  64247.6015625
# Added marker for channel:  600  at position:  66710.8984375
# Added marker for channel:  600  at position:  70455.1015625
# Added marker for channel:  600  at position:  72546.3984375
# Added marker for channel:  600  at position:  76750.0
# Added marker for channel:  600  at position:  80123.0
# Added marker for channel:  600  at position:  82592.796875
# Added marker for channel:  600  at position:  85595.203125
# Added marker for channel:  600  at position:  87846.703125
# Added marker for channel:  600  at position:  90658.703125
# Added marker for channel:  600  at position:  93662.1015625
# Added marker for channel:  600  at position:  96441.8984375
# Added marker for channel:  600  at position:  98798.296875
# Added marker for channel:  600  at position:  101244.0
# Added marker for channel:  600  at position:  104829.0
# Added marker for channel:  600  at position:  107410.0
# Added marker for channel:  600  at position:  109472.0
# Added marker for channel:  600  at position:  112755.0
# Added marker for channel:  600  at position:  115694.0
# Added marker for channel:  600  at position:  119000.0
# Added marker for channel:  660  at position:  1000.0
# Added marker for channel:  660  at position:  3729.97998046875
# Added marker for channel:  660  at position:  7000.490234375
# Added marker for channel:  660  at position:  9382.8095703125
# Added marker for channel:  660  at position:  12603.5
# Added marker for channel:  660  at position:  15802.7001953125
# Added marker for channel:  660  at position:  18596.19921875
# Added marker for channel:  660  at position:  21195.80078125
# Added marker for channel:  660  at position:  24021.5
# Added marker for channel:  660  at position:  27182.599609375
# Added marker for channel:  660  at position:  30166.0
# Added marker for channel:  660  at position:  33125.5
# Added marker for channel:  660  at position:  36076.69921875
# Added marker for channel:  660  at position:  39666.5
# Added marker for channel:  660  at position:  43361.80078125
# Added marker for channel:  660  at position:  47073.19921875
# Added marker for channel:  660  at position:  49928.19921875
# Added marker for channel:  660  at position:  52807.6015625
# Added marker for channel:  660  at position:  55631.80078125
# Added marker for channel:  660  at position:  58421.3984375
# Added marker for channel:  660  at position:  61151.8984375
# Added marker for channel:  660  at position:  63608.3984375
# Added marker for channel:  660  at position:  66781.703125
# Added marker for channel:  660  at position:  70079.1015625
# Added marker for channel:  660  at position:  72106.3984375
# Added marker for channel:  660  at position:  74835.8984375
# Added marker for channel:  660  at position:  76887.203125
# Added marker for channel:  660  at position:  79916.0
# Added marker for channel:  660  at position:  82710.3984375
# Added marker for channel:  660  at position:  84852.5
# Added marker for channel:  660  at position:  87069.796875
# Added marker for channel:  660  at position:  90356.8984375
# Added marker for channel:  660  at position:  92834.0
# Added marker for channel:  660  at position:  95542.5
# Added marker for channel:  660  at position:  98093.296875
# Added marker for channel:  660  at position:  101221.0
# Added marker for channel:  660  at position:  103976.0
# Added marker for channel:  660  at position:  107815.0
# Added marker for channel:  660  at position:  110073.0
# Added marker for channel:  660  at position:  112560.0
# Added marker for channel:  660  at position:  115802.0
# Added marker for channel:  660  at position:  119000.0
# Added marker for channel:  720  at position:  1000.0
# Added marker for channel:  720  at position:  3701.169921875
# Added marker for channel:  720  at position:  6519.0400390625
# Added marker for channel:  720  at position:  9339.83984375
# Added marker for channel:  720  at position:  11874.5
# Added marker for channel:  720  at position:  15197.7998046875
# Added marker for channel:  720  at position:  18712.900390625
# Added marker for channel:  720  at position:  21029.30078125
# Added marker for channel:  720  at position:  23684.099609375
# Added marker for channel:  720  at position:  26492.69921875
# Added marker for channel:  720  at position:  29636.69921875
# Added marker for channel:  720  at position:  32193.400390625
# Added marker for channel:  720  at position:  35692.8984375
# Added marker for channel:  720  at position:  39171.3984375
# Added marker for channel:  720  at position:  42425.80078125
# Added marker for channel:  720  at position:  45126.5
# Added marker for channel:  720  at position:  48162.1015625
# Added marker for channel:  720  at position:  51387.69921875
# Added marker for channel:  720  at position:  54167.0
# Added marker for channel:  720  at position:  57069.30078125
# Added marker for channel:  720  at position:  59413.6015625
# Added marker for channel:  720  at position:  61991.69921875
# Added marker for channel:  720  at position:  64584.0
# Added marker for channel:  720  at position:  67929.703125
# Added marker for channel:  720  at position:  71025.3984375
# Added marker for channel:  720  at position:  73684.1015625
# Added marker for channel:  720  at position:  77136.203125
# Added marker for channel:  720  at position:  79749.0
# Added marker for channel:  720  at position:  82849.6015625
# Added marker for channel:  720  at position:  86355.0
# Added marker for channel:  720  at position:  89810.1015625
# Added marker for channel:  720  at position:  92008.796875
# Added marker for channel:  720  at position:  95447.796875
# Added marker for channel:  720  at position:  97496.6015625
# Added marker for channel:  720  at position:  100568.0
# Added marker for channel:  720  at position:  102976.0
# Added marker for channel:  720  at position:  105490.0
# Added marker for channel:  720  at position:  108412.0
# Added marker for channel:  720  at position:  111326.0
# Added marker for channel:  720  at position:  113968.0
# Added marker for channel:  720  at position:  117162.0
# Added marker for channel:  720  at position:  119000.0
# Added marker for channel:  780  at position:  1000.0
# Added marker for channel:  780  at position:  3495.1201171875
# Added marker for channel:  780  at position:  5951.66015625
# Added marker for channel:  780  at position:  9609.8603515625
# Added marker for channel:  780  at position:  12251.0
# Added marker for channel:  780  at position:  14664.599609375
# Added marker for channel:  780  at position:  17029.80078125
# Added marker for channel:  780  at position:  20772.5
# Added marker for channel:  780  at position:  23651.900390625
# Added marker for channel:  780  at position:  26064.5
# Added marker for channel:  780  at position:  28262.69921875
# Added marker for channel:  780  at position:  31265.099609375
# Added marker for channel:  780  at position:  33550.80078125
# Added marker for channel:  780  at position:  35888.19921875
# Added marker for channel:  780  at position:  38790.5
# Added marker for channel:  780  at position:  41863.30078125
# Added marker for channel:  780  at position:  44211.3984375
# Added marker for channel:  780  at position:  46396.5
# Added marker for channel:  780  at position:  49369.6015625
# Added marker for channel:  780  at position:  52731.8984375
# Added marker for channel:  780  at position:  55659.69921875
# Added marker for channel:  780  at position:  58975.1015625
# Added marker for channel:  780  at position:  61766.1015625
# Added marker for channel:  780  at position:  64413.6015625
# Added marker for channel:  780  at position:  66948.203125
# Added marker for channel:  780  at position:  69464.3984375
# Added marker for channel:  780  at position:  72718.296875
# Added marker for channel:  780  at position:  75975.1015625
# Added marker for channel:  780  at position:  78794.8984375
# Added marker for channel:  780  at position:  82805.703125
# Added marker for channel:  780  at position:  86012.703125
# Added marker for channel:  780  at position:  89214.796875
# Added marker for channel:  780  at position:  92428.203125
# Added marker for channel:  780  at position:  95633.296875
# Added marker for channel:  780  at position:  98546.3984375
# Added marker for channel:  780  at position:  101784.0
# Added marker for channel:  780  at position:  104653.0
# Added marker for channel:  780  at position:  107295.0
# Added marker for channel:  780  at position:  110172.0
# Added marker for channel:  780  at position:  113363.0
# Added marker for channel:  780  at position:  116179.0
# Added marker for channel:  780  at position:  119000.0
# Added marker for channel:  840  at position:  1000.0
# Added marker for channel:  840  at position:  3901.85009765625
# Added marker for channel:  840  at position:  6418.93994140625
# Added marker for channel:  840  at position:  9466.7998046875
# Added marker for channel:  840  at position:  11710.400390625
# Added marker for channel:  840  at position:  14568.400390625
# Added marker for channel:  840  at position:  17462.900390625
# Added marker for channel:  840  at position:  20576.69921875
# Added marker for channel:  840  at position:  22666.5
# Added marker for channel:  840  at position:  25398.400390625
# Added marker for channel:  840  at position:  27767.599609375
# Added marker for channel:  840  at position:  30496.099609375
# Added marker for channel:  840  at position:  33309.6015625
# Added marker for channel:  840  at position:  36069.80078125
# Added marker for channel:  840  at position:  38458.5
# Added marker for channel:  840  at position:  40933.6015625
# Added marker for channel:  840  at position:  43435.5
# Added marker for channel:  840  at position:  45781.69921875
# Added marker for channel:  840  at position:  48856.8984375
# Added marker for channel:  840  at position:  52108.8984375
# Added marker for channel:  840  at position:  54219.19921875
# Added marker for channel:  840  at position:  57319.80078125
# Added marker for channel:  840  at position:  60201.19921875
# Added marker for channel:  840  at position:  63246.1015625
# Added marker for channel:  840  at position:  65839.796875
# Added marker for channel:  840  at position:  68610.796875
# Added marker for channel:  840  at position:  71628.8984375
# Added marker for channel:  840  at position:  74972.203125
# Added marker for channel:  840  at position:  77730.5
# Added marker for channel:  840  at position:  80855.0
# Added marker for channel:  840  at position:  84395.0
# Added marker for channel:  840  at position:  87235.3984375
# Added marker for channel:  840  at position:  90513.203125
# Added marker for channel:  840  at position:  93769.0
# Added marker for channel:  840  at position:  96750.0
# Added marker for channel:  840  at position:  99865.703125
# Added marker for channel:  840  at position:  102383.0
# Added marker for channel:  840  at position:  105659.0
# Added marker for channel:  840  at position:  109570.0
# Added marker for channel:  840  at position:  112396.0
# Added marker for channel:  840  at position:  115887.0
# Added marker for channel:  840  at position:  119000.0

# %% [markdown]
# ## Show the Plot

# %%
import bokeh.plotting as bplt

showPlot = True
if showPlot:
    bplt.show(hfo_plot)

# %% [markdown]
# ## Export the plot to a file

# %%
export = False

if export:
    file_path = f"{PATH_TO_FILE}results/seeg_all_regions_diff_snr.html"

    # Customize the output file settings
    bplt.output_file(filename=file_path, title="SEEG Data - Voltage dynamics across time")

    # Save the plot
    bplt.save(hfo_plot)

# %%
# TODO: Analyze the HFOs of different channels unde
